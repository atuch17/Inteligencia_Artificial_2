# %% [markdown]
# __No te olvides de rellenar esto:__
#
# - Número de grupo: 18
# - Nombre de los integrantes del grupo: Hong Xiang Chen, Adrian Turiel Charro y Andrés Teruel Fernández

# %% [markdown]
# # Práctica 1
#
# > __Fecha de entrega: 11 de abril de 2021__
#
#
# ## Parte 2: similitud semántica
#
# Una de las grandes ventajas de las representaciones estructuradas es que podemos aprovechar su estructura para calcular similitudes semánticas entre las entidades. En esta ocasión vamos a cacular la similitud entre dos conceptos como:
#
# $$Sim(A, B) = \frac{\delta(root, C)}{\delta(root, C) + \delta(C, A) + \delta(C, B)}$$
#
# siendo:
#
# - $\delta(X, Y)$ el __mínimo__ número de aristas que conecta A y B, siendo A más general que B.
# - $C = LCS(A, B)$ el concepto más específico de la jerarquía que es más general que A y B (_least common subsummer_).
#
# La idea tras esta similitud queda reflejada en la siguiente imagen:
#
# <img src="sim.png" alt="Similitud" style="width: 300px;"/>
#
# En la práctica pueden existir distintos conceptos C que cumplen la definición de _least common subsummer_ de A y B por lo que es necesario definir cuál de ellos vamos a utilizar. En nuestro caso seleccionaremos __uno de los que maximiza el valor de similitud__.

# %% [markdown]
# ### 1) Obtener la taxonomía con la que vamos a trabajar
#
# Utiliza el [punto el acceso](https://query.wikidata.org/) SPARQL de Wikidata para ejecutar una consulta que devuelva todos los pares de entidades $(x, y)$ tal que $x$ es subconcepto directo de $y$ y ambos son un tipos de [instrumentos musicales (Q34379)](https://www.wikidata.org/wiki/Q34379). Debes recuperar tantos las URIs de la entidades como sus etiquetas.
#
# Escribe en la siguiente celda la consulta que has utilizado comentada adecuadamente.

# %% [raw]
# SELECT ?y ?yLabel ?x ?xLabel
# WHERE
# {
#   ?x wdt:P279 ?y.
#   ?y wdt:P279* wd:Q34379. # y es un instrumento
#   SERVICE wikibase:label { bd:serviceParam wikibase:language"[AUTO_LANGUAGE],es, en". }
# }

# %% [markdown]
# A continuación descarga todas las respuestas en formato _Archivo JSON_ y guardalo en el mismo directorio de la práctica.
#
# _Nota: en el momento de realizar esta práctica obtuve 4727 resultados pero el número puede variar al ser Wikidata una base de conocimiento dinámica._

# %% [markdown]
# ### 2) Cargar la taxonomía en memoria
#
# Vamos a cargar la taxonomía de clases en memoria para poder operar con ella. Representaremos la jerarquía de clases mediante las siguientes estructuras:
#
# - Un diccionario que asocia a cada identificador su etiqueta (por ejemplo 'Q34379' -> 'musical instrument')
# - Un diccionario que asocia cada clase con sus subclases directas (por ejemplo 'Q17172850' -> {'Q101436564', 'Q1067089', 'Q186506', 'Q210970', 'Q223166', ...}, )
# - Un diccionario que asocia cada clase con sus superclases directas (por ejemplo 'Q5994' -> {'Q3152898', 'Q4951628', 'Q52954'})
#
# Tienes libertad para elegir cómo quieres representar la taxonomía en Python:
#
# - Puedes usar una clase. En ese caso tendrás que ir añadiendo métodos a la clase para completar cada uno de los apartados de la práctica. Escribe el código de la clase en una única celda y utiliza los métodos que necesites en cada uno de los apartados.
# - Puedes usar 3 variables globales para representar la taxonomía. En ese caso deberás escribir las operaciones como funciones en cada uno de los apartados de la práctica.
#
# En cualquier caso recuerda documentar adecuadamente el código y trata de que sea sencillo de entender.
#
# Crea una operación _load_ que reciba el nombre del fichero json y cargue el grafo en memoria usando las estructuras anteriores.
#
# ```python
# import json
#
# with open(filename) as f:
#     data = json.load(f)
# ```

# %% [markdown]
# Hemos optado por usar los 3 diccionarios como variables globales y crear funciones aparte que trabajen con ellas

# %%
import json

def load(archivo): 
    with open(archivo, encoding="utf8") as f:
        data = json.load(f)

    instrumento_etiqueta = dict()
    clase_subclase       = dict()
    clase_superclase     = dict()

    for p in data:
        a = p['x'].split(sep='/')
        b = p['y'].split(sep='/')
        instrumento_etiqueta[a[-1]] = p['xLabel']
        instrumento_etiqueta[b[-1]] = p['yLabel']
        clase_subclase.setdefault(b[-1], []).append(a[-1])
        clase_superclase.setdefault(a[-1], []).append(b[-1])

    return instrumento_etiqueta, clase_subclase, clase_superclase

# %% [markdown]
# * ### Comentarios:
#
# Cargamos todos los datos en la variable data, e inicializamos los diccionarios que vamos a usar después. La forma en que añadimos los datos al diccionario consiste en:
#
# 'a = p['x'].split(sep='/')' → Convierte algo de la forma 'http://www.wikidata.org/entity/Q11404' en un vector, donde cada elemento del vector, es el contenido entre esos '/', de forma que solo nos interesa quedarnos con el ultimo, es de decir, el 'Q11404', por eso a cada diccionario le añadimos el último elemento de ese vector (vector[-1])
#
# -------------

# %%
identificador_etiqueta, subclase, superclase = load('taxonomia.json')

# %%
identificador_etiqueta
# Out:
# {'Q191464': 'zerbaghali',
#  'Q11404': 'drums',
#  'Q208421': 'caja',
#  'Q211028': 'cacaaaaa',
#  'Q221769': 'taiko',
#  'Q440856': 'dhimay',
#  'Q520754': 'xiangjiao gu',
#  'Q537750': 'Yembe',
#  'Q811075': 'batá',
#  'Q849349': 'Tom-Tom',
#  'Q1062015': 'janggu',
#  'Q1156506': 'Dabakan',
#  'Q1158124': 'Q1158124',
#  'Q1196937': 'tenor drum',
#  'Q1235547': 'Doli',
#  'Q1321939': 'Nagara',
#  'Q1436500': 'Mridanga',
#  'Q1558889': 'Comunicación con tambores',
#  'Q1575231': 'tambor de mano',
#  'Q2118356': 'Q2118356',
#  'Q2217018': 'Q2217018',
#  'Q2391458': 'Q2391458',
#  'Q2565221': 'Q2565221',
#  'Q2754430': 'buk',
#  'Q3038392': 'Dayereh',
#  'Q3199707': 'Q3199707',
#  'Q3623050': 'Sakara',
#  'Q4450903': 'Q4450903',
#  'Q4863624': 'Barril de bomba',
#  'Q4905606': 'Big Drum',
#  'Q5064156': 'ceremonial drum',
#  'Q5211919': 'Damaha',
#  'Q6458439': 'Keho',
#  'Q7278496': 'Raban',
#  'Q7384685': 'Maruas',
#  'Q7682928': 'tanggu',
#  'Q7852753': 'Tumyr',
#  'Q10396699': 'Q10396699',
#  'Q10829913': 'bronze drum',
#  'Q11420300': 'Uchiwa daiko',
#  'Q11950748': 'Tabal',
#  'Q12698682': 'Nahara',
#  'Q12821705': 'Duhul',
#  'Q13025534': 'Poeng mang',
#  'Q14640031': 'kundu',
#  'Q15614634': 'kakko',
#  'Q28657984': 'Bengo baido',
#  'Q28944914': 'Dindimi',
#  'Q60617211': 'tin drum',
#  'Q60742599': 'yaogu',
#  'Q80862258': 'Gataberaya',
#  'Q101968884': 'agbosí',
#  'Q129321': 'Ayoyotes',
#  'Q12639': 'idiófono',
#  'Q133722': 'Bianzhong',
#  'Q339801': "ka'eke'eke",
#  'Q390110': 'Vibraslap',
#  'Q398619': 'Agung',
#  'Q835684': 'Clicker',
#  'Q859236': 'Cegléd water jug',
#  'Q871633': 'Campanilla (instrumento)',
#  'Q936762': 'lamelófono',
#  'Q943438': 'chalaparta',
#  'Q963334': 'Hi hat',
#  'Q976406': 'Aro pandereta',
#  'Q978694': 'Calabash',
#  'Q1014229': 'yunluo',
#  'Q1043002': 'Shekere',
#  'Q1050106': 'handchime',
#  'Q1075560': 'Sonajero',
#  'Q1195473': 'Toaca',
#  'Q1196263': 'Suikinkutsu',
#  'Q1252956': 'Karátalas',
#  'Q1371129': 'Qraqeb',
#  'Q1394579': 'Quijada',
#  'Q1401426': 'Treshchotka',
#  'Q1414882': 'Chinesco',
#  'Q1514705': 'bell plate',
#  'Q1537130': 'Gong ageng',
#  'Q1540998': 'Güira',
#  'Q1743465': 'Kiringi',
#  'Q1790046': 'Crótalos (instrumento griego)',
#  'Q1842022': 'sanba',
#  'Q1968760': 'Shaker',
#  'Q2118808': 'Dance Chimes',
#  'Q2280552': 'kane',
#  'Q2553890': 'Egg shaker',
#  'Q2574301': 'Teponaztli',
#  'Q2628163': 'altar bell',
#  'Q2640100': 'saron',
#  'Q2698284': 'Lagerfono',
#  'Q2815701': 'Jing',
#  'Q2904003': 'binzasara',
#  'Q2964066': 'Q2964066',
#  'Q3051404': 'Kokiriko',
#  'Q3069712': 'Ferrinho',
#  'Q3075428': 'Ocean drum',
#  'Q3089272': 'frottoir',
#  'Q3177916': 'Keyboard glockenspiel',
#  'Q3216262': 'tam-tam',
#  'Q3286003': 'manjira',
#  'Q4073152': 'Ahoko',
#  'Q4201135': 'calung',
#  'Q4203025': 'blaidyn  retar',
#  'Q4260715': 'Slentem',
#  'Q4422479': 'Skrabalai',
#  'Q4508644': 'Q4508644',
#  'Q4748495': 'amplified cactus',
#  'Q4804279': 'cántaro',
#  'Q4835508': 'BElls',
#  'Q4837771': 'babendil',
#  'Q4869261': 'batih',
#  'Q4883310': 'bell cymbal',
#  'Q4885547': 'ranat ek lek',
#  'Q4924951': 'khong wong yai',
#  'Q4925415': 'khong wong lek',
#  'Q4926117': 'ranat thum lek',
#  'Q4928618': 'blown idiophones',
#  'Q4936269': 'Bock-a-da-bock',
#  'Q4965824': 'Briazkalnytsia',
#  'Q4997651': 'Bungkaka',
#  'Q5018028': 'Cajón de rumba',
#  'Q5018032': 'Cajón de tapeo',
#  'Q5091360': 'chengila',
#  'Q5118643': 'Chácaras',
#  'Q5269026': 'Dhantal',
#  'Q5280486': 'idiófono golpeado',
#  'Q5503427': 'friction idiophones',
#  'Q5520758': 'Gandingan a Kayo',
#  'Q5567120': 'glass marimba',
#  'Q5567145': 'Glasschord',
#  'Q5571121': 'Glock-guitar',
#  'Q5616867': 'Guitarra de canya',
#  'Q5960459': 'Paiban',
#  'Q6368868': 'Karawasi',
#  'Q6415165': 'Kirikoketa',
#  'Q6443033': 'Kulintang a kayo',
#  'Q6443034': 'Kulintang a tiniok',
#  'Q6585154': 'ranat thum',
#  'Q6585156': 'ranat ek',
#  'Q6585157': 'ranat kaeo',
#  'Q6667913': 'Loh tarang',
#  'Q6701540': 'Lujon',
#  'Q6704467': 'luntang',
#  'Q6845269': 'Mihbaj',
#  'Q7079990': 'Ogene',
#  'Q7095084': 'Onugadu',
#  'Q7189851': 'Phách',
#  'Q7191300': 'Pidkova',
#  'Q7199741': 'Pixiphone',
#  'Q7207611': 'Pogo cello',
#  'Q7296331': 'Ravanne',
#  'Q7561075': 'Song bells',
#  'Q7561115': 'Song loan',
#  'Q7619070': 'Stone marimba',
#  'Q7666172': 'sênh tiền',
#  'Q7667735': "t'rưng",
#  'Q7826219': 'Torokhkatalo',
#  'Q7837932': 'Trejdeksnis',
#  'Q7852942': 'Tuned bottles',
#  'Q7877832': 'Ugly stick',
#  'Q8015157': 'Slento',
#  'Q9007999': 'Ilimba',
#  'Q9067389': 'Redoba',
#  'Q11859952': 'Caxirola',
#  'Q12010762': 'Wobble board',
#  'Q12273079': 'bell tree',
#  'Q12620014': 'chuk',
#  'Q13062980': 'kyizi',
#  'Q16257797': 'Marimbol',
#  'Q16632086': 'musical anvil',
#  'Q16875619': 'chap',
#  'Q16878852': 'gyile',
#  'Q16885385': 'Katsa (instrument)',
#  'Q16891573': 'ulla',
#  'Q16908447': 'Jhyamta',
#  'Q20106138': 'Q20106138',
#  'Q21789767': 'Q21789767',
#  'Q55722920': 'metal sheets',
#  'Q55722940': 'flexed diaphragms',
#  'Q55738956': 'electro-acoustic idiophones',
#  'Q57592280': 'jauram',
#  'Q66124118': 'stone harp',
#  'Q6010': 'rapping',
#  'Q27939': 'canto',
#  'Q41923': 'yodel',
#  'Q127624': 'White voice',
#  'Q579955': 'Regueifa',
#  'Q600094': 'peán',
#  'Q820922': 'Salmodia',
#  'Q1436228': 'Gwerz',
#  'Q1477153': 'Musica reservata',
#  'Q1497328': 'sign singing',
#  'Q1500983': 'Sprechgesang',
#  'Q1553339': 'cántico',
#  'Q1567963': 'sing-along',
#  'Q2222716': 'Q2222716',
#  'Q2706051': 'Q2706051',
#  'Q2956219': 'Canto amobeo',
#  'Q2956237': 'canto lírico',
#  'Q2956242': 'Q2956242',
#  'Q2956246': 'Canto mozárabe',
#  'Q3655696': 'cante flamenco',
#  'Q3655812': 'singing in ancient Rome',
#  'Q3924081': 'prosodion',
#  'Q3976062': 'strina',
#  'Q3981262': 'Tasgia',
#  'Q5249313': 'declamación',
#  'Q6781835': 'marzas',
#  'Q10394634': 'Yimakan',
#  'Q12057308': 'Q12057308',
#  'Q12336368': 'solo singing',
#  'Q15990884': 'cantillation',
#  'Q18822510': 'jazz singing',
#  'Q19973796': 'Q19973796',
#  'Q25616123': 'Q25616123',
#  'Q66098673': 'vocal effect',
#  'Q79054127': 'Kengë Malsorqe',
#  'Q34379': 'instrumento musical',
#  'Q52954': 'teclado',
#  'Q105738': 'electrófono',
#  'Q133163': 'instrumento de percusión',
#  'Q212892': 'membranófono',
#  'Q217306': 'instrumento transpositor',
#  'Q230062': 'Q230062',
#  'Q245519': '6-plus-6-instruments',
#  'Q258681': 'platerspiel',
#  'Q334606': 'practice instrument',
#  'Q356923': 'Adiaphone',
#  'Q365289': 'Pyrophone',
#  'Q386382': 'tympanum',
#  'Q391640': 'Sintetizador modular',
#  'Q424111': 'acoustic musical instrument',
#  'Q431585': 'rawap',
#  'Q432358': 'Shak-shak',
#  'Q471918': 'Pong lang',
#  'Q487818': 'shruti box',
#  'Q492055': 'octavina',
#  'Q513996': 'Caisa',
#  'Q530209': 'atenteben',
#  'Q541464': 'Corneta china',
#  'Q545271': 'tikitiri',
#  'Q550596': 'Vocaloid',
#  'Q619351': 'Apollonicon',
#  'Q623168': 'Tantan',
#  'Q654117': 'Mesa de mezclas de audio',
#  'Q659216': 'aerófono',
#  'Q679771': 'Klaxophone',
#  'Q695269': 'bamboo musical instrument',
#  'Q698590': 'arpa doppia',
#  'Q698593': 'Arpa de dos órdenes',
#  'Q704687': 'sogeum',
#  'Q713574': 'Violonchelo eléctrico',
#  'Q715223': 'sound module',
#  'Q735008': 'jiegu',
#  'Q758885': 'Q758885',
#  'Q810447': 'bajo',
#  'Q810545': 'Bass pedals',
#  'Q816031': 'Belloneon',
#  'Q816656': 'Q816656',
#  'Q825246': 'Sorna',
#  'Q859091': 'Ghatam',
#  'Q889113': 'Bock',
#  'Q890731': 'boha',
#  'Q893045': 'Boomwhacker',
#  'Q895007': 'Bougarabou',
#  'Q911724': 'Pandura',
#  'Q924514': 'cimboa',
#  'Q952980': 'Pku',
#  'Q956339': 'Walpipe',
#  'Q977922': 'Orquestrión',
#  'Q1051772': 'cordófono',
#  'Q1052089': 'Caña Rociera',
#  'Q1071649': 'instrumentos musicales tradicionales de Japón',
#  'Q1099050': 'Clavicylinder',
#  'Q1134224': 'Q1134224',
#  'Q1158854': 'Calíope (instrumento)',
#  'Q1243790': 'Dord',
#  'Q1282828': 'gumbass',
#  'Q1295894': 'Q1295894',
#  'Q1328586': 'Q1328586',
#  'Q1381282': 'signal instrument',
#  'Q1434775': 'musical clock',
#  'Q1493069': 'Gamelán gong kebyar',
#  'Q1493856': 'Electroteremín',
#  'Q1554749': 'Q1554749',
#  'Q1559267': 'instrumento musical mecánico',
#  'Q1585780': 'Sasando',
#  'Q1632523': 'Q1632523',
#  'Q1756773': 'Fue',
#  'Q1759467': 'Koyabu Symmetric Board',
#  'Q1791240': 'Kuhlohorn',
#  'Q1829398': 'alto trombone',
#  'Q2002523': 'Q2002523',
#  'Q2030249': 'Vielle organisée',
#  'Q2048167': 'palmas flamencas',
#  'Q2125979': 'Q2125979',
#  'Q2171311': 'Flumpet',
#  'Q2195783': 'Viola organista',
#  'Q2215175': 'Salo (instrument)',
#  'Q2229742': 'Sosso-Bala',
#  'Q2305258': 'tulum',
#  'Q2310383': 'toy instrument',
#  'Q2313828': 'Gaita',
#  'Q2361629': 'Subharchord',
#  'Q2374764': 'Symphonium',
#  'Q2382928': 'T´bol',
#  'Q2386534': 'tabla tarang',
#  'Q2390872': 'Q2390872',
#  'Q2399657': 'Q2399657',
#  'Q2419480': 'Theremin cello',
#  'Q2452218': 'karnay',
#  'Q2453802': 'Triola',
#  'Q2473977': 'Reactable',
#  'Q2510552': 'Nagara',
#  'Q2511482': 'Brinquinho',
#  'Q2529757': 'vocal',
#  'Q2532441': 'Q2532441',
#  'Q2540826': 'Kafir harp',
#  'Q2551648': 'Cataquí',
#  'Q2564890': 'Q2564890',
#  'Q2646434': 'algaita',
#  'Q2724498': 'ravanahatha',
#  'Q2746062': 'ghungroo',
#  'Q2755228': 'tenor banjo',
#  'Q2827710': 'Q2827710',
#  'Q2858170': 'Apertintaille',
#  'Q2879595': 'Kauaha',
#  'Q2887846': 'Gaita cabreiresa',
#  'Q2895785': 'Kabosy',
#  'Q2900642': 'Bhankora',
#  'Q2902353': 'Romantic guitar',
#  'Q2902424': 'Bigophone',
#  'Q2912399': 'santoor',
#  'Q2917420': 'Belembaotuyan',
#  'Q2958769': 'Q2958769',
#  'Q3009831': 'cécilium',
#  'Q3040117': 'Zendrum',
#  'Q3058452': 'pipasso',
#  'Q3061445': 'Ever büree',
#  'Q3122611': 'gyil',
#  'Q3127531': 'Harmoniflûte',
#  'Q3142190': 'huéhuetl',
#  'Q3143699': 'hydraulophone',
#  'Q3152884': 'Q3152884',
#  'Q3153674': 'Intonarumori',
#  'Q3181140': 'Rebana',
#  'Q3190079': 'Junjung',
#  'Q3194590': 'Kebero',
#  'Q3200735': 'kuzhal',
#  'Q3209207': 'Akan Drum',
#  'Q3299336': 'Mazhar',
#  'Q3300302': 'Mirwas',
#  'Q3339215': 'Ney-anbān',
#  'Q3346567': 'Akete',
#  'Q3395204': 'Aburukuwa',
#  'Q3408860': 'Chitarra Italiana',
#  'Q3415911': 'rabel',
#  'Q3416144': 'malunga',
#  'Q3418321': 'ralé-poussé',
#  'Q3480678': 'setor',
#  'Q3481213': 'shahi baaja',
#  'Q3482784': 'shōko',
#  'Q3495190': 'sringa',
#  'Q3509664': 'Gudugudu',
#  'Q3514627': "tamak'",
#  'Q3515769': 'tarol',
#  'Q3538954': 'Q3538954',
#  'Q3541635': 'Tsugaru-jamisen',
#  'Q3559944': 'tambouras',
#  'Q3623161': 'Harmonizer',
#  'Q3624466': 'Mazanki',
#  'Q3631657': 'aṣíkò',
#  'Q3636149': 'Q3636149',
#  'Q3636159': 'Q3636159',
#  'Q3659427': 'volynka',
#  'Q3662051': 'Q3662051',
#  'Q3675133': 'Q3675133',
#  'Q3675208': 'Q3675208',
#  'Q3675209': 'Q3675209',
#  'Q3728958': 'Pepa',
#  'Q3753343': 'Q3753343',
#  'Q3785746': 'Detuner',
#  'Q3809543': 'Q3809543',
#  'Q3868722': 'Q3868722',
#  'Q3901246': 'phagotum',
#  'Q3913027': 'Gogona',
#  'Q3955010': 'Q3955010',
#  'Q3961834': 'singing arc',
#  'Q3964959': 'sopila',
#  'Q3973375': 'Q3973375',
#  'Q3977133': 'Q3977133',
#  'Q3979125': 'Synare',
#  'Q3980595': 'Tamburello',
#  'Q3980611': 'marching percussion instrument',
#  'Q3992030': 'Tlapitzalli',
#  'Q3999196': 'Q3999196',
#  'Q4009015': 'Q4009015',
#  'Q4019221': 'whamola',
#  'Q4058045': 'Adyrna',
#  'Q4097743': 'Buhay',
#  'Q4160615': 'Cura nagara',
#  'Q4179783': 'jetigen',
#  'Q4180005': 'taraban',
#  'Q4207259': 'tungso',
#  'Q4217223': 'saenghwang',
#  'Q4244156': 'Q4244156',
#  'Q4306652': 'instrumento musical del Barroco',
#  'Q4358503': 'igba',
#  'Q4371818': 'Phondar',
#  'Q4384972': 'pkhachich',
#  'Q4399245': 'rud',
#  'Q4447851': 'sybyzgy',
#  'Q4470335': 'Ukeke',
#  'Q4524679': 'shichepshin',
#  'Q4644330': '80-string koto',
#  'Q4667250': 'ranat',
#  'Q4683217': "Adjutant's Call",
#  'Q4687908': 'Aeotana',
#  'Q4697540': 'Ainu fiddle',
#  'Q4699678': 'Ajayu',
#  'Q4734668': 'Alounloun',
#  'Q4739172': 'amakondere',
#  'Q4745429': 'American bass viol',
#  'Q4751792': 'Anasazi flute',
#  'Q4778966': 'Apache fiddle',
#  'Q4783433': 'Arabic musical instruments',
#  'Q4784605': 'arbajo',
#  'Q4807598': 'Asor',
#  'Q4812665': 'dilli kaval',
#  'Q4818209': 'Attention',
#  'Q4833134': 'Azusayumi',
#  'Q4839758': 'Backsticking',
#  'Q4842576': 'Bahian guitar',
#  'Q4855834': 'banjeaurine',
#  'Q4858007': 'bara',
#  'Q4876234': 'Beamz',
#  'Q4904776': 'Bifora',
#  'Q4906756': 'Big piano',
#  'Q4936748': 'Bodu beru',
#  'Q4937543': 'Bogdon Box Bass',
#  'Q4939982': 'bolombatto',
#  'Q4943384': 'boom-ba',
#  'Q4971783': 'bro',
#  'Q4986985': 'bukkehorn',
#  'Q4989127': 'tambur',
#  'Q5000938': 'Burton grip',
#  'Q5021684': 'Call to Quarters',
#  'Q5037685': 'Caramusa',
#  'Q5039581': 'carimba',
#  'Q5057403': 'cekuntrung',
#  'Q5065645': 'ceterone',
#  'Q5066401': 'chadagan',
#  'Q5073927': 'Charangon',
#  'Q5094876': 'Chhepchher',
#  'Q5097384': 'chikara',
#  'Q5104748': 'choor',
#  'Q5116565': 'Church Call',
#  'Q5129638': 'Claviola',
#  'Q5150931': 'Combo organ',
#  'Q5171897': 'cornstalk fiddle',
#  'Q5188204': 'Cross-stringing',
#  'Q5189202': 'crowdy-crawn',
#  'Q5193091': 'Culoepuya',
#  'Q5195473': 'Matófono',
#  'Q5199417': 'Cymbal choke',
#  'Q5202987': 'cảnh',
#  'Q5227697': 'datong',
#  'Q5252609': 'Karinding',
#  'Q5268580': 'deze',
#  'Q5268673': 'Dhadd',
#  'Q5268703': 'dhak',
#  'Q5269692': 'Dhol',
#  'Q5284584': 'division viol',
#  'Q5299971': 'Bombardino de doble campana',
#  'Q5309083': 'Drum charts',
#  'Q5311266': 'ducheke',
#  'Q5311633': 'duda',
#  'Q5312527': 'Duggi',
#  'Q5312626': 'Duhulla',
#  'Q5321271': 'dūdas',
#  'Q5325306': 'eagle bone whistle',
#  'Q5350462': 'ekkalam',
#  'Q5357606': 'electric grand piano',
#  'Q5357961': 'electrocardiophone',
#  'Q5359741': 'Guitarra alta de once cuerdas',
#  'Q5365913': 'sohaegeum',
#  'Q5389067': 'erikundi',
#  'Q5401002': 'esterilla',
#  'Q5421167': 'instrumento musical experimental',
#  'Q5446820': 'fidola',
#  'Q5454461': 'Fish-drum',
#  'Q5465744': 'foot drum',
#  'Q5466463': 'footed drum',
#  'Q5511031': 'Fuzz-wah',
#  'Q5516807': 'Gagar',
#  'Q5518524': 'galgo',
#  'Q5520015': 'Gamelan gong gede',
#  'Q5520022': 'Gamelan semar pegulingan',
#  'Q5520755': 'gandingan',
#  'Q5528996': 'gazamba',
#  'Q5529320': 'Gbedu',
#  'Q5555723': 'Gharha',
#  'Q5577129': 'Goema',
#  'Q5577965': 'Goje',
#  'Q5577967': 'gojinjo-daiko',
#  'Q5581804': 'Gonguê',
#  'Q5599360': 'Great Irish Warpipes',
#  'Q5614420': 'guban',
#  'Q5614726': 'Gue',
#  'Q5616828': 'Guitar fiddle',
#  'Q5616864': 'Guitarra de golpe',
#  'Q5616871': 'Guitarra panzona',
#  'Q5616873': 'Guitarra séptima',
#  'Q5616880': 'Guitarrón argentino',
#  'Q5618064': 'gumbe',
#  'Q5636660': 'habbān',
#  'Q5640442': 'hakgediya',
#  'Q5647100': 'hand-repique',
#  'Q5647435': 'Baby bass',
#  'Q5669631': 'Torompe',
#  'Q5669795': 'Almirez',
#  'Q5672149': 'Q5672149',
#  'Q5676660': 'Escaque',
#  'Q5682233': 'hatun charango',
#  'Q5686093': 'Hio',
#  'Q5691425': 'Q5691425',
#  'Q5692465': 'Q5692465',
#  'Q5708319': 'Q5708319',
#  'Q5714725': 'Ayotl',
#  'Q5739373': 'Caja (instrumento musical andino)',
#  'Q5739510': 'Cajita rítmica afroperuana',
#  'Q5748186': 'Capador',
#  'Q5755977': 'Cascahuilla',
#  'Q5765399': 'Checo (percusión)',
#  'Q5766417': 'Chililitli',
#  'Q5769609': 'Divan',
#  'Q5784662': 'Pandero jarocho',
#  'Q5807311': 'Dinarra',
#  'Q5851173': 'Pat waing',
#  'Q5875501': 'Garrahand',
#  'Q5887436': 'Guataca',
#  'Q5891381': 'Halam',
#  'Q5910397': 'Q5910397',
#  'Q5989356': 'Madiumba',
#  'Q5989502': 'Maea',
#  'Q5998237': 'Ilimba drum',
#  'Q6004656': 'Q6004656',
#  'Q6053421': 'Hegit',
#  'Q6074814': 'Piano (tambor)',
#  'Q6105823': 'Repique (tambor)',
#  'Q6116662': 'Sachaguitarra',
#  'Q6138473': 'Tambor alegre',
#  'Q6138475': 'Tambor cilíndrico de dos membranas',
#  'Q6138488': 'Tambora panameña',
#  'Q6140170': 'Tecomapiloa',
#  'Q6159663': 'Varelina',
#  'Q6169915': 'Yelatáj chos woley',
#  'Q6172796': 'Jedinka',
#  'Q6174597': 'Ñolkin',
#  'Q6191226': 'Jhyali',
#  'Q6191895': 'jiaohu',
#  'Q6202344': 'Sonaja (instrumento musical)',
#  'Q6312746': 'Junggeum',
#  'Q6322455': "k'lông pút",
#  'Q6322465': "k'ni",
#  'Q6343712': 'Kaba gaida',
#  'Q6354593': 'kalumbu',
#  'Q6371338': 'karkm',
#  'Q6373847': 'Karyenda',
#  'Q6374198': 'Kashaka',
#  'Q6377724': 'Kato',
#  'Q6379590': 'kawala',
#  'Q6382446': 'kecer',
#  'Q6398221': 'keyboard bass',
#  'Q6402245': 'khong mon',
#  'Q6402253': 'khonkhota',
#  'Q6403208': 'khushtar',
#  'Q6404050': 'Kiboe',
#  'Q6411198': 'King 3B',
#  'Q6429164': 'kong thom',
#  'Q6429165': 'kong toch',
#  'Q6430350': 'Kontigi',
#  'Q6432225': 'Korg Mini Pops',
#  'Q6435771': 'krachap pi',
#  'Q6436666': 'Krekhts',
#  'Q6436675': 'krem',
#  'Q6441262': 'kubing',
#  'Q6442289': 'Gaita colombiana',
#  'Q6442505': 'kukkuma',
#  'Q6442967': 'kulibit',
#  'Q6453652': 'kèn',
#  'Q6453655': 'Kèn đám ma',
#  'Q6461940': 'lingm',
#  'Q6462789': 'Q6462789',
#  'Q6472082': 'Laggutu',
#  'Q6491889': 'laruan',
#  'Q6508789': 'Leadpipe',
#  'Q6532301': 'Ardin (instrumento musical)',
#  'Q6586195': 'thon and rammana',
#  'Q7672803': 'taal',
#  'Q7673920': 'tack piano',
#  'Q7674568': 'tadghtita',
#  'Q7678546': 'Takuapu',
#  'Q7679165': 'talempong',
#  'Q7681055': 'Tambora de gaita',
#  'Q7681062': 'Tamborita calentana',
#  'Q7683067': 'tangmuri',
#  'Q7685353': 'taralila',
#  'Q7687617': 'Tassa',
#  'Q7690562': 'Tbilat',
#  'Q7698121': 'temir komuz',
#  'Q7700564': 'Tenor cornett',
#  'Q7707025': 'Tetzilacatl',
#  'Q7710699': 'Thappu',
#  'Q7725623': 'Gudastviri',
#  'Q7801775': 'tihu',
#  'Q7804752': 'Timbrel',
#  'Q7808741': 'Tiorbino',
#  'Q7808838': 'Tiple doliente',
#  'Q7810254': 'titti',
#  'Q7811975': 'Tochacatl',
#  'Q7813451': 'toka',
#  'Q7814483': 'Tololoche',
#  'Q7830966': 'tozacatl',
#  'Q7841293': 'Tricordia',
#  'Q7843503': 'triple contrabass viol',
#  'Q7844785': 'tro',
#  'Q7844787': 'tro sau thom',
#  'Q7844788': 'Tro Khmer',
#  'Q7844789': 'tro sau toch',
#  'Q7844791': 'tro u',
#  'Q7849269': 'trống chầu',
#  'Q7849271': 'trống cái',
#  'Q7849273': 'trống cơm',
#  'Q7849749': 'tsintsila',
#  'Q7851703': 'tuhu',
#  'Q7852608': "tumdak'",
#  'Q7852690': 'tumpong',
#  'Q7857859': 'twi ba',
#  'Q7876892': 'Udaka vadya',
#  'Q7878283': 'ukelin',
#  'Q7901528': 'Urumee',
#  'Q7928364': 'Vienna valve trombone',
#  'Q7933010': 'viola de buriti',
#  'Q7961299': 'Walaycho',
#  'Q7976961': 'wazza',
#  'Q8045285': 'Xutuli',
#  'Q8046046': 'YTR-2320',
#  'Q8047056': 'yakatat',
#  'Q8047761': 'Yamaha SY22',
#  'Q8048103': 'Yamudi',
#  'Q8070483': 'zhangu',
#  'Q8075090': 'zukra',
#  'Q8075256': 'Zummarah-bi-soan',
#  'Q8079916': 'đàn goong',
#  'Q8079917': 'đàn hồ',
#  'Q8079921': 'đàn sến',
#  'Q8204672': 'Armonio de fuelle manual',
#  'Q8353519': 'Damphu',
#  'Q9001426': 'Guitarra latina',
#  'Q9022704': 'Lincolnshire bagpipes',
#  'Q9065175': 'Quenacho',
#  'Q9081684': 'Tambores de barro prehispánicos',
#  'Q9182138': 'Q9182138',
#  'Q9212830': 'Dudka',
#  'Q9419091': 'liujiaoxian',
#  'Q9659186': 'tiexianzai',
#  'Q10269821': 'ESP Tom Araya',
#  'Q10306950': 'jirba',
#  'Q10314435': 'Kisanji',
#  'Q10353206': 'Prato-e-faca',
#  'Q10369682': 'kezaixian',
#  'Q10403797': 'tromba egiziana',
#  'Q10431752': 'Swedish cowhorn',
#  'Q10431758': 'Q10431758',
#  'Q10753171': 'Venu',
#  'Q10783013': 'kèn lá',
#  'Q10783687': "kềnh H'Mông",
#  'Q10822595': "sáo H'Mông",
#  'Q10840083': 'đing năm',
#  'Q10840437': 'đàn đáy',
#  'Q10861374': 'Q10861374',
#  'Q10892404': 'bajiao gu',
#  'Q11075759': 'shougu',
#  'Q11092881': 'muye',
#  'Q11098361': 'Traditional Vietnamese musical instruments',
#  'Q11215782': 'Q11215782',
#  'Q11341612': 'mandolone',
#  'Q11498653': 'atarigane',
#  'Q11650198': 'luo',
#  'Q11682277': 'Guitarra huapanguera',
#  'Q11829254': 'resheto',
#  'Q11910152': 'Q11910152',
#  'Q11911068': 'Q11911068',
#  'Q11920628': 'Q11920628',
#  'Q11939060': 'Nunun',
#  'Q11946334': 'Q11946334',
#  'Q11953199': 'Q11953199',
#  'Q11954880': 'Violí de bufa',
#  'Q6653370': 'litungu',
#  'Q6654102': 'Liuto cantabile',
#  'Q6668722': 'lokole',
#  'Q6710917': 'låtfiol',
#  'Q6718658': 'Sataer',
#  'Q6723506': 'machete',
#  'Q6732512': 'maguhu',
#  'Q6740488': 'Makuta',
#  'Q6748128': 'mandobass',
#  'Q6749152': 'mangtong',
#  'Q6749173': 'manguerito',
#  'Q6750463': 'manjur',
#  'Q6754723': 'maram',
#  'Q6759026': 'marfa',
#  'Q6772421': 'marovany',
#  'Q6782415': 'Masak baja',
#  'Q6783062': 'mashak',
#  'Q6797579': 'Mayohuacan',
#  'Q6815777': 'Memotron',
#  'Q6862658': 'Mina',
#  'Q6864712': 'minggah',
#  'Q6875024': 'Misa Kitara',
#  'Q6932203': 'mugni',
#  'Q6936014': 'Munggang',
#  'Q6943773': 'Mute cornett',
#  'Q6951309': 'Novike',
#  'Q6960304': 'Nakara',
#  'Q7047745': 'Noisemaker',
#  'Q7064485': 'Novation DrumStation',
#  'Q7071063': 'nyele',
#  'Q7071407': 'näverlapp',
#  'Q7075256': 'obokano',
#  'Q7075353': 'obrom',
#  'Q7076774': 'Octave glissando',
#  'Q7083206': 'yazh',
#  'Q7090062': 'Omele',
#  'Q7090795': 'omukuli',
#  'Q7095385': 'Oopoochawa',
#  'Q7101770': 'Organ crawl',
#  'Q7101775': 'Organ flue pipe scaling',
#  'Q7103992': 'Orpheus Winds',
#  'Q7108528': 'Oterfløyte',
#  'Q7120230': 'PQube',
#  'Q7123295': 'Padayani thappu',
#  'Q7129321': 'Pamiri rubab',
#  'Q7130187': 'Pancai baja',
#  'Q7143055': 'Pastoral pipes',
#  'Q7186113': 'Philomel',
#  'Q7198298': 'Pisha',
#  'Q7201800': 'plasmaphone',
#  'Q7205095': 'ploong',
#  'Q7265233': 'pūtātara',
#  'Q7269255': 'Quarter bells',
#  'Q7269501': 'Quasimidi Sirius',
#  'Q7271943': 'Quijongo',
#  'Q7272401': 'quintephone',
#  'Q7272469': 'Quintola',
#  'Q7281253': 'radiodrum',
#  'Q7303480': 'Boyuk nagara',
#  'Q7314870': 'Requinto jarocho',
#  'Q7320165': 'rhaita',
#  'Q7334676': 'ring-repique',
#  'Q7360333': 'Roland MS-1 Digital Sampler',
#  'Q7361386': 'rolmo',
#  'Q7365591': 'roneat dek',
#  'Q7365593': 'roneat ek',
#  'Q7379154': 'quinto',
#  'Q7403597': 'Salamiyyah',
#  'Q7404961': 'sallaneh',
#  'Q7406098': 'Salterio mexicano',
#  'Q7408984': 'Sambal',
#  'Q7410180': 'samponha',
#  'Q7418239': 'sanhu',
#  'Q7418340': 'Sanj',
#  'Q7421024': 'Sapp',
#  'Q7426334': 'sato',
#  'Q7428594': 'Sawat saxophone',
#  'Q7428890': 'Saxtuba',
#  'Q7462274': 'Shahrud',
#  'Q7502339': 'Shoshannim',
#  'Q7505701': 'Shuttle Pipes',
#  'Q7506038': 'Shyuvr',
#  'Q7513987': 'sikulu',
#  'Q7515478': 'silnyen',
#  'Q7531816': 'siter',
#  'Q7533633': 'Sjøfløyte',
#  'Q7555423': 'soku',
#  'Q7564023': 'Sotone',
#  'Q7564871': 'sounding stone',
#  'Q7572372': 'Space Harp',
#  'Q7586583': 'sruti upanga',
#  'Q7623972': 'String change',
#  'Q7623984': 'String noise',
#  'Q7630969': 'subcontrabass tuba',
#  'Q7636250': 'sulibao',
#  'Q7638092': 'sumui',
#  'Q7639273': 'Sundari',
#  'Q7652693': 'Svilpa',
#  'Q7661404': 'sinfonía',
#  'Q7664811': 'Szopelka',
#  'Q18449487': 'Q18449487',
#  'Q18627458': 'Botet',
#  'Q19671148': 'karnal',
#  'Q19856213': 'hulusheng',
#  'Q19895199': 'Pena',
#  'Q19899453': 'Udukku',
#  'Q20009773': 'Q20009773',
#  'Q20103041': 'Rabequet',
#  'Q20103238': 'Rigo-rago',
#  'Q20104603': 'Gall-gallet',
#  'Q20104853': 'Q20104853',
#  'Q20106313': 'Q20106313',
#  'Q20106353': 'Q20106353',
#  'Q20106964': 'Q20106964',
#  'Q20523954': 'Orff instruments',
#  'Q20585538': 'Saron panerus',
#  'Q20826903': 'Q20826903',
#  'Q20854933': 'Fontomfrom',
#  'Q20967773': 'tide organ',
#  'Q21080967': 'aak instrument',
#  'Q21081475': 'Q21081475',
#  'Q21087040': 'Q21087040',
#  'Q21087453': 'Q21087453',
#  'Q25093046': 'Engalabi',
#  'Q25101248': 'Guitaro',
#  'Q25226698': 'Ground bow',
#  'Q25348503': 'Multi-course harp',
#  'Q25395631': 'Q25395631',
#  'Q25399492': 'Q25399492',
#  'Q25412985': 'Guache',
#  'Q25472791': 'Q25472791',
#  'Q25644178': 'Kendara',
#  'Q25680583': 'Sneng',
#  'Q27027147': 'Q27027147',
#  'Q27181298': 'Qoltuq nagara',
#  'Q27510104': 'Q27510104',
#  'Q27513249': 'Q27513249',
#  'Q28137123': 'Cythara',
#  'Q28148538': 'Pito rociero',
#  'Q28170750': 'Q28170750',
#  'Q28171515': 'Q28171515',
#  'Q28192975': 'Q28192975',
#  'Q28219771': 'Guayo',
#  'Q28403542': 'Riddle drum',
#  'Q28452681': 'Stamna',
#  'Q28692811': 'nigenkin',
#  'Q28710739': 'Q28710739',
#  'Q28737179': 'Q28737179',
#  'Q29017799': 'Chiboni',
#  'Q29277213': 'Q29277213',
#  'Q29301219': 'Q29301219',
#  'Q30034571': 'pūtōrino',
#  'Q30324270': 'Oudola',
#  'Q30347637': 'Tembong',
#  'Q30347664': 'Q30347664',
#  'Q31842594': 'Q31842594',
#  'Q34379956': 'Q34379956',
#  'Q37681691': 'Vadya',
#  'Q39056298': 'Ahardin',
#  'Q40447270': 'Bendré',
#  'Q40447413': 'bofu',
#  'Q40448318': 'Bérenté',
#  'Q43079402': 'Catá',
#  'Q44254442': 'Sonorophone',
#  'Q44254482': 'Piyapi',
#  'Q44254502': 'Lawle',
#  'Q44254550': 'Windbell',
#  'Q44254585': 'Embilta',
#  'Q44254611': 'Pong',
#  'Q44254669': 'Kodokan',
#  'Q44254678': 'Vipanci vina',
#  'Q44254733': 'Pattung',
#  'Q45753024': 'Geger',
#  'Q46996061': 'contrabass trombone',
#  'Q46996068': 'Q46996068',
#  'Q48817576': 'Hydraulis of Dion',
#  'Q49184007': 'Musical instruments of Sardinia',
#  'Q50329237': 'Affuente',
#  'Q50331514': "Tumbarinu 'e Gavoi",
#  'Q51846072': 'Q51846072',
#  'Q52987174': 'Janzi',
#  'Q55568438': 'outstanding instrument',
#  'Q55738523': 'deflagration instruments',
#  'Q56062174': 'Q56062174',
#  'Q56062175': 'Q56062175',
#  'Q56196958': 'tifa dasar',
#  'Q56196959': 'Q56196959',
#  'Q56196961': 'Q56196961',
#  'Q56196962': 'Q56196962',
#  'Q56251798': 'Q56251798',
#  'Q56251800': 'Q56251800',
#  'Q56251803': 'Q56251803',
#  'Q56251805': 'Q56251805',
#  'Q56251806': 'oloi-olio',
#  'Q56276235': 'Clapper stick',
#  'Q56277888': 'Guitarra chamula',
#  'Q56401746': 'Q56401746',
#  'Q56476228': 'Luogu',
#  'Q56862947': 'improvised musical instrument',
#  'Q59419216': 'Kutiro',
#  'Q11955392': 'Q11955392',
#  'Q11990687': 'Fanfrnoch',
#  'Q12017895': 'Q12017895',
#  'Q12059669': 'Tritonikon',
#  'Q12233838': 'Gu',
#  'Q12483344': 'Q12483344',
#  'Q12483346': 'Q12483346',
#  'Q12484415': 'Q12484415',
#  'Q12485397': 'kutiyapi',
#  'Q12519046': 'Q12519046',
#  'Q12521411': 'Tifa',
#  'Q12791479': 'Q12791479',
#  'Q12863848': 'Q12863848',
#  'Q12885443': 'Toubeleki',
#  'Q12904608': 'kemane',
#  'Q12983208': 'Thattai',
#  'Q12987976': 'Murasu',
#  'Q13038039': 'Cula',
#  'Q13038049': 'Cyli',
#  'Q13096799': 'Saron barung',
#  'Q13135638': 'folk instrument',
#  'Q13408004': 'Riq',
#  'Q13636556': 'Q13636556',
#  'Q13656026': 'Oom-pah',
#  'Q14754685': 'Q14754685',
#  'Q15057905': 'Q15057905',
#  'Q15069864': 'niutuiqin',
#  'Q15210789': 'Fiðla',
#  'Q15212740': 'barítono',
#  'Q15220707': 'Q15220707',
#  'Q15717974': 'Chitra vina',
#  'Q15785425': 'Banam',
#  'Q15824524': 'Kse diev',
#  'Q15869380': 'Naqara',
#  'Q16133280': 'Q16133280',
#  'Q16205517': 'agiarut',
#  'Q16256860': 'Yanggeum',
#  'Q16304285': 'pi nai',
#  'Q16522042': 'Q16522042',
#  'Q16556212': 'Q16556212',
#  'Q16572861': 'Q16572861',
#  'Q16573450': 'Guitarrón uruguayo',
#  'Q16590872': 'Q16590872',
#  'Q16629274': 'Saz',
#  'Q16637700': 'Tambor llamador',
#  'Q16678513': 'Slavic musical instruments',
#  'Q16708063': 'kongahyan',
#  'Q16796308': 'Ngoma lungundu',
#  'Q16837506': 'bamboo clapper',
#  'Q16843539': 'Blues Bender',
#  'Q16892532': 'zhengni',
#  'Q16910195': 'paqin',
#  'Q16910872': 'Ninera',
#  'Q16911115': 'Organum (instrument)',
#  'Q16916457': 'Eeng',
#  'Q16917012': 'dapaqin',
#  'Q16918224': 'marching instrument',
#  'Q16918625': 'Khanjani',
#  'Q16919362': 'Hom',
#  'Q16928253': 'Tamboo bamboo',
#  'Q16928510': 'Kittle',
#  'Q16938266': 'khin',
#  'Q16938324': 'Sotto voce',
#  'Q16940786': 'huluqin',
#  'Q16965914': 'Naumati Baaja',
#  'Q16975813': 'Ilu',
#  'Q16976029': 'kalaleng',
#  'Q16977624': 'mangey',
#  'Q16999252': 'gourd mouth organ',
#  'Q17000154': 'lag-na',
#  'Q17012197': 'nevel',
#  'Q17025635': 'tiqin',
#  'Q17049229': 'GL-1 Guitalele',
#  'Q17055647': 'Xiqin',
#  'Q17061825': 'naobo',
#  'Q17062754': 'Korean barrel drum',
#  'Q17064573': 'tulum-zurna',
#  'Q17067314': 'bubon',
#  'Q17068242': 'pattala',
#  'Q17070015': 'Kus',
#  'Q17070147': 'Uruttu Chenda',
#  'Q17070215': 'Veekku Chenda',
#  'Q17082422': 'tar shehnai',
#  'Q17084554': 'tanbou',
#  'Q17085087': 'Rabeca',
#  'Q17086716': 'saw bang',
#  'Q17099062': 'Stabule',
#  'Q17105516': 'Found object',
#  'Q17117240': 'thongophone',
#  'Q17143535': 'Tahitian ukulele',
#  'Q17172850': 'voz',
#  'Q17189221': 'Q17189221',
#  'Q17591720': 'tocadiscos',
#  'Q18178803': 'Matraca',
#  'Q18224135': 'Maestrola',
#  'Q18350431': 'Huuchir',
#  'Q18377839': 'msondo',
#  'Q18379775': 'ndzumara',
#  'Q18391628': 'ndzendze',
#  'Q59480249': 'Baltic musical instruments',
#  ...}

# %%
subclase
# Out:
# {'Q11404': ['Q191464',
#   'Q208421',
#   'Q211028',
#   'Q221769',
#   'Q440856',
#   'Q520754',
#   'Q537750',
#   'Q811075',
#   'Q849349',
#   'Q1062015',
#   'Q1156506',
#   'Q1158124',
#   'Q1196937',
#   'Q1235547',
#   'Q1321939',
#   'Q1436500',
#   'Q1558889',
#   'Q1575231',
#   'Q2118356',
#   'Q2217018',
#   'Q2391458',
#   'Q2565221',
#   'Q2754430',
#   'Q3038392',
#   'Q3199707',
#   'Q3623050',
#   'Q4450903',
#   'Q4863624',
#   'Q4905606',
#   'Q5064156',
#   'Q5211919',
#   'Q6458439',
#   'Q7278496',
#   'Q7384685',
#   'Q7682928',
#   'Q7852753',
#   'Q10396699',
#   'Q10829913',
#   'Q11420300',
#   'Q11950748',
#   'Q12698682',
#   'Q12821705',
#   'Q13025534',
#   'Q14640031',
#   'Q15614634',
#   'Q28657984',
#   'Q28944914',
#   'Q60617211',
#   'Q60742599',
#   'Q80862258',
#   'Q101968884'],
#  'Q12639': ['Q129321',
#   'Q133722',
#   'Q339801',
#   'Q390110',
#   'Q398619',
#   'Q835684',
#   'Q859236',
#   'Q871633',
#   'Q936762',
#   'Q943438',
#   'Q963334',
#   'Q976406',
#   'Q978694',
#   'Q1014229',
#   'Q1043002',
#   'Q1050106',
#   'Q1075560',
#   'Q1195473',
#   'Q1196263',
#   'Q1252956',
#   'Q1371129',
#   'Q1394579',
#   'Q1401426',
#   'Q1414882',
#   'Q1514705',
#   'Q1537130',
#   'Q1540998',
#   'Q1743465',
#   'Q1790046',
#   'Q1842022',
#   'Q1968760',
#   'Q2118808',
#   'Q2280552',
#   'Q2553890',
#   'Q2574301',
#   'Q2628163',
#   'Q2640100',
#   'Q2698284',
#   'Q2815701',
#   'Q2904003',
#   'Q2964066',
#   'Q3051404',
#   'Q3069712',
#   'Q3075428',
#   'Q3089272',
#   'Q3177916',
#   'Q3216262',
#   'Q3286003',
#   'Q4073152',
#   'Q4201135',
#   'Q4203025',
#   'Q4260715',
#   'Q4422479',
#   'Q4508644',
#   'Q4748495',
#   'Q4804279',
#   'Q4835508',
#   'Q4837771',
#   'Q4869261',
#   'Q4883310',
#   'Q4885547',
#   'Q4924951',
#   'Q4925415',
#   'Q4926117',
#   'Q4928618',
#   'Q4936269',
#   'Q4965824',
#   'Q4997651',
#   'Q5018028',
#   'Q5018032',
#   'Q5091360',
#   'Q5118643',
#   'Q5269026',
#   'Q5280486',
#   'Q5503427',
#   'Q5520758',
#   'Q5567120',
#   'Q5567145',
#   'Q5571121',
#   'Q5616867',
#   'Q5960459',
#   'Q6368868',
#   'Q6415165',
#   'Q6443033',
#   'Q6443034',
#   'Q6585154',
#   'Q6585156',
#   'Q6585157',
#   'Q6667913',
#   'Q6701540',
#   'Q6704467',
#   'Q6845269',
#   'Q7079990',
#   'Q7095084',
#   'Q7189851',
#   'Q7191300',
#   'Q7199741',
#   'Q7207611',
#   'Q7296331',
#   'Q7561075',
#   'Q7561115',
#   'Q7619070',
#   'Q7666172',
#   'Q7667735',
#   'Q7826219',
#   'Q7837932',
#   'Q7852942',
#   'Q7877832',
#   'Q8015157',
#   'Q9007999',
#   'Q9067389',
#   'Q11859952',
#   'Q12010762',
#   'Q12273079',
#   'Q12620014',
#   'Q13062980',
#   'Q16257797',
#   'Q16632086',
#   'Q16875619',
#   'Q16878852',
#   'Q16885385',
#   'Q16891573',
#   'Q16908447',
#   'Q20106138',
#   'Q21789767',
#   'Q55722920',
#   'Q55722940',
#   'Q55738956',
#   'Q57592280',
#   'Q66124118'],
#  'Q27939': ['Q6010',
#   'Q41923',
#   'Q127624',
#   'Q579955',
#   'Q600094',
#   'Q820922',
#   'Q1436228',
#   'Q1477153',
#   'Q1497328',
#   'Q1500983',
#   'Q1553339',
#   'Q1567963',
#   'Q2222716',
#   'Q2706051',
#   'Q2956219',
#   'Q2956237',
#   'Q2956242',
#   'Q2956246',
#   'Q3655696',
#   'Q3655812',
#   'Q3924081',
#   'Q3976062',
#   'Q3981262',
#   'Q5249313',
#   'Q6781835',
#   'Q10394634',
#   'Q12057308',
#   'Q12336368',
#   'Q15990884',
#   'Q18822510',
#   'Q19973796',
#   'Q25616123',
#   'Q66098673',
#   'Q79054127'],
#  'Q34379': ['Q11404',
#   'Q12639',
#   'Q27939',
#   'Q52954',
#   'Q105738',
#   'Q133163',
#   'Q212892',
#   'Q217306',
#   'Q230062',
#   'Q245519',
#   'Q258681',
#   'Q334606',
#   'Q356923',
#   'Q365289',
#   'Q386382',
#   'Q391640',
#   'Q424111',
#   'Q431585',
#   'Q432358',
#   'Q471918',
#   'Q487818',
#   'Q492055',
#   'Q513996',
#   'Q530209',
#   'Q541464',
#   'Q545271',
#   'Q550596',
#   'Q619351',
#   'Q623168',
#   'Q654117',
#   'Q659216',
#   'Q679771',
#   'Q695269',
#   'Q698590',
#   'Q698593',
#   'Q704687',
#   'Q713574',
#   'Q715223',
#   'Q735008',
#   'Q758885',
#   'Q810447',
#   'Q810545',
#   'Q816031',
#   'Q816656',
#   'Q825246',
#   'Q859091',
#   'Q889113',
#   'Q890731',
#   'Q893045',
#   'Q895007',
#   'Q911724',
#   'Q924514',
#   'Q952980',
#   'Q956339',
#   'Q977922',
#   'Q1051772',
#   'Q1052089',
#   'Q1071649',
#   'Q1099050',
#   'Q1134224',
#   'Q1158854',
#   'Q1243790',
#   'Q1282828',
#   'Q1295894',
#   'Q1328586',
#   'Q1381282',
#   'Q1434775',
#   'Q1493069',
#   'Q1493856',
#   'Q1554749',
#   'Q1559267',
#   'Q1585780',
#   'Q1632523',
#   'Q1756773',
#   'Q1759467',
#   'Q1791240',
#   'Q1829398',
#   'Q2002523',
#   'Q2030249',
#   'Q2048167',
#   'Q2125979',
#   'Q2171311',
#   'Q2195783',
#   'Q2215175',
#   'Q2229742',
#   'Q2305258',
#   'Q2310383',
#   'Q2313828',
#   'Q2361629',
#   'Q2374764',
#   'Q2382928',
#   'Q2386534',
#   'Q2390872',
#   'Q2399657',
#   'Q2419480',
#   'Q2452218',
#   'Q2453802',
#   'Q2473977',
#   'Q2510552',
#   'Q2511482',
#   'Q2529757',
#   'Q2532441',
#   'Q2540826',
#   'Q2551648',
#   'Q2564890',
#   'Q2646434',
#   'Q2724498',
#   'Q2746062',
#   'Q2755228',
#   'Q2827710',
#   'Q2858170',
#   'Q2879595',
#   'Q2887846',
#   'Q2895785',
#   'Q2900642',
#   'Q2902353',
#   'Q2902424',
#   'Q2912399',
#   'Q2917420',
#   'Q2958769',
#   'Q3009831',
#   'Q3040117',
#   'Q3058452',
#   'Q3061445',
#   'Q3122611',
#   'Q3127531',
#   'Q3142190',
#   'Q3143699',
#   'Q3152884',
#   'Q3153674',
#   'Q3181140',
#   'Q3190079',
#   'Q3194590',
#   'Q3200735',
#   'Q3209207',
#   'Q3299336',
#   'Q3300302',
#   'Q3339215',
#   'Q3346567',
#   'Q3395204',
#   'Q3408860',
#   'Q3415911',
#   'Q3416144',
#   'Q3418321',
#   'Q3480678',
#   'Q3481213',
#   'Q3482784',
#   'Q3495190',
#   'Q3509664',
#   'Q3514627',
#   'Q3515769',
#   'Q3538954',
#   'Q3541635',
#   'Q3559944',
#   'Q3623161',
#   'Q3624466',
#   'Q3631657',
#   'Q3636149',
#   'Q3636159',
#   'Q3659427',
#   'Q3662051',
#   'Q3675133',
#   'Q3675208',
#   'Q3675209',
#   'Q3728958',
#   'Q3753343',
#   'Q3785746',
#   'Q3809543',
#   'Q3868722',
#   'Q3901246',
#   'Q3913027',
#   'Q3955010',
#   'Q3961834',
#   'Q3964959',
#   'Q3973375',
#   'Q3977133',
#   'Q3979125',
#   'Q3980595',
#   'Q3980611',
#   'Q3992030',
#   'Q3999196',
#   'Q4009015',
#   'Q4019221',
#   'Q4058045',
#   'Q4097743',
#   'Q4160615',
#   'Q4179783',
#   'Q4180005',
#   'Q4207259',
#   'Q4217223',
#   'Q4244156',
#   'Q4260715',
#   'Q4306652',
#   'Q4358503',
#   'Q4371818',
#   'Q4384972',
#   'Q4399245',
#   'Q4447851',
#   'Q4470335',
#   'Q4524679',
#   'Q4644330',
#   'Q4667250',
#   'Q4683217',
#   'Q4687908',
#   'Q4697540',
#   'Q4699678',
#   'Q4734668',
#   'Q4739172',
#   'Q4745429',
#   'Q4751792',
#   'Q4778966',
#   'Q4783433',
#   'Q4784605',
#   'Q4807598',
#   'Q4812665',
#   'Q4818209',
#   'Q4833134',
#   'Q4839758',
#   'Q4842576',
#   'Q4855834',
#   'Q4858007',
#   'Q4876234',
#   'Q4904776',
#   'Q4906756',
#   'Q4936748',
#   'Q4937543',
#   'Q4939982',
#   'Q4943384',
#   'Q4971783',
#   'Q4986985',
#   'Q4989127',
#   'Q5000938',
#   'Q5021684',
#   'Q5037685',
#   'Q5039581',
#   'Q5057403',
#   'Q5065645',
#   'Q5066401',
#   'Q5073927',
#   'Q5094876',
#   'Q5097384',
#   'Q5104748',
#   'Q5116565',
#   'Q5129638',
#   'Q5150931',
#   'Q5171897',
#   'Q5188204',
#   'Q5189202',
#   'Q5193091',
#   'Q5195473',
#   'Q5199417',
#   'Q5202987',
#   'Q5227697',
#   'Q5252609',
#   'Q5268580',
#   'Q5268673',
#   'Q5268703',
#   'Q5269692',
#   'Q5284584',
#   'Q5299971',
#   'Q5309083',
#   'Q5311266',
#   'Q5311633',
#   'Q5312527',
#   'Q5312626',
#   'Q5321271',
#   'Q5325306',
#   'Q5350462',
#   'Q5357606',
#   'Q5357961',
#   'Q5359741',
#   'Q5365913',
#   'Q5389067',
#   'Q5401002',
#   'Q5421167',
#   'Q5446820',
#   'Q5454461',
#   'Q5465744',
#   'Q5466463',
#   'Q5511031',
#   'Q5516807',
#   'Q5518524',
#   'Q5520015',
#   'Q5520022',
#   'Q5520755',
#   'Q5528996',
#   'Q5529320',
#   'Q5555723',
#   'Q5577129',
#   'Q5577965',
#   'Q5577967',
#   'Q5581804',
#   'Q5599360',
#   'Q5614420',
#   'Q5614726',
#   'Q5616828',
#   'Q5616864',
#   'Q5616871',
#   'Q5616873',
#   'Q5616880',
#   'Q5618064',
#   'Q5636660',
#   'Q5640442',
#   'Q5647100',
#   'Q5647435',
#   'Q5669631',
#   'Q5669795',
#   'Q5672149',
#   'Q5676660',
#   'Q5682233',
#   'Q5686093',
#   'Q5691425',
#   'Q5692465',
#   'Q5708319',
#   'Q5714725',
#   'Q5739373',
#   'Q5739510',
#   'Q5748186',
#   'Q5755977',
#   'Q5765399',
#   'Q5766417',
#   'Q5769609',
#   'Q5784662',
#   'Q5807311',
#   'Q5851173',
#   'Q5875501',
#   'Q5887436',
#   'Q5891381',
#   'Q5910397',
#   'Q5989356',
#   'Q5989502',
#   'Q5998237',
#   'Q6004656',
#   'Q6053421',
#   'Q6074814',
#   'Q6105823',
#   'Q6116662',
#   'Q6138473',
#   'Q6138475',
#   'Q6138488',
#   'Q6140170',
#   'Q6159663',
#   'Q6169915',
#   'Q6172796',
#   'Q6174597',
#   'Q6191226',
#   'Q6191895',
#   'Q6202344',
#   'Q6312746',
#   'Q6322455',
#   'Q6322465',
#   'Q6343712',
#   'Q6354593',
#   'Q6371338',
#   'Q6373847',
#   'Q6374198',
#   'Q6377724',
#   'Q6379590',
#   'Q6382446',
#   'Q6398221',
#   'Q6402245',
#   'Q6402253',
#   'Q6403208',
#   'Q6404050',
#   'Q6411198',
#   'Q6429164',
#   'Q6429165',
#   'Q6430350',
#   'Q6432225',
#   'Q6435771',
#   'Q6436666',
#   'Q6436675',
#   'Q6441262',
#   'Q6442289',
#   'Q6442505',
#   'Q6442967',
#   'Q6453652',
#   'Q6453655',
#   'Q6461940',
#   'Q6462789',
#   'Q6472082',
#   'Q6491889',
#   'Q6508789',
#   'Q6532301',
#   'Q6586195',
#   'Q7672803',
#   'Q7673920',
#   'Q7674568',
#   'Q7678546',
#   'Q7679165',
#   'Q7681055',
#   'Q7681062',
#   'Q7683067',
#   'Q7685353',
#   'Q7687617',
#   'Q7690562',
#   'Q7698121',
#   'Q7700564',
#   'Q7707025',
#   'Q7710699',
#   'Q7725623',
#   'Q7801775',
#   'Q7804752',
#   'Q7808741',
#   'Q7808838',
#   'Q7810254',
#   'Q7811975',
#   'Q7813451',
#   'Q7814483',
#   'Q7830966',
#   'Q7841293',
#   'Q7843503',
#   'Q7844785',
#   'Q7844787',
#   'Q7844788',
#   'Q7844789',
#   'Q7844791',
#   'Q7849269',
#   'Q7849271',
#   'Q7849273',
#   'Q7849749',
#   'Q7851703',
#   'Q7852608',
#   'Q7852690',
#   'Q7857859',
#   'Q7876892',
#   'Q7878283',
#   'Q7901528',
#   'Q7928364',
#   'Q7933010',
#   'Q7961299',
#   'Q7976961',
#   'Q8045285',
#   'Q8046046',
#   'Q8047056',
#   'Q8047761',
#   'Q8048103',
#   'Q8070483',
#   'Q8075090',
#   'Q8075256',
#   'Q8079916',
#   'Q8079917',
#   'Q8079921',
#   'Q8204672',
#   'Q8353519',
#   'Q9001426',
#   'Q9022704',
#   'Q9065175',
#   'Q9081684',
#   'Q9182138',
#   'Q9212830',
#   'Q9419091',
#   'Q9659186',
#   'Q10269821',
#   'Q10306950',
#   'Q10314435',
#   'Q10353206',
#   'Q10369682',
#   'Q10403797',
#   'Q10431752',
#   'Q10431758',
#   'Q10753171',
#   'Q10783013',
#   'Q10783687',
#   'Q10822595',
#   'Q10840083',
#   'Q10840437',
#   'Q10861374',
#   'Q10892404',
#   'Q11075759',
#   'Q11092881',
#   'Q11098361',
#   'Q11215782',
#   'Q11341612',
#   'Q11498653',
#   'Q11650198',
#   'Q11682277',
#   'Q11829254',
#   'Q11910152',
#   'Q11911068',
#   'Q11920628',
#   'Q11939060',
#   'Q11946334',
#   'Q11953199',
#   'Q11954880',
#   'Q6653370',
#   'Q6654102',
#   'Q6668722',
#   'Q6710917',
#   'Q6718658',
#   'Q6723506',
#   'Q6732512',
#   'Q6740488',
#   'Q6748128',
#   'Q6749152',
#   'Q6749173',
#   'Q6750463',
#   'Q6754723',
#   'Q6759026',
#   'Q6772421',
#   'Q6782415',
#   'Q6783062',
#   'Q6797579',
#   'Q6815777',
#   'Q6862658',
#   'Q6864712',
#   'Q6875024',
#   'Q6932203',
#   'Q6936014',
#   'Q6943773',
#   'Q6951309',
#   'Q6960304',
#   'Q7047745',
#   'Q7064485',
#   'Q7071063',
#   'Q7071407',
#   'Q7075256',
#   'Q7075353',
#   'Q7076774',
#   'Q7083206',
#   'Q7090062',
#   'Q7090795',
#   'Q7095385',
#   'Q7101770',
#   'Q7101775',
#   'Q7103992',
#   'Q7108528',
#   'Q7120230',
#   'Q7123295',
#   'Q7129321',
#   'Q7130187',
#   'Q7143055',
#   'Q7186113',
#   'Q7198298',
#   'Q7201800',
#   'Q7205095',
#   'Q7265233',
#   'Q7269255',
#   'Q7269501',
#   'Q7271943',
#   'Q7272401',
#   'Q7272469',
#   'Q7281253',
#   'Q7303480',
#   'Q7314870',
#   'Q7320165',
#   'Q7334676',
#   'Q7360333',
#   'Q7361386',
#   'Q7365591',
#   'Q7365593',
#   'Q7379154',
#   'Q7403597',
#   'Q7404961',
#   'Q7406098',
#   'Q7408984',
#   'Q7410180',
#   'Q7418239',
#   'Q7418340',
#   'Q7421024',
#   'Q7426334',
#   'Q7428594',
#   'Q7428890',
#   'Q7462274',
#   'Q7502339',
#   'Q7505701',
#   'Q7506038',
#   'Q7513987',
#   'Q7515478',
#   'Q7531816',
#   'Q7533633',
#   'Q7555423',
#   'Q7564023',
#   'Q7564871',
#   'Q7572372',
#   'Q7586583',
#   'Q7623972',
#   'Q7623984',
#   'Q7630969',
#   'Q7636250',
#   'Q7638092',
#   'Q7639273',
#   'Q7652693',
#   'Q7661404',
#   'Q7664811',
#   'Q18449487',
#   'Q18627458',
#   'Q19671148',
#   'Q19856213',
#   'Q19895199',
#   'Q19899453',
#   'Q20009773',
#   'Q20103041',
#   'Q20103238',
#   'Q20104603',
#   'Q20104853',
#   'Q20106313',
#   'Q20106353',
#   'Q20106964',
#   'Q20523954',
#   'Q20585538',
#   'Q20826903',
#   'Q20854933',
#   'Q20967773',
#   'Q21080967',
#   'Q21081475',
#   'Q21087040',
#   'Q21087453',
#   'Q25093046',
#   'Q25101248',
#   'Q25226698',
#   'Q25348503',
#   'Q25395631',
#   'Q25399492',
#   'Q25412985',
#   'Q25472791',
#   'Q25644178',
#   'Q25680583',
#   'Q27027147',
#   'Q27181298',
#   'Q27510104',
#   'Q27513249',
#   'Q28137123',
#   'Q28148538',
#   'Q28170750',
#   'Q28171515',
#   'Q28192975',
#   'Q28219771',
#   'Q28403542',
#   'Q28452681',
#   'Q28692811',
#   'Q28710739',
#   'Q28737179',
#   'Q29017799',
#   'Q29277213',
#   'Q29301219',
#   'Q30034571',
#   'Q30324270',
#   'Q30347637',
#   'Q30347664',
#   'Q31842594',
#   'Q34379956',
#   'Q37681691',
#   'Q39056298',
#   'Q40447270',
#   'Q40447413',
#   'Q40448318',
#   'Q43079402',
#   'Q44254442',
#   'Q44254482',
#   'Q44254502',
#   'Q44254550',
#   'Q44254585',
#   'Q44254611',
#   'Q44254669',
#   'Q44254678',
#   'Q44254733',
#   'Q45753024',
#   'Q46996061',
#   'Q46996068',
#   'Q48817576',
#   'Q49184007',
#   'Q50329237',
#   'Q50331514',
#   'Q51846072',
#   'Q52987174',
#   'Q55568438',
#   'Q55738523',
#   'Q56062174',
#   'Q56062175',
#   'Q56196958',
#   'Q56196959',
#   'Q56196961',
#   'Q56196962',
#   'Q56251798',
#   'Q56251800',
#   'Q56251803',
#   'Q56251805',
#   'Q56251806',
#   'Q56276235',
#   'Q56277888',
#   'Q56401746',
#   'Q56476228',
#   'Q56862947',
#   'Q59419216',
#   'Q11955392',
#   'Q11990687',
#   'Q12017895',
#   'Q12059669',
#   'Q12233838',
#   'Q12483344',
#   'Q12483346',
#   'Q12484415',
#   'Q12485397',
#   'Q12519046',
#   'Q12521411',
#   'Q12791479',
#   'Q12863848',
#   'Q12885443',
#   'Q12904608',
#   'Q12983208',
#   'Q12987976',
#   'Q13038039',
#   'Q13038049',
#   'Q13096799',
#   'Q13135638',
#   'Q13408004',
#   'Q13636556',
#   'Q13656026',
#   'Q14754685',
#   'Q15057905',
#   'Q15069864',
#   'Q15210789',
#   'Q15212740',
#   'Q15220707',
#   'Q15614634',
#   'Q15717974',
#   'Q15785425',
#   'Q15824524',
#   'Q15869380',
#   'Q16133280',
#   'Q16205517',
#   'Q16256860',
#   'Q16304285',
#   'Q16522042',
#   'Q16556212',
#   'Q16572861',
#   'Q16573450',
#   'Q16590872',
#   'Q16629274',
#   'Q16637700',
#   'Q16678513',
#   'Q16708063',
#   'Q16796308',
#   'Q16837506',
#   'Q16843539',
#   'Q16892532',
#   'Q16910195',
#   'Q16910872',
#   'Q16911115',
#   'Q16916457',
#   'Q16917012',
#   'Q16918224',
#   'Q16918625',
#   'Q16919362',
#   'Q16928253',
#   'Q16928510',
#   'Q16938266',
#   'Q16938324',
#   'Q16940786',
#   'Q16965914',
#   'Q16975813',
#   'Q16976029',
#   'Q16977624',
#   'Q16999252',
#   'Q17000154',
#   'Q17012197',
#   'Q17025635',
#   'Q17049229',
#   'Q17055647',
#   'Q17061825',
#   'Q17062754',
#   'Q17064573',
#   'Q17067314',
#   'Q17068242',
#   'Q17070015',
#   'Q17070147',
#   'Q17070215',
#   'Q17082422',
#   'Q17084554',
#   'Q17085087',
#   'Q17086716',
#   'Q17099062',
#   'Q17105516',
#   'Q17117240',
#   'Q17143535',
#   'Q17172850',
#   'Q17189221',
#   'Q17591720',
#   'Q18178803',
#   'Q18224135',
#   'Q18350431',
#   'Q18377839',
#   'Q18379775',
#   'Q18391628',
#   'Q59480249',
#   'Q60024229',
#   'Q60024246',
#   'Q60190502',
#   'Q60401255',
#   'Q60748953',
#   'Q61890953',
#   'Q62568526',
#   'Q65066724',
#   'Q65067370',
#   'Q65069429',
#   'Q65121950',
#   'Q65129374',
#   'Q65167558',
#   'Q65203986',
#   'Q65329834',
#   'Q67247227',
#   'Q72194192',
#   'Q75044936',
#   'Q75797748',
#   'Q82987019',
#   'Q83388852',
#   'Q83401618',
#   'Q89441855',
#   'Q95687066',
#   'Q98329515',
#   'Q99700503',
#   'Q99700702',
#   'Q104521646',
#   'Q104996348'],
#  'Q52954': ['Q1444',
#   'Q5994',
#   'Q25180',
#   'Q81982',
#   'Q191823',
#   'Q336767',
#   'Q490054',
#   'Q862501',
#   'Q960650',
#   'Q1099112',
#   'Q1099153',
#   'Q1124573',
#   'Q1300012',
#   'Q1343007',
#   'Q3177916',
#   'Q6147937',
#   'Q6516591',
#   'Q11712894',
#   'Q18328047',
#   'Q22266768',
#   'Q25427897',
#   'Q30162558',
#   'Q59537298',
#   'Q65486616'],
#  'Q105738': ['Q1149304',
#   'Q1327500',
#   'Q1372823',
#   'Q2317481',
#   'Q50821977',
#   'Q50822193',
#   'Q55739029',
#   'Q55739031'],
#  'Q133163': ['Q93985',
#   'Q104363',
#   'Q128309',
#   'Q133722',
#   'Q194492',
#   'Q270200',
#   'Q354765',
#   'Q395212',
#   'Q609599',
#   'Q850118',
#   'Q943438',
#   'Q954983',
#   'Q1189515',
#   'Q1410790',
#   'Q1428415',
#   'Q1437089',
#   'Q1439716',
#   'Q1458221',
#   'Q1644824',
#   'Q1661583',
#   'Q1898734',
#   'Q2046356',
#   'Q2046658',
#   'Q2128998',
#   'Q2360352',
#   'Q2368593',
#   'Q2781273',
#   'Q2898290',
#   'Q3083684',
#   'Q3144475',
#   'Q3193614',
#   'Q3275471',
#   'Q3305735',
#   'Q3522389',
#   'Q3574205',
#   'Q3623050',
#   'Q3998771',
#   'Q4422479',
#   'Q4465189',
#   'Q4848966',
#   'Q4898607',
#   'Q4986147',
#   'Q5017970',
#   'Q5032021',
#   'Q5280486',
#   'Q5719092',
#   'Q5732744',
#   'Q5765986',
#   'Q5766082',
#   'Q5959276',
#   'Q6138484',
#   'Q6344764',
#   'Q6374198',
#   'Q6813330',
#   'Q7198871',
#   'Q7362780',
#   'Q7536920',
#   'Q7821057',
#   'Q7897283',
#   'Q11910499',
#   'Q11913230',
#   'Q11926747',
#   'Q11926749',
#   'Q11941932',
#   'Q11950748',
#   'Q11955385',
#   'Q12486450',
#   'Q12690320',
#   'Q13219842',
#   'Q14640031',
#   'Q17062763',
#   'Q17138362',
#   'Q17621647',
#   'Q19588483',
#   'Q19754610',
#   'Q21087039',
#   'Q21087294',
#   'Q21091809',
#   'Q21099529',
#   'Q25432192',
#   'Q27924148',
#   'Q28497151',
#   'Q30674028',
#   'Q56643162',
#   'Q58230999',
#   'Q65129374',
#   'Q66657140',
#   'Q68647735',
#   'Q94771632',
#   'Q94955062',
#   'Q94955292',
#   'Q94995062',
#   'Q105379653'],
#  'Q212892': ['Q139132',
#   'Q193666',
#   'Q379248',
#   'Q503646',
#   'Q537750',
#   'Q583827',
#   'Q584522',
#   'Q744831',
#   'Q745421',
#   'Q747604',
#   'Q748760',
#   'Q816793',
#   'Q892936',
#   'Q940274',
#   'Q1098246',
#   'Q1207707',
#   'Q1249186',
#   'Q1351166',
#   'Q1355394',
#   'Q1553249',
#   'Q1557967',
#   'Q1562149',
#   'Q1768224',
#   'Q1771072',
#   'Q2510552',
#   'Q3038392',
#   'Q3181140',
#   'Q3196570',
#   'Q3511343',
#   'Q3525409',
#   'Q3534333',
#   'Q3566151',
#   'Q3624317',
#   'Q3773253',
#   'Q4077510',
#   'Q4148082',
#   'Q4863335',
#   'Q5032021',
#   'Q5268652',
#   'Q5289312',
#   'Q5523319',
#   'Q5717556',
#   'Q5766082',
#   'Q6421295',
#   'Q6421296',
#   'Q6421299',
#   'Q6421300',
#   'Q6441836',
#   'Q6726202',
#   'Q7124768',
#   'Q7680593',
#   'Q7682928',
#   'Q7997355',
#   'Q8014803',
#   'Q8081782',
#   'Q9087780',
#   'Q9355433',
#   'Q10335911',
#   'Q11653585',
#   'Q12521411',
#   'Q13219842',
#   'Q16948539',
#   'Q18389994',
#   'Q19588483',
#   'Q27490824',
#   'Q28402531',
#   'Q28497151',
#   'Q50829196',
#   'Q52192089',
#   'Q55724270',
#   'Q59419216',
#   'Q65251914'],
#  'Q1444': ['Q281460',
#   'Q930827',
#   'Q1327327',
#   'Q1891833',
#   'Q1930186',
#   'Q2029807',
#   'Q2595587',
#   'Q2678997',
#   'Q3356240',
#   'Q3484808',
#   'Q7315415',
#   'Q7661431',
#   'Q12286601',
#   'Q12460259',
#   'Q15976349',
#   'Q16293243',
#   'Q97376750'],
#  'Q5994': ['Q448050',
#   'Q450578',
#   'Q454862',
#   'Q593995',
#   'Q754186',
#   'Q1136507',
#   'Q1148709',
#   'Q1512133',
#   'Q1521313',
#   'Q1526615',
#   'Q1681975',
#   'Q2141273',
#   'Q2341764',
#   'Q2631948',
#   'Q2752967',
#   'Q3382191',
#   'Q3503387',
#   'Q3846212',
#   'Q7187884',
#   'Q17155771',
#   'Q105693575'],
#  'Q81982': ['Q623941', 'Q1746064', 'Q5646557', 'Q17146589'],
#  'Q93985': ['Q2451592'],
#  'Q104363': ['Q66646696'],
#  'Q128309': ['Q4014830', 'Q5139701'],
#  'Q194492': ['Q1493069', 'Q5520009', 'Q5520017', 'Q12472139', 'Q105379653'],
#  'Q270200': ['Q7379154'],
#  'Q336767': ['Q79838',
#   'Q593050',
#   'Q1421815',
#   'Q1494360',
#   'Q1584136',
#   'Q1919657',
#   'Q3127548',
#   'Q20616435'],
#  'Q820922': ['Q2078967'],
#  'Q1149304': ['Q593794', 'Q1327396', 'Q5616912', 'Q5663215'],
#  'Q1327500': ['Q163829',
#   'Q207691',
#   'Q320002',
#   'Q490054',
#   'Q604813',
#   'Q639717',
#   'Q646683',
#   'Q831698',
#   'Q862501',
#   'Q862880',
#   'Q908562',
#   'Q1129025',
#   'Q1140792',
#   'Q1327480',
#   'Q1343007',
#   'Q1417866',
#   'Q1508837',
#   'Q1753848',
#   'Q1799406',
#   'Q2212859',
#   'Q2473977',
#   'Q2978687',
#   'Q3131599',
#   'Q3241627',
#   'Q3268757',
#   'Q3356240',
#   'Q3503387',
#   'Q4734959',
#   'Q5358437',
#   'Q7108425',
#   'Q7523623',
#   'Q9339403',
#   'Q15336282',
#   'Q21041406',
#   'Q28017773',
#   'Q55738975',
#   'Q55738993',
#   'Q55738997',
#   'Q65069429',
#   'Q100999414'],
#  'Q217306': ['Q8343',
#   'Q8345',
#   'Q8380',
#   'Q185041',
#   'Q602719',
#   'Q656766',
#   'Q808215',
#   'Q810511',
#   'Q1366388',
#   'Q1571002',
#   'Q1760274',
#   'Q2731509',
#   'Q6517474',
#   'Q56299622',
#   'Q98647213',
#   'Q98654724',
#   'Q104521646'],
#  'Q334606': ['Q634514'],
#  'Q391640': ['Q3862760'],
#  'Q550596': ['Q21467791', 'Q22909673'],
#  'Q654117': ['Q2994640', 'Q15879612'],
#  'Q659216': ['Q173453',
#   'Q181247',
#   'Q750934',
#   'Q930949',
#   'Q952980',
#   'Q1242932',
#   'Q1535806',
#   'Q1680874',
#   'Q1727254',
#   'Q2757805',
#   'Q5429274',
#   'Q7847122',
#   'Q9212830',
#   'Q13522655',
#   'Q15516303',
#   'Q16939309',
#   'Q19896195',
#   'Q25408189',
#   'Q42896320',
#   'Q50840728',
#   'Q55738955',
#   'Q61366793',
#   'Q95976560'],
#  'Q695269': ['Q54820129'],
#  'Q810447': ['Q46185'],
#  'Q977922': ['Q7187884'],
#  'Q1051772': ['Q76239',
#   'Q170060',
#   'Q644440',
#   'Q644562',
#   'Q660182',
#   'Q706025',
#   'Q736802',
#   'Q806351',
#   'Q827200',
#   'Q854664',
#   'Q873588',
#   'Q916056',
#   'Q944501',
#   'Q1056351',
#   'Q1129422',
#   'Q1255518',
#   'Q1414954',
#   'Q1426973',
#   'Q1798603',
#   'Q2059671',
#   'Q2317481',
#   'Q2407046',
#   'Q2599780',
#   'Q2660670',
#   'Q2670517',
#   'Q2679436',
#   'Q2912399',
#   'Q3120694',
#   'Q3299211',
#   'Q3299793',
#   'Q3571466',
#   'Q3817760',
#   'Q3888862',
#   'Q4272647',
#   'Q4460933',
#   'Q4507063',
#   'Q4890356',
#   'Q5101105',
#   'Q5102334',
#   'Q5102596',
#   'Q5150938',
#   'Q5191871',
#   'Q5191872',
#   'Q5192829',
#   'Q5208957',
#   'Q5269025',
#   'Q5299280',
#   'Q5313363',
#   'Q5317665',
#   'Q5614447',
#   'Q5616842',
#   'Q5618830',
#   'Q5647920',
#   'Q5924836',
#   'Q5946037',
#   'Q5986114',
#   'Q5988789',
#   'Q6368525',
#   'Q6427274',
#   'Q6444095',
#   'Q6450485',
#   'Q6450700',
#   'Q6502879',
#   'Q6524983',
#   'Q6577044',
#   'Q6583096',
#   'Q6668609',
#   'Q6682188',
#   'Q7135795',
#   'Q7139986',
#   'Q7420932',
#   'Q7423131',
#   'Q7550275',
#   'Q7618343',
#   'Q7622758',
#   'Q7646518',
#   'Q7653835',
#   'Q7685994',
#   'Q7688050',
#   'Q7698037',
#   'Q7700567',
#   'Q7861991',
#   'Q7933058',
#   'Q7933063',
#   'Q7933085',
#   'Q8050542',
#   'Q8070952',
#   'Q8079920',
#   'Q8079925',
#   'Q8079926',
#   'Q8079927',
#   'Q8080008',
#   'Q9190327',
#   'Q10751910',
#   'Q10823878',
#   'Q11705089',
#   'Q12712274',
#   'Q13027834',
#   'Q13181472',
#   'Q13417190',
#   'Q16057581',
#   'Q16155191',
#   'Q19588495',
#   'Q20641082',
#   'Q21087171',
#   'Q53514237',
#   'Q55724996',
#   'Q95716801',
#   'Q98079039'],
#  'Q1343007': ['Q1047696',
#   'Q1112687',
#   'Q2978662',
#   'Q5048950',
#   'Q6147937',
#   'Q7355580',
#   'Q51716584'],
#  'Q1372823': ['Q380616',
#   'Q960650',
#   'Q1053287',
#   'Q1136507',
#   'Q1149847',
#   'Q1327327',
#   'Q55738964',
#   'Q55738965',
#   'Q55738966',
#   'Q55738967',
#   'Q55738968'],
#  'Q1553339': ['Q582093',
#   'Q1433428',
#   'Q1957470',
#   'Q2379556',
#   'Q2489759',
#   'Q7535807',
#   'Q28163991'],
#  'Q1644824': ['Q848250',
#   'Q1552564',
#   'Q2237198',
#   'Q6346681',
#   'Q8067152',
#   'Q15141691',
#   'Q55722119',
#   'Q55722130',
#   'Q55722133',
#   'Q55722137',
#   'Q55722141'],
#  'Q1661583': ['Q890073'],
#  'Q3083684': ['Q16533924'],
#  'Q3655696': ['Q958982', 'Q2338544', 'Q48359853'],
#  'Q5249313': ['Q494452', 'Q3689380', 'Q3976471'],
#  'Q11712894': ['Q209554', 'Q281460', 'Q12460259'],
#  'Q15990884': ['Q772497', 'Q2936610'],
#  'Q18822510': ['Q623202'],
#  'Q50821977': ['Q55738956',
#   'Q55738958',
#   'Q55738960',
#   'Q55738962',
#   'Q55738963'],
#  'Q50822193': ['Q1112687',
#   'Q5276177',
#   'Q55739021',
#   'Q55739022',
#   'Q55739023',
#   'Q55739024',
#   'Q55739025',
#   'Q55739027'],
#  'Q1071649': ['Q60517',
#   'Q120585',
#   'Q241337',
#   'Q249105',
#   'Q289037',
#   'Q425748',
#   'Q655142',
#   'Q829729',
#   'Q954904',
#   'Q1328494',
#   'Q1474569',
#   'Q1756773',
#   'Q1760249',
#   'Q1842022',
#   'Q1975355',
#   'Q2280552',
#   'Q2709639',
#   'Q2904003',
#   'Q3100072',
#   'Q3144475',
#   'Q3327567',
#   'Q3435701',
#   'Q3482784',
#   'Q3571466',
#   'Q3729520',
#   'Q4148082',
#   'Q4216548',
#   'Q5587995',
#   'Q5986114',
#   'Q6363675',
#   'Q20983120',
#   'Q25220665',
#   'Q25230390'],
#  'Q193666': ['Q17057067', 'Q17093977', 'Q21087294', 'Q21091809'],
#  'Q583827': ['Q176926',
#   'Q3699530',
#   'Q3926020',
#   'Q50752927',
#   'Q55724298',
#   'Q55724319',
#   'Q55724576',
#   'Q72421021',
#   'Q77969886'],
#  'Q1553249': ['Q13094251',
#   'Q13094253',
#   'Q13094254',
#   'Q13094255',
#   'Q72100872',
#   'Q73514883'],
#  'Q4863335': ['Q2046658', 'Q7410116', 'Q43895968'],
#  'Q6813330': ['Q1233386'],
#  'Q7198871': ['Q189737'],
#  'Q13219842': ['Q319154', 'Q3574843', 'Q6421300', 'Q13026720', 'Q19841014'],
#  'Q19588483': ['Q1515888', 'Q1751598', 'Q3514744', 'Q5280487'],
#  'Q105379653': ['Q56196958'],
#  'Q8343': ['Q8345',
#   'Q277815',
#   'Q656766',
#   'Q810511',
#   'Q810515',
#   'Q961470',
#   'Q1366388',
#   'Q1905735',
#   'Q2731509',
#   'Q6517474',
#   'Q8961774',
#   'Q17141242',
#   'Q56299622',
#   'Q72422235',
#   'Q98183018',
#   'Q98647213',
#   'Q98654724'],
#  'Q46185': ['Q288342',
#   'Q424017',
#   'Q548517',
#   'Q584917',
#   'Q727758',
#   'Q743821',
#   'Q922217',
#   'Q932855',
#   'Q1165005',
#   'Q1404623',
#   'Q1523005',
#   'Q1669802',
#   'Q2887371',
#   'Q3742421',
#   'Q4039410',
#   'Q5165633',
#   'Q6941604',
#   'Q6941607',
#   'Q7622681',
#   'Q64166304'],
#  'Q76239': ['Q627110',
#   'Q2145031',
#   'Q3296114',
#   'Q3574205',
#   'Q5288901',
#   'Q10973993',
#   'Q15785448',
#   'Q17074660',
#   'Q30034751',
#   'Q30034781',
#   'Q44608867',
#   'Q44617887',
#   'Q50829016',
#   'Q55365924',
#   'Q55724721',
#   'Q55724763',
#   'Q55724776'],
#  'Q173453': ['Q11405',
#   'Q11786',
#   'Q178374',
#   'Q180744',
#   'Q230075',
#   'Q591109',
#   'Q611061',
#   'Q743836',
#   'Q779650',
#   'Q810513',
#   'Q864778',
#   'Q946304',
#   'Q1048934',
#   'Q1126540',
#   'Q1134218',
#   'Q1134287',
#   'Q1164356',
#   'Q1696139',
#   'Q2030802',
#   'Q2094941',
#   'Q2228469',
#   'Q2394487',
#   'Q2394517',
#   'Q2402135',
#   'Q2482031',
#   'Q2665724',
#   'Q2757805',
#   'Q2930175',
#   'Q3099989',
#   'Q3152896',
#   'Q3339215',
#   'Q3341170',
#   'Q3571222',
#   'Q3944144',
#   'Q4345357',
#   'Q5551733',
#   'Q5655491',
#   'Q5869541',
#   'Q6017467',
#   'Q6030755',
#   'Q6076988',
#   'Q7461202',
#   'Q11712894',
#   'Q12818538',
#   'Q13038040',
#   'Q15840541',
#   'Q19826868',
#   'Q20383146',
#   'Q21684172',
#   'Q22266768',
#   'Q24288450',
#   'Q25380080',
#   'Q25411777',
#   'Q25432212',
#   'Q28071027',
#   'Q28733066',
#   'Q44192898',
#   'Q55738527',
#   'Q55738955',
#   'Q67202852'],
#  'Q181247': ['Q8343',
#   'Q8345',
#   'Q9798',
#   'Q11405',
#   'Q189388',
#   'Q656766',
#   'Q750934',
#   'Q810511',
#   'Q810515',
#   'Q925589',
#   'Q961470',
#   'Q1059131',
#   'Q1091329',
#   'Q1123270',
#   'Q1127899',
#   'Q1225550',
#   'Q1366388',
#   'Q1592960',
#   'Q1986655',
#   'Q2035157',
#   'Q2108766',
#   'Q2482031',
#   'Q2731509',
#   'Q2890812',
#   'Q3061445',
#   'Q3152896',
#   'Q3388256',
#   'Q3514733',
#   'Q3528106',
#   'Q5321271',
#   'Q5716913',
#   'Q5988478',
#   'Q6034092',
#   'Q6517474',
#   'Q10484225',
#   'Q12646220',
#   'Q13522655',
#   'Q28048653',
#   'Q56299622',
#   'Q98647213',
#   'Q104521646'],
#  'Q750934': ['Q893187', 'Q5963228', 'Q13522655'],
#  'Q1255518': ['Q10542074'],
#  'Q1426973': ['Q17049229'],
#  'Q1798603': ['Q192096',
#   'Q198215',
#   'Q230262',
#   'Q381651',
#   'Q859350',
#   'Q1022225',
#   'Q1068162',
#   'Q1202193',
#   'Q1221385',
#   'Q1415095',
#   'Q1778051',
#   'Q1785355',
#   'Q1789755',
#   'Q3087584',
#   'Q3152898',
#   'Q3539688',
#   'Q3559312',
#   'Q4505787',
#   'Q4854658',
#   'Q5018034',
#   'Q5296883',
#   'Q5456262',
#   'Q6404050',
#   'Q7339001',
#   'Q7409426',
#   'Q7505340',
#   'Q7563269',
#   'Q9001433',
#   'Q10965821',
#   'Q16413988',
#   'Q16948101',
#   'Q16965455',
#   'Q16975812',
#   'Q17067914',
#   'Q17093070',
#   'Q17104426',
#   'Q18413275',
#   'Q18616021',
#   'Q25110755',
#   'Q62604102',
#   'Q84309610'],
#  'Q2407046': ['Q11954880'],
#  'Q2731509': ['Q36973404'],
#  'Q2994640': ['Q7920476'],
#  'Q13522655': ['Q24943194'],
#  'Q42896320': ['Q399597', 'Q3152896'],
#  'Q50829196': ['Q483994', 'Q55724583', 'Q55724586', 'Q83401618'],
#  'Q50840728': ['Q54819588', 'Q55725012', 'Q55738515'],
#  'Q54820129': ['Q524526', 'Q846109', 'Q960389', 'Q3388256', 'Q25630013'],
#  'Q4783433': ['Q17057067', 'Q92315739'],
#  'Q5421167': ['Q862501',
#   'Q1527836',
#   'Q4748495',
#   'Q5358007',
#   'Q7531714',
#   'Q65069429'],
#  'Q7047745': ['Q4937326'],
#  'Q7272401': ['Q5357961', 'Q5358007'],
#  'Q4306652': ['Q742180'],
#  'Q208421': ['Q810420', 'Q3083684', 'Q16535112'],
#  'Q211028': ['Q16901912'],
#  'Q221769': ['Q11653585'],
#  'Q811075': ['Q7090062', 'Q73806655', 'Q73806689', 'Q73806761'],
#  'Q871633': ['Q7488347'],
#  'Q936762': ['Q1365218',
#   'Q1467960',
#   'Q2642697',
#   'Q3236956',
#   'Q3913027',
#   'Q4692521',
#   'Q5357621',
#   'Q5989356',
#   'Q6786485',
#   'Q7240510',
#   'Q7814729',
#   'Q8096207',
#   'Q55722155',
#   'Q55722183',
#   'Q56294700',
#   'Q101967894'],
#  'Q1514705': ['Q13062980'],
#  'Q1575231': ['Q270200', 'Q598306'],
#  'Q5064156': ['Q1771072'],
#  'Q10829913': ['Q1078822', 'Q3319384'],
#  'Q67247227': ['Q12339842'],
#  'Q98329515': ['Q207691',
#   'Q1129025',
#   'Q1144761',
#   'Q3087584',
#   'Q17172850',
#   'Q55738923'],
#  'Q6010': ['Q384181', 'Q101552821'],
#  'Q41923': ['Q885943'],
#  'Q2628163': ['Q262991', 'Q71830623'],
#  'Q4928618': ['Q55722893', 'Q55722906'],
#  'Q5280486': ['Q1095097', 'Q1474569', 'Q1670830', 'Q6025130', 'Q19462049'],
#  'Q5503427': ['Q48230',
#   'Q953846',
#   'Q1144761',
#   'Q1179017',
#   'Q1471374',
#   'Q7922585',
#   'Q55722217',
#   'Q55722796',
#   'Q55722819',
#   'Q55722887'],
#  'Q55722920': ['Q1241859', 'Q55722926', 'Q55722930', 'Q55722933', 'Q55722937'],
#  'Q55738956': ['Q743659', 'Q1759986'],
#  'Q1295894': ['Q290688', 'Q7047745'],
#  'Q1381282': ['Q12180', 'Q996531', 'Q1678302', 'Q2285118'],
#  'Q1559267': ['Q201654', 'Q593995', 'Q1365218', 'Q20826189'],
#  'Q1756773': ['Q524526',
#   'Q1058772',
#   'Q1064880',
#   'Q3022449',
#   'Q3572459',
#   'Q5911047'],
#  'Q2310383': ['Q7108425', 'Q10662188'],
#  'Q2313828': ['Q1820831', 'Q5517372', 'Q5517374', 'Q16570484'],
#  'Q11405': ['Q209554',
#   'Q478634',
#   'Q568883',
#   'Q706424',
#   'Q750934',
#   'Q839767',
#   'Q960389',
#   'Q1134958',
#   'Q1146067',
#   'Q1685320',
#   'Q1756773',
#   'Q2167687',
#   'Q2285118',
#   'Q2626629',
#   'Q2661289',
#   'Q3030514',
#   'Q3100072',
#   'Q3390893',
#   'Q4743369',
#   'Q5216174',
#   'Q5805460',
#   'Q7215228',
#   'Q7577345',
#   'Q7852690',
#   'Q10537276',
#   'Q10887115',
#   'Q11618207',
#   'Q11853199',
#   'Q13038039',
#   'Q17146875',
#   'Q18711246',
#   'Q19708717',
#   'Q20164852',
#   'Q20655433',
#   'Q21041941',
#   'Q21056588',
#   'Q25220665',
#   'Q54820129',
#   'Q55738528',
#   'Q56753171',
#   'Q87332636',
#   'Q94634196',
#   'Q100948993'],
#  'Q180744': ['Q8338',
#   'Q44150',
#   'Q202027',
#   'Q277670',
#   'Q819132',
#   'Q938353',
#   'Q1553522',
#   'Q1628293',
#   'Q1662735',
#   'Q1678302',
#   'Q1779894',
#   'Q2568945',
#   'Q2757805',
#   'Q3163373',
#   'Q3192692',
#   'Q6956736',
#   'Q7911679',
#   'Q10426885',
#   'Q10426889',
#   'Q12486669',
#   'Q16951760',
#   'Q25043174',
#   'Q55738916',
#   'Q79351900',
#   'Q82052189',
#   'Q97477525'],
#  'Q424017': ['Q1554184'],
#  'Q623941': ['Q2017606', 'Q7113218'],
#  'Q864778': ['Q25555663'],
#  'Q1126540': ['Q277670',
#   'Q996531',
#   'Q1335907',
#   'Q1628293',
#   'Q1678302',
#   'Q2568945',
#   'Q16951760',
#   'Q25043174',
#   'Q94572957',
#   'Q95976560',
#   'Q97477525'],
#  'Q2145031': ['Q102129672'],
#  'Q2665724': ['Q48298', 'Q3354343', 'Q58318973'],
#  'Q2887371': ['Q6941604', 'Q6941610'],
#  'Q3152896': ['Q185626',
#   'Q512191',
#   'Q864989',
#   'Q2152657',
#   'Q50362275',
#   'Q55738876',
#   'Q55738890'],
#  'Q4014830': ['Q3839161'],
#  'Q30034751': ['Q1630744', 'Q55724671'],
#  'Q27911': ['Q810480',
#   'Q1002146',
#   'Q2532487',
#   'Q3636053',
#   'Q5885030',
#   'Q7082656',
#   'Q20638448',
#   'Q54636007',
#   'Q54636036',
#   'Q54636068',
#   'Q54636271',
#   'Q64363543'],
#  'Q31687': ['Q810480',
#   'Q1062931',
#   'Q1601737',
#   'Q5721499',
#   'Q5721503',
#   'Q5885030',
#   'Q8243255',
#   'Q8243257',
#   'Q19740895',
#   'Q21478751',
#   'Q25404193',
#   'Q54635681',
#   'Q54635751',
#   'Q54635784'],
#  'Q37137': ['Q5785182',
#   'Q5785183',
#   'Q6141663',
#   'Q54635184',
#   'Q54635214',
#   'Q54635335'],
#  'Q178389': ['Q19907686'],
#  'Q186506': ['Q682525',
#   'Q1300059',
#   'Q1878954',
#   'Q1999862',
#   'Q6012297',
#   'Q54634572',
#   'Q54634726',
#   'Q54634862',
#   'Q54634945'],
#  'Q207691': ['Q18634896'],
#  'Q210970': ['Q53395016', 'Q53830255', 'Q54634945'],
#  'Q223166': ['Q1873389'],
#  'Q281460': ['Q120430',
#   'Q511330',
#   'Q918236',
#   'Q1742272',
#   'Q1806700',
#   'Q2098977',
#   'Q2371434',
#   'Q7252112',
#   'Q18088112',
#   'Q29213520',
#   'Q97313710'],
#  'Q810480': ['Q54635842', 'Q54635897'],
#  'Q1136507': ['Q186496', 'Q743659', 'Q1759986'],
#  'Q1148709': ['Q1243503', 'Q3657114', 'Q98294965'],
#  'Q1327327': ['Q105891',
#   'Q133506',
#   'Q1037667',
#   'Q1396591',
#   'Q2459005',
#   'Q94994685'],
#  'Q2353374': ['Q698593'],
#  'Q3087584': ['Q932855', 'Q1365097', 'Q20758461'],
#  'Q3382191': ['Q5410385', 'Q18218617'],
#  'Q4852742': ['Q145840', 'Q1147128', 'Q2595197', 'Q3504809', 'Q3732881'],
#  'Q6164901': ['Q53829839'],
#  'Q6983813': ['Q37137', 'Q6012300', 'Q53395016', 'Q53395277'],
#  'Q12286601': ['Q1256576'],
#  'Q12460259': ['Q213461',
#   'Q380835',
#   'Q608926',
#   'Q1792434',
#   'Q2227437',
#   'Q4335803',
#   'Q7452719',
#   'Q18692399'],
#  'Q12486669': ['Q16253812'],
#  'Q55738923': ['Q8350',
#   'Q228529',
#   'Q808573',
#   'Q2757805',
#   'Q4982421',
#   'Q15840862'],
#  'Q163829': ['Q139300',
#   'Q507314',
#   'Q512222',
#   'Q514109',
#   'Q744418',
#   'Q882090',
#   'Q908562',
#   'Q1047660',
#   'Q1112687',
#   'Q1129025',
#   'Q1527709',
#   'Q1557633',
#   'Q1638169',
#   'Q1670451',
#   'Q1758289',
#   'Q1784412',
#   'Q2055092',
#   'Q3268757',
#   'Q3440123',
#   'Q3440278',
#   'Q3571431',
#   'Q3717396',
#   'Q4906756',
#   'Q5048910',
#   'Q5276177',
#   'Q6136833',
#   'Q6763674',
#   'Q6902065',
#   'Q7917856',
#   'Q8047658',
#   'Q8047705',
#   'Q10573289',
#   'Q11338907',
#   'Q64160820',
#   'Q65038698',
#   'Q65038716',
#   'Q65038747',
#   'Q65038798',
#   'Q65038848',
#   'Q102429587',
#   'Q102430257'],
#  'Q192096': ['Q204482',
#   'Q372308',
#   'Q579484',
#   'Q615941',
#   'Q685663',
#   'Q831657',
#   'Q843679',
#   'Q854664',
#   'Q882033',
#   'Q1057085',
#   'Q1067399',
#   'Q1340475',
#   'Q1363679',
#   'Q1440075',
#   'Q1521728',
#   'Q1815667',
#   'Q2303097',
#   'Q2405825',
#   'Q2924103',
#   'Q3622278',
#   'Q3764046',
#   'Q3889206',
#   'Q4055237',
#   'Q4138014',
#   'Q4506643',
#   'Q4518086',
#   'Q4690002',
#   'Q4867994',
#   'Q5208668',
#   'Q5577965',
#   'Q5936422',
#   'Q10566114',
#   'Q10969818',
#   'Q11897419',
#   'Q15785425',
#   'Q15842338',
#   'Q15882423',
#   'Q22329414',
#   'Q57050725',
#   'Q57315384',
#   'Q82506229',
#   'Q85244912',
#   'Q87826372',
#   'Q87929050',
#   'Q87929588',
#   'Q102047921',
#   'Q102048081',
#   'Q102049376'],
#  'Q230262': ['Q47369',
#   'Q61285',
#   'Q76239',
#   'Q81982',
#   'Q139727',
#   'Q167126',
#   'Q176322',
#   'Q201129',
#   'Q262414',
#   'Q272827',
#   'Q289037',
#   'Q342234',
#   'Q342244',
#   'Q356330',
#   'Q507102',
#   'Q528239',
#   'Q529070',
#   'Q530140',
#   'Q532584',
#   'Q539942',
#   'Q546936',
#   'Q569224',
#   'Q665657',
#   'Q717407',
#   'Q723720',
#   'Q726303',
#   'Q733370',
#   'Q766461',
#   'Q792006',
#   'Q904646',
#   'Q922337',
#   'Q934675',
#   'Q959769',
#   'Q980383',
#   'Q988736',
#   'Q1044408',
#   'Q1051805',
#   'Q1093290',
#   'Q1133096',
#   'Q1144423',
#   'Q1147128',
#   'Q1165850',
#   'Q1244764',
#   'Q1248877',
#   'Q1343310',
#   'Q1419463',
#   'Q1423158',
#   'Q1475928',
#   'Q1660902',
#   'Q1764519',
#   'Q1786674',
#   'Q1808586',
#   'Q1823485',
#   'Q1889053',
#   'Q1889346',
#   'Q1956258',
#   'Q2094724',
#   'Q2216381',
#   'Q2297117',
#   'Q2300910',
#   'Q2365138',
#   'Q2451473',
#   'Q2572376',
#   'Q2599780',
#   'Q2613413',
#   'Q2624504',
#   'Q2709639',
#   'Q2744331',
#   'Q2824470',
#   'Q2882376',
#   'Q2895785',
#   'Q2909502',
#   'Q2910789',
#   'Q2956018',
#   'Q2974434',
#   'Q2978671',
#   'Q3033215',
#   'Q3120694',
#   'Q3139624',
#   'Q3196048',
#   'Q3256872',
#   'Q3273394',
#   'Q3285538',
#   'Q3296114',
#   'Q3346604',
#   'Q3362060',
#   'Q3377400',
#   'Q3480675',
#   'Q3494249',
#   'Q3560503',
#   'Q3623687',
#   'Q4517166',
#   'Q4695064',
#   'Q5068327',
#   'Q5099012',
#   'Q5216205',
#   'Q6685124',
#   'Q7285748',
#   'Q7450625',
#   'Q8079924',
#   'Q12810474',
#   'Q13109778',
#   'Q14295311',
#   'Q16950185',
#   'Q16966446',
#   'Q16977296',
#   'Q17037930',
#   'Q17152331',
#   'Q21010028',
#   'Q21012217',
#   'Q21013802',
#   'Q21782861',
#   'Q25393850',
#   'Q31075152',
#   'Q47165627',
#   'Q48733111',
#   'Q52987174',
#   'Q56063219',
#   'Q56253877',
#   'Q57306162',
#   'Q57315360',
#   'Q60750638',
#   'Q65516030',
#   'Q77073277',
#   'Q81962448',
#   'Q82350983',
#   'Q82506229'],
#  'Q320002': ['Q1327157', 'Q2828910', 'Q2856400'],
#  'Q380616': ['Q11252023'],
#  'Q381651': ['Q940380'],
#  'Q582093': ['Q1786016'],
#  'Q646683': ['Q383826',
#   'Q415298',
#   'Q1047696',
#   'Q1327157',
#   'Q6577295',
#   'Q7360327',
#   'Q7360332'],
#  'Q831698': ['Q927078',
#   'Q978134',
#   'Q1414221',
#   'Q1424143',
#   'Q1574458',
#   'Q3440268',
#   'Q4947503',
#   'Q17011489'],
#  'Q862880': ['Q60630',
#   'Q264300',
#   'Q931470',
#   'Q1273117',
#   'Q1778683',
#   'Q1789202',
#   'Q11303163',
#   'Q17635986',
#   'Q61459923'],
#  'Q890073': ['Q244475', 'Q1322478', 'Q1574776', 'Q3269139', 'Q65075954'],
#  'Q908562': ['Q379637'],
#  'Q1112687': ['Q3571430'],
#  'Q1417866': ['Q1476554'],
#  'Q1433428': ['Q3002559', 'Q3329162', 'Q58327700'],
#  'Q1753848': ['Q1060750', 'Q1327157', 'Q2599170', 'Q23050178'],
#  'Q3152898': ['Q5994', 'Q362026', 'Q882033', 'Q21849594', 'Q22662103'],
#  'Q3268757': ['Q173900',
#   'Q426035',
#   'Q641534',
#   'Q734687',
#   'Q767833',
#   'Q1946637',
#   'Q2536440',
#   'Q2790815',
#   'Q3088595',
#   'Q3256715',
#   'Q3516190',
#   'Q3717397',
#   'Q6432217',
#   'Q6815765',
#   'Q6839692',
#   'Q6907261',
#   'Q6907270',
#   'Q7360301',
#   'Q10588857',
#   'Q17143830',
#   'Q17145154',
#   'Q30640838',
#   'Q30894627',
#   'Q56274779',
#   'Q56275448',
#   'Q56275651',
#   'Q56277852',
#   'Q65038641',
#   'Q65038771',
#   'Q65038826'],
#  'Q55722119': ['Q55722122', 'Q55722126'],
#  'Q55722130': ['Q427782', 'Q28933636'],
#  'Q47369': ['Q202094', 'Q1019744', 'Q25348503', 'Q26874923', 'Q55724861'],
#  'Q145840': ['Q59479456'],
#  'Q209554': ['Q3388256', 'Q7520842'],
#  'Q399597': ['Q336767',
#   'Q380979',
#   'Q593050',
#   'Q812043',
#   'Q849052',
#   'Q1478007',
#   'Q1527072',
#   'Q1585602',
#   'Q1595537',
#   'Q1740479',
#   'Q1757934',
#   'Q1975355',
#   'Q2131850',
#   'Q2822837',
#   'Q3435701',
#   'Q6926344',
#   'Q19650003',
#   'Q55725115',
#   'Q69694460'],
#  'Q494452': ['Q260703', 'Q834104', 'Q2532754', 'Q16553805'],
#  'Q1808578': ['Q1814870',
#   'Q3120694',
#   'Q3392660',
#   'Q15785423',
#   'Q27897491',
#   'Q27897593',
#   'Q30038759',
#   'Q55525195',
#   'Q87929050'],
#  'Q2338544': ['Q2339999', 'Q5737784'],
#  'Q2595197': ['Q59480046'],
#  'Q3504809': ['Q59510924'],
#  'Q3514744': ['Q1158229', 'Q3729520', 'Q55723918', 'Q55723921'],
#  'Q3732881': ['Q12367621'],
#  'Q5276177': ['Q954204',
#   'Q6432218',
#   'Q55739005',
#   'Q55739010',
#   'Q55739014',
#   'Q55739017'],
#  'Q5280487': ['Q891935',
#   'Q1283177',
#   'Q1555833',
#   'Q1606685',
#   'Q4940751',
#   'Q5193170',
#   'Q7022514'],
#  'Q6025130': ['Q1644824', 'Q2132068', 'Q55722145'],
#  'Q19462049': ['Q104363', 'Q915689', 'Q19589361', 'Q30038792'],
#  'Q53829839': ['Q1376492', 'Q53830131'],
#  'Q55722217': ['Q55722221', 'Q55722232'],
#  'Q55722796': ['Q55722801', 'Q55722815'],
#  'Q55722819': ['Q55722823', 'Q55722857'],
#  'Q55722887': ['Q290688'],
#  'Q55722893': ['Q55722898', 'Q55722902'],
#  'Q55722906': ['Q55722909', 'Q55722912'],
#  'Q55724586': ['Q381629'],
#  'Q55724975': ['Q585969',
#   'Q1703491',
#   'Q3623687',
#   'Q16911842',
#   'Q29918192',
#   'Q55724982',
#   'Q55724987'],
#  'Q55738960': ['Q78987',
#   'Q186496',
#   'Q685663',
#   'Q1099153',
#   'Q1187260',
#   'Q1273167',
#   'Q1527836',
#   'Q2613413',
#   'Q7190594'],
#  'Q55738962': ['Q1091033'],
#  'Q8350': ['Q1829398',
#   'Q7516594',
#   'Q13194854',
#   'Q28536659',
#   'Q29042985',
#   'Q46996061',
#   'Q94698273',
#   'Q94698365'],
#  'Q27914': ['Q359278',
#   'Q359282',
#   'Q1062991',
#   'Q1471878',
#   'Q1601762',
#   'Q1711349',
#   'Q1873389',
#   'Q2176240',
#   'Q2338646',
#   'Q3312506',
#   'Q3983766',
#   'Q5492408',
#   'Q5885030',
#   'Q6141658',
#   'Q6141661',
#   'Q6141663',
#   'Q21002493',
#   'Q54635368',
#   'Q54635391',
#   'Q54635582',
#   'Q54635669',
#   'Q64698592'],
#  'Q30903': ['Q58192',
#   'Q836983',
#   'Q1401208',
#   'Q1999862',
#   'Q2164335',
#   'Q2327598',
#   'Q3312506',
#   'Q3822738',
#   'Q3964985',
#   'Q3964989',
#   'Q3964990',
#   'Q3964991',
#   'Q5681011',
#   'Q53828789',
#   'Q53829462',
#   'Q53829839',
#   'Q53830255',
#   'Q54556150'],
#  'Q58192': ['Q3964988', 'Q37952097', 'Q53828775', 'Q53828951'],
#  'Q478634': ['Q656696',
#   'Q1236478',
#   'Q1802897',
#   'Q2723974',
#   'Q3469620',
#   'Q16519124',
#   'Q20850789',
#   'Q28223045',
#   'Q55738651',
#   'Q55738660',
#   'Q55738689'],
#  'Q836983': ['Q53828788'],
#  'Q1146067': ['Q3413904', 'Q104696501'],
#  'Q1401208': ['Q37952097'],
#  'Q2164335': ['Q3964988', 'Q53828951'],
#  'Q2661289': ['Q615403', 'Q1672931', 'Q2723974'],
#  'Q3312506': ['Q2327598', 'Q54635582'],
#  'Q11853199': ['Q1342193', 'Q2911343', 'Q5941969'],
#  'Q54819588': ['Q205234', 'Q54819544', 'Q55725025'],
#  'Q55722937': ['Q1426827'],
#  'Q55738515': ['Q55738518', 'Q55738520'],
#  'Q55738528': ['Q1879241', 'Q11853199', 'Q16875637', 'Q55738635', 'Q55738636'],
#  'Q61285': ['Q6488062', 'Q7315754', 'Q94994656', 'Q94994658', 'Q94994660'],
#  'Q201129': ['Q18451574'],
#  'Q959769': ['Q863302', 'Q6893623', 'Q22137142', 'Q56063219', 'Q56651492'],
#  'Q1044408': ['Q204482', 'Q81962448'],
#  'Q1093290': ['Q2542042', 'Q25451376'],
#  'Q1343310': ['Q5375216'],
#  'Q1423158': ['Q338463', 'Q818845', 'Q866288', 'Q903376', 'Q1002233'],
#  'Q1823485': ['Q13199436', 'Q13199437', 'Q73792461'],
#  'Q2300910': ['Q56054583'],
#  'Q10969818': ['Q10259047', 'Q12060981'],
#  'Q22329414': ['Q40125',
#   'Q570544',
#   'Q595730',
#   'Q742180',
#   'Q1095029',
#   'Q1628064',
#   'Q16910024',
#   'Q102278359'],
#  'Q57050725': ['Q8355',
#   'Q8371',
#   'Q80019',
#   'Q80284',
#   'Q178933',
#   'Q182718',
#   'Q361424',
#   'Q521151',
#   'Q584967',
#   'Q608650',
#   'Q638182',
#   'Q692640',
#   'Q830863',
#   'Q1094813',
#   'Q1243782',
#   'Q1365097',
#   'Q1572629',
#   'Q4867994',
#   'Q6435369',
#   'Q12060981',
#   'Q15838637'],
#  'Q57315384': ['Q60689',
#   'Q348878',
#   'Q369556',
#   'Q623509',
#   'Q669370',
#   'Q726306',
#   'Q737520',
#   'Q1078965',
#   'Q1095084',
#   'Q1130464',
#   'Q1420096',
#   'Q1818847',
#   'Q2606162',
#   'Q3622278',
#   'Q5277044',
#   'Q10259047'],
#  'Q87929050': ['Q510487'],
#  'Q8338': ['Q403800',
#   'Q1435054',
#   'Q1490771',
#   'Q1554099',
#   'Q1684559',
#   'Q2143787',
#   'Q2242097',
#   'Q2916053',
#   'Q3540298',
#   'Q10403797',
#   'Q10594045',
#   'Q12950623',
#   'Q55648738',
#   'Q65229823'],
#  'Q264376': ['Q1327396'],
#  'Q379269': ['Q143905',
#   'Q286502',
#   'Q681825',
#   'Q925985',
#   'Q1026087',
#   'Q1999898',
#   'Q2341903',
#   'Q4408428',
#   'Q4501563',
#   'Q20524414'],
#  'Q882090': ['Q680486'],
#  'Q1527709': ['Q3601141'],
#  'Q1628293': ['Q2995990'],
#  'Q1662735': ['Q808574',
#   'Q850613',
#   'Q938353',
#   'Q943488',
#   'Q996531',
#   'Q1003249',
#   'Q1082843',
#   'Q1265690',
#   'Q1798537',
#   'Q2606377',
#   'Q3929958',
#   'Q5389648',
#   'Q12339842',
#   'Q20523126',
#   'Q55738902',
#   'Q81028971'],
#  'Q26874923': ['Q55724937', 'Q55724960'],
#  'Q55724861': ['Q55724865', 'Q55724880'],
#  'Q55738916': ['Q749247', 'Q2786107', 'Q55738917', 'Q55738923', 'Q55738924'],
#  'Q64160820': ['Q3198941'],
#  'Q260703': ['Q1052647', 'Q1427250', 'Q3927277', 'Q3980121', 'Q19378483'],
#  'Q834104': ['Q1088910',
#   'Q1243409',
#   'Q2899714',
#   'Q3053322',
#   'Q3404720',
#   'Q51858933',
#   'Q56707502',
#   'Q59312240'],
#  'Q849052': ['Q8070986'],
#  'Q940380': ['Q608223'],
#  'Q1786016': ['Q301934'],
#  'Q2532754': ['Q10427702'],
#  'Q6926344': ['Q15849628'],
#  'Q16553805': ['Q749516',
#   'Q932249',
#   'Q1107393',
#   'Q1537595',
#   'Q1746134',
#   'Q1756136',
#   'Q2133569',
#   'Q2345056',
#   'Q3698146',
#   'Q4828015',
#   'Q17051677',
#   'Q27617339',
#   'Q56839489',
#   'Q60455964',
#   'Q100250703',
#   'Q105376441'],
#  'Q19650003': ['Q51290',
#   'Q162992',
#   'Q215032',
#   'Q336767',
#   'Q512191',
#   'Q1595537',
#   'Q2029807',
#   'Q2227437',
#   'Q3009831',
#   'Q12460259'],
#  'Q55725115': ['Q1115244'],
#  'Q57306162': ['Q6607',
#   'Q258896',
#   'Q585289',
#   'Q751884',
#   'Q804161',
#   'Q810475',
#   'Q1328494',
#   'Q1445371',
#   'Q1683429',
#   'Q1751664',
#   'Q1860805',
#   'Q7699116',
#   'Q73405507'],
#  'Q57315360': ['Q74207',
#   'Q120031',
#   'Q191000',
#   'Q229205',
#   'Q268329',
#   'Q302497',
#   'Q516397',
#   'Q687406',
#   'Q717773',
#   'Q807780',
#   'Q941492',
#   'Q1164636',
#   'Q1236973',
#   'Q1640934',
#   'Q1889070',
#   'Q2216785',
#   'Q17091232'],
#  'Q65516030': ['Q180733',
#   'Q468776',
#   'Q840920',
#   'Q1137869',
#   'Q2651987',
#   'Q2946292',
#   'Q7602177'],
#  'Q185626': ['Q8343',
#   'Q8345',
#   'Q393004',
#   'Q646920',
#   'Q810511',
#   'Q810515',
#   'Q1060334',
#   'Q1227174',
#   'Q1366388',
#   'Q1437981',
#   'Q1543785',
#   'Q1783263',
#   'Q1888789',
#   'Q2482031',
#   'Q6517474',
#   'Q7563204',
#   'Q55738869',
#   'Q55738875',
#   'Q63619194',
#   'Q98647213',
#   'Q98654724',
#   'Q104521646'],
#  'Q244475': ['Q44547979'],
#  'Q426035': ['Q56274779'],
#  'Q1087611': ['Q804099', 'Q2249425'],
#  'Q1322478': ['Q814696', 'Q1574776', 'Q6393214', 'Q25711740'],
#  'Q1778683': ['Q2222875'],
#  'Q1814870': ['Q201129',
#   'Q539942',
#   'Q790312',
#   'Q3346604',
#   'Q16938294',
#   'Q55724800',
#   'Q55724804'],
#  'Q2152657': ['Q8347',
#   'Q123526',
#   'Q196318',
#   'Q259556',
#   'Q411553',
#   'Q425748',
#   'Q540887',
#   'Q594256',
#   'Q737917',
#   'Q796273',
#   'Q840638',
#   'Q842190',
#   'Q847911',
#   'Q901239',
#   'Q930367',
#   'Q949708',
#   'Q1128412',
#   'Q1179086',
#   'Q1195575',
#   'Q1328415',
#   'Q1611652',
#   'Q1724468',
#   'Q1755559',
#   'Q2096912',
#   'Q2451599',
#   'Q3528106',
#   'Q3556433',
#   'Q3636033',
#   'Q5771718',
#   'Q10564296',
#   'Q11434792',
#   'Q19896195',
#   'Q55738828',
#   'Q55738862',
#   'Q56294647'],
#  'Q2339999': ['Q5737784'],
#  'Q11303163': ['Q6907278'],
#  'Q30038759': ['Q322050',
#   'Q1051805',
#   'Q1809626',
#   'Q55724811',
#   'Q55724833',
#   'Q55724846'],
#  'Q50362275': ['Q1760502'],
#  'Q55723921': ['Q55723926', 'Q55723936', 'Q55723949', 'Q55723960'],
#  'Q55738876': ['Q55738877', 'Q55738888', 'Q55738889'],
#  'Q55738890': ['Q55738891', 'Q55738892'],
#  'Q58327700': ['Q3329162'],
#  'Q78987': ['Q58228',
#   'Q161266',
#   'Q208173',
#   'Q248927',
#   'Q287028',
#   'Q322625',
#   'Q384486',
#   'Q544437',
#   'Q598668',
#   'Q599105',
#   'Q623103',
#   'Q741440',
#   'Q835670',
#   'Q835795',
#   'Q897770',
#   'Q898248',
#   'Q901802',
#   'Q912249',
#   'Q935171',
#   'Q940380',
#   'Q1099184',
#   'Q1334769',
#   'Q1523022',
#   'Q1629178',
#   'Q1785930',
#   'Q2661834',
#   'Q3105372',
#   'Q3266401',
#   'Q3717479',
#   'Q3742419',
#   'Q3742424',
#   'Q3764000',
#   'Q3764002',
#   'Q3783325',
#   'Q3935028',
#   'Q3935031',
#   'Q3967462',
#   'Q3967465',
#   'Q3967468',
#   'Q3987462',
#   'Q4041761',
#   'Q4355994',
#   'Q4992976',
#   'Q5324315',
#   'Q5443269',
#   'Q5443279',
#   'Q6117810',
#   'Q6907264',
#   'Q11877740',
#   'Q17107352',
#   'Q19926561',
#   'Q21234987',
#   'Q41795428',
#   'Q64166304',
#   'Q66314525',
#   'Q99902121'],
#  'Q185003': ['Q2442891',
#   'Q3327567',
#   'Q5533138',
#   'Q6434803',
#   'Q8032597',
#   'Q13399266',
#   'Q16849057',
#   'Q55722167',
#   'Q55722172',
#   'Q68647735'],
#  'Q205234': ['Q695738', 'Q25111662', 'Q30590490'],
#  'Q213461': ['Q182999', 'Q4335803'],
#  'Q381629': ['Q14527921'],
#  'Q669610': ['Q3321167'],
#  'Q915689': ['Q12620014'],
#  'Q1273167': ['Q5647435'],
#  'Q1283177': ['Q203861',
#   'Q244976',
#   'Q816793',
#   'Q3033439',
#   'Q3181140',
#   'Q3980641',
#   'Q16973705',
#   'Q55723465',
#   'Q55723476'],
#  'Q1555833': ['Q936590',
#   'Q3142190',
#   'Q3773253',
#   'Q5161032',
#   'Q5199281',
#   'Q5913432',
#   'Q13219842',
#   'Q55723246',
#   'Q55723287',
#   'Q55723416',
#   'Q55723458'],
#  'Q1606685': ['Q55723166', 'Q55723171'],
#  'Q1630744': ['Q2478767', 'Q3559312', 'Q55724600', 'Q55724611'],
#  'Q1703491': ['Q2197997', 'Q29918192'],
#  'Q2132068': ['Q39777',
#   'Q1024685',
#   'Q1542137',
#   'Q2904003',
#   'Q5764117',
#   'Q8210684',
#   'Q15155966',
#   'Q16058159',
#   'Q16545960',
#   'Q28944896',
#   'Q29043034',
#   'Q55722090',
#   'Q55722102',
#   'Q55722112'],
#  'Q2227437': ['Q4592185'],
#  'Q19589361': ['Q930342',
#   'Q1400830',
#   'Q6703366',
#   'Q55720616',
#   'Q55720619',
#   'Q55720623',
#   'Q55720626',
#   'Q55721707'],
#  'Q30038792': ['Q1074981',
#   'Q1118321',
#   'Q1744337',
#   'Q3806379',
#   'Q3891158',
#   'Q5581711',
#   'Q5647544',
#   'Q5705315',
#   'Q6435369',
#   'Q8015183',
#   'Q55721717',
#   'Q55721721',
#   'Q55721724',
#   'Q55721729',
#   'Q55722061',
#   'Q76375798',
#   'Q76375872'],
#  'Q54819544': ['Q55738514', 'Q55773741'],
#  'Q55722122': ['Q1394579'],
#  'Q55722186': ['Q5995811', 'Q55722190', 'Q55722194'],
#  'Q55722232': ['Q655389', 'Q55722235', 'Q55722239'],
#  'Q55722857': ['Q457992', 'Q917571', 'Q1413983'],
#  'Q55724322': ['Q55724326', 'Q55724330', 'Q55724333'],
#  'Q55724342': ['Q9097454', 'Q62973838'],
#  'Q55724561': ['Q55724566', 'Q55724570'],
#  'Q55724671': ['Q55724674', 'Q55724679', 'Q105394052'],
#  'Q55724692': ['Q55724696', 'Q55724700'],
#  'Q55724710': ['Q55724718'],
#  'Q55724736': ['Q55724739', 'Q55724742'],
#  'Q55724752': ['Q55724755', 'Q55724759'],
#  'Q55724771': ['Q55724767'],
#  'Q55724982': ['Q1703491', 'Q2909502', 'Q29918192'],
#  'Q55725025': ['Q399597', 'Q55725029', 'Q55725032', 'Q55725076', 'Q55725172'],
#  'Q55738520': ['Q1500255'],
#  'Q55738978': ['Q207691', 'Q490054', 'Q639717', 'Q862501', 'Q2978687'],
#  'Q55738979': ['Q55738980', 'Q55738982', 'Q55738991'],
#  'Q55738998': ['Q55738999', 'Q55739000'],
#  'Q55739005': ['Q55739007', 'Q55739008'],
#  'Q55739010': ['Q2856400', 'Q55739011', 'Q55739013'],
#  'Q55739014': ['Q55739015', 'Q55739016'],
#  'Q55739017': ['Q55739018', 'Q55739020'],
#  'Q12521411': ['Q56196958'],
#  'Q15212740': ['Q790468'],
#  'Q16133280': ['Q6560884'],
#  'Q16678513': ['Q178389',
#   'Q854664',
#   'Q941492',
#   'Q1147128',
#   'Q1195473',
#   'Q1437981',
#   'Q3622278',
#   'Q4229054',
#   'Q4244288',
#   'Q4410905',
#   'Q4852742'],
#  'Q16918224': ['Q12486669'],
#  'Q17172850': ['Q27911',
#   'Q31687',
#   'Q37137',
#   'Q186506',
#   'Q210970',
#   'Q223166',
#   'Q1067089',
#   'Q6164901',
# ...
#   'Q24196576',
#   'Q48877774',
#   'Q55185569',
#   'Q98457398',
#   'Q99902121'],
#  'Q31561': ['Q424017',
#   'Q719120',
#   'Q930531',
#   'Q1051615',
#   'Q2563510',
#   'Q4167999',
#   'Q5559305',
#   'Q5559315'],
#  'Q180733': ['Q370534',
#   'Q516559',
#   'Q645977',
#   'Q1021853',
#   'Q1143814',
#   'Q1255766',
#   'Q1321111',
#   'Q1543978',
#   'Q1544746',
#   'Q1633881',
#   'Q1774380',
#   'Q1889081',
#   'Q2372387',
#   'Q2957508',
#   'Q3038397',
#   'Q3108592',
#   'Q3111551',
#   'Q3129376',
#   'Q3194948',
#   'Q3256872',
#   'Q3267861',
#   'Q3482621',
#   'Q3528038',
#   'Q4854663',
#   'Q5719028',
#   'Q6450485',
#   'Q7450625',
#   'Q10684877',
#   'Q15717974',
#   'Q16837625',
#   'Q42912610',
#   'Q86727408',
#   'Q95690299',
#   'Q105273680'],
#  'Q83509': ['Q1428152'],
#  'Q101401': ['Q384459',
#   'Q395212',
#   'Q508113',
#   'Q862131',
#   'Q1123573',
#   'Q1225366',
#   'Q1236988',
#   'Q1532134',
#   'Q1804457',
#   'Q2290944',
#   'Q2425278',
#   'Q2599704',
#   'Q3443123',
#   'Q3500690',
#   'Q4883306',
#   'Q5194721',
#   'Q7651136',
#   'Q11180044',
#   'Q11648241',
#   'Q11773837',
#   'Q12045376',
#   'Q15789092',
#   'Q16486668',
#   'Q18169117',
#   'Q31842594',
#   'Q43385258',
#   'Q55721738',
#   'Q55721745',
#   'Q65965707',
#   'Q96309259'],
#  'Q165666': ['Q415058',
#   'Q789141',
#   'Q2356567',
#   'Q2631432',
#   'Q4201135',
#   'Q7365592',
#   'Q15852398'],
#  'Q183932': ['Q1879664', 'Q16657095'],
#  'Q190172': ['Q93992',
#   'Q203449',
#   'Q491453',
#   'Q2045021',
#   'Q2066397',
#   'Q2371907',
#   'Q4220665',
#   'Q5182316',
#   'Q5347295',
#   'Q5647142',
#   'Q7206087',
#   'Q7649196',
#   'Q7658823',
#   'Q10375408'],
#  'Q208320': ['Q843271',
#   'Q1129755',
#   'Q1538345',
#   'Q1791487',
#   'Q3548238',
#   'Q6387169',
#   'Q6610630',
#   'Q11650198',
#   'Q12475687',
#   'Q28949019',
#   'Q55721731',
#   'Q55721734'],
#  'Q218802': ['Q83489',
#   'Q1414230',
#   'Q4244288',
#   'Q6585167',
#   'Q10902606',
#   'Q12811888',
#   'Q18161788',
#   'Q55738588',
#   'Q55738592',
#   'Q55738593'],
#  'Q626035': ['Q5555619'],
#  'Q628428': ['Q604538',
#   'Q957212',
#   'Q2081927',
#   'Q3393157',
#   'Q4694587',
#   'Q5350631',
#   'Q5996169',
#   'Q16831511',
#   'Q105840309'],
#  'Q830763': ['Q4900300', 'Q27333783', 'Q29533335'],
#  'Q892076': ['Q7476405', 'Q12476900', 'Q13092219'],
#  'Q945405': ['Q830763'],
#  'Q1076223': ['Q356887', 'Q384324', 'Q681251', 'Q1009927'],
#  'Q1143818': ['Q5559282'],
#  'Q1165766': ['Q626035',
#   'Q849667',
#   'Q892076',
#   'Q2640100',
#   'Q2991844',
#   'Q4262704',
#   'Q5521203',
#   'Q5618779',
#   'Q6415141',
#   'Q8015157',
#   'Q66829666',
#   'Q66829670'],
#  'Q4951628': ['Q5994',
#   'Q81982',
#   'Q191823',
#   'Q204482',
#   'Q255358',
#   'Q262414',
#   'Q370915',
#   'Q372308',
#   'Q419896',
#   'Q877239',
#   'Q904646',
#   'Q922337',
#   'Q1044408',
#   'Q1098974',
#   'Q1124573',
#   'Q1136653',
#   'Q1588017',
#   'Q1805401',
#   'Q1823485',
#   'Q2145031',
#   'Q2365138',
#   'Q2405825',
#   'Q2744331',
#   'Q3354977',
#   'Q3362451',
#   'Q4852742',
#   'Q5676660',
#   'Q6121180',
#   'Q7578333',
#   'Q7838128',
#   'Q13199436',
#   'Q13199437',
#   'Q18391628',
#   'Q22662103',
#   'Q73792461',
#   'Q81962448',
#   'Q82350983'],
#  'Q8084116': ['Q829729', 'Q987843', 'Q6685124', 'Q16255463'],
#  'Q55722098': ['Q426948'],
#  'Q55722108': ['Q540049'],
#  'Q55723249': ['Q55723253', 'Q55723256'],
#  'Q55723259': ['Q20427331', 'Q40447413', 'Q55723264', 'Q55723274'],
#  'Q55723291': ['Q55723295', 'Q55723299'],
#  'Q55723303': ['Q55723306', 'Q55723318'],
#  'Q55723420': ['Q55723424', 'Q55723427'],
#  'Q55723431': ['Q55723435', 'Q55723447'],
#  'Q55723469': ['Q193666', 'Q11084057', 'Q17057067'],
#  'Q55723472': ['Q255273'],
#  'Q55724615': ['Q55157360', 'Q55724629'],
#  'Q55724660': ['Q55724664', 'Q55724667'],
#  'Q55724683': ['Q8069980', 'Q15851679'],
#  'Q55724686': ['Q863302'],
#  'Q55724815': ['Q290951',
#   'Q389949',
#   'Q664055',
#   'Q1321111',
#   'Q3049642',
#   'Q3869301',
#   'Q8079915',
#   'Q55724819',
#   'Q55724823',
#   'Q85134374'],
#  'Q55724825': ['Q241337', 'Q249105', 'Q579484'],
#  'Q55724830': ['Q284532', 'Q922001', 'Q976650'],
#  'Q55724836': ['Q171253',
#   'Q178389',
#   'Q207821',
#   'Q322675',
#   'Q356330',
#   'Q717773',
#   'Q748420',
#   'Q829729',
#   'Q980383',
#   'Q1246482',
#   'Q1633881',
#   'Q2216381',
#   'Q2660670',
#   'Q3424319',
#   'Q3545453',
#   'Q5099012',
#   'Q18449477',
#   'Q57315360',
#   'Q57315384',
#   'Q65516030'],
#  'Q322625': ['Q3448320',
#   'Q3830846',
#   'Q4993471',
#   'Q5559370',
#   'Q5559371',
#   'Q5559379',
#   'Q10855932'],
#  'Q695738': ['Q1428501', 'Q76922491', 'Q76922747', 'Q76923197', 'Q76923428'],
#  'Q935171': ['Q1143818', 'Q1347244', 'Q1523008', 'Q1523013', 'Q5383149'],
#  'Q55722172': ['Q55722175', 'Q55722179'],
#  'Q55738869': ['Q55738870', 'Q55738874'],
#  'Q55738875': ['Q8347',
#   'Q229717',
#   'Q313053',
#   'Q646920',
#   'Q1024962',
#   'Q1046018',
#   'Q1247912',
#   'Q1543785',
#   'Q2598017',
#   'Q3905918'],
#  'Q63619194': ['Q776563'],
#  'Q55738828': ['Q1398629', 'Q55738830', 'Q55738860'],
#  'Q55738862': ['Q1124382', 'Q3905918', 'Q55738863', 'Q55738864'],
#  'Q55724846': ['Q55724850', 'Q55724854'],
#  'Q55724865': ['Q339306',
#   'Q3339324',
#   'Q3605859',
#   'Q4752984',
#   'Q5375216',
#   'Q55724870',
#   'Q55724873',
#   'Q55724876',
#   'Q104996348'],
#  'Q55724880': ['Q60517',
#   'Q2670360',
#   'Q2956018',
#   'Q4942171',
#   'Q6532301',
#   'Q30038873'],
#  'Q55725029': ['Q5284752', 'Q55725101'],
#  'Q55725032': ['Q55725036', 'Q55725039'],
#  'Q55738514': ['Q666971', 'Q7993828'],
#  'Q55738635': ['Q81026716'],
#  'Q55738636': ['Q55738637', 'Q55738647'],
#  'Q55738892': ['Q5429274'],
#  'Q55738917': ['Q200823',
#   'Q204638',
#   'Q742168',
#   'Q55738918',
#   'Q55738921',
#   'Q55738922'],
#  'Q55738924': ['Q403800', 'Q55738926', 'Q55738940', 'Q55774273'],
#  'Q55738982': ['Q55738984', 'Q55738986'],
#  'Q55738999': ['Q25000099'],
#  'Q55739008': ['Q139300'],
#  'Q55773741': ['Q2566774'],
#  'Q229205': ['Q11877740', 'Q61054536'],
#  'Q258896': ['Q2755228', 'Q4855834', 'Q12785442', 'Q94771465'],
#  'Q510487': ['Q6442505', 'Q17085087', 'Q49566348', 'Q84307929'],
#  'Q678090': ['Q7076779', 'Q56054583'],
#  'Q1812862': ['Q1740329'],
#  'Q2096201': ['Q948603', 'Q6117810'],
#  'Q2617520': ['Q587027', 'Q5163252'],
#  'Q5348940': ['Q4955628'],
#  'Q5272139': ['Q10297761'],
#  'Q84307929': ['Q623509', 'Q1246482', 'Q3033074', 'Q15842338'],
#  'Q98457398': ['Q1683429', 'Q6524983', 'Q7314870'],
#  'Q1516264': ['Q3925792', 'Q3925799'],
#  'Q2255516': ['Q3388256'],
#  'Q2645536': ['Q3705108', 'Q3705109'],
#  'Q6436135': ['Q61278249', 'Q61285936', 'Q61314309'],
#  'Q55721718': ['Q201735'],
#  'Q55721719': ['Q452030', 'Q789141', 'Q1264755', 'Q5515287'],
#  'Q55721722': ['Q748455'],
#  'Q55721723': ['Q320341', 'Q849667', 'Q1514705', 'Q1704079', 'Q8079928'],
#  'Q55721727': ['Q178812', 'Q7850717'],
#  'Q55722057': ['Q3429366'],
#  'Q55723181': ['Q55723185', 'Q55723197'],
#  'Q55723210': ['Q55723216', 'Q55723232'],
#  'Q55723332': ['Q55723336', 'Q55723339'],
#  'Q55723342': ['Q55723345', 'Q55723358'],
#  'Q55723375': ['Q55723379', 'Q55723383'],
#  'Q55723387': ['Q55723390', 'Q55723402'],
#  'Q55738595': ['Q55738597', 'Q55738601', 'Q55738602'],
#  'Q55738609': ['Q55738610', 'Q55738611'],
#  'Q55738894': ['Q55738896', 'Q55738897'],
#  'Q55774135': ['Q1999077',
#   'Q3491104',
#   'Q4229054',
#   'Q5462362',
#   'Q5462363',
#   'Q5504567',
#   'Q6379590',
#   'Q7090791',
#   'Q19938802',
#   'Q55738577',
#   'Q55738580',
#   'Q55738584'],
#  'Q76922491': ['Q4650511',
#   'Q4650514',
#   'Q7992392',
#   'Q17155778',
#   'Q76929499',
#   'Q76932609',
#   'Q76933027',
#   'Q76933289',
#   'Q76934343',
#   'Q76936262',
#   'Q76936540',
#   'Q76938619',
#   'Q76938856',
#   'Q77033850',
#   'Q77034259',
#   'Q77061796'],
#  'Q76922747': ['Q4650511',
#   'Q4650513',
#   'Q4650514',
#   'Q5439989',
#   'Q17155778',
#   'Q76929499',
#   'Q76930110',
#   'Q76932609',
#   'Q76933027',
#   'Q76933289',
#   'Q76935385',
#   'Q76936262',
#   'Q76936540',
#   'Q76937168',
#   'Q76937752',
#   'Q76938365',
#   'Q76939765',
#   'Q77033850',
#   'Q77034259',
#   'Q77057127',
#   'Q77058618',
#   'Q77061796'],
#  'Q55724840': ['Q508805',
#   'Q611259',
#   'Q665657',
#   'Q806351',
#   'Q963150',
#   'Q1588132',
#   'Q1788910',
#   'Q2542042',
#   'Q2563510',
#   'Q5065645',
#   'Q5288710',
#   'Q6810507',
#   'Q7077068',
#   'Q7531430',
#   'Q13580448',
#   'Q16950185',
#   'Q25091993',
#   'Q51446928',
#   'Q57050725',
#   'Q57306162'],
#  'Q55724941': ['Q698605', 'Q3623688', 'Q4795697'],
#  'Q55724944': ['Q19572214', 'Q55724952', 'Q55724957'],
#  'Q55724964': ['Q1288250', 'Q3623687'],
#  'Q55724967': ['Q1231959', 'Q2687005'],
#  'Q55738637': ['Q55738639', 'Q55738643'],
#  'Q55738647': ['Q55738648', 'Q55738649'],
#  'Q55738652': ['Q55738653', 'Q55738657', 'Q55738658'],
#  'Q55738661': ['Q568883',
#   'Q5259641',
#   'Q55738662',
#   'Q55738667',
#   'Q55738669',
#   'Q55738675'],
#  'Q55738681': ['Q55738682', 'Q55738686', 'Q55738687', 'Q55738688'],
#  'Q55738830': ['Q675382', 'Q1753689', 'Q55738856', 'Q55738859'],
#  'Q55738860': ['Q8347',
#   'Q83513',
#   'Q159998',
#   'Q230471',
#   'Q677921',
#   'Q808215',
#   'Q863876',
#   'Q911038',
#   'Q1024962',
#   'Q1127899',
#   'Q1264870',
#   'Q2096912',
#   'Q3636033',
#   'Q3869274',
#   'Q7110008',
#   'Q7700581',
#   'Q15294559',
#   'Q42889517',
#   'Q82111555'],
#  'Q55738863': ['Q2035157', 'Q46190664'],
#  'Q55738864': ['Q145971', 'Q281460', 'Q7661431', 'Q82742085', 'Q82742718'],
#  'Q55738870': ['Q55738871', 'Q55738872'],
#  'Q159998': ['Q3689094'],
#  'Q207821': ['Q874501', 'Q890870', 'Q17088628', 'Q58878971'],
#  'Q322675': ['Q528239'],
#  'Q677921': ['Q540887', 'Q1818477', 'Q12158805', 'Q82126834'],
#  'Q1231959': ['Q988742'],
#  'Q11084057': ['Q6012653'],
#  'Q19572214': ['Q2542348'],
#  'Q55157360': ['Q55724621', 'Q55724625'],
#  'Q55723264': ['Q55723268', 'Q55723271'],
#  'Q55723274': ['Q55723278', 'Q55723282'],
#  'Q55723306': ['Q55723310', 'Q55723314'],
#  'Q55723318': ['Q55723322', 'Q55723325'],
#  'Q55723345': ['Q55723350', 'Q55723355'],
#  'Q55723358': ['Q55723363', 'Q55723367'],
#  'Q55723379': ['Q2655327', 'Q4077510'],
#  'Q55723383': ['Q243998'],
#  'Q55723390': ['Q55723395', 'Q55723398'],
#  'Q55723402': ['Q55723405', 'Q55723409'],
#  'Q55723435': ['Q55723439', 'Q55723443'],
#  'Q55723447': ['Q55723451', 'Q55723455'],
#  'Q55724629': ['Q55724632', 'Q55724639'],
#  'Q55724952': ['Q2353374'],
#  'Q55724957': ['Q2542348'],
#  'Q55738597': ['Q5953170', 'Q55738598', 'Q55738599'],
#  'Q55738602': ['Q55738604', 'Q55738608'],
#  'Q55738639': ['Q55738640', 'Q55738641'],
#  'Q55738643': ['Q55738644', 'Q55738646'],
#  'Q55738653': ['Q55738654', 'Q55738655'],
#  'Q55738662': ['Q841005', 'Q55738663', 'Q55738665'],
#  'Q55738669': ['Q55738671', 'Q55738674'],
#  'Q55738675': ['Q339359', 'Q55738676', 'Q55738677'],
#  'Q55738682': ['Q55738684', 'Q55738685'],
#  'Q55738859': ['Q324299', 'Q425748', 'Q930367', 'Q1046018', 'Q17082043'],
#  'Q131168': ['Q495529', 'Q7630969'],
#  'Q163759': ['Q790468',
#   'Q2568945',
#   'Q2579099',
#   'Q6053155',
#   'Q25043174',
#   'Q96100101',
#   'Q97477525'],
#  'Q1757829': ['Q189388',
#   'Q778999',
#   'Q3565271',
#   'Q55738911',
#   'Q55738912',
#   'Q98381333'],
#  'Q42889517': ['Q8377',
#   'Q8380',
#   'Q185041',
#   'Q411553',
#   'Q602719',
#   'Q808215',
#   'Q1571002',
#   'Q1760274',
#   'Q5165635',
#   'Q7198510',
#   'Q15730895'],
#  'Q55738577': ['Q55738559', 'Q55738578', 'Q55738579'],
#  'Q55738580': ['Q55738581', 'Q55738583'],
#  'Q55738584': ['Q55738585', 'Q55738586'],
#  'Q55738871': ['Q863876', 'Q3869274'],
#  'Q55738872': ['Q8343',
#   'Q8345',
#   'Q390570',
#   'Q656766',
#   'Q745769',
#   'Q810511',
#   'Q810515',
#   'Q961470',
#   'Q1366388',
#   'Q2731509',
#   'Q4222986',
#   'Q6517474',
#   'Q56299622',
#   'Q98647213',
#   'Q98654724',
#   'Q104521646'],
#  'Q55738897': ['Q2479786'],
#  'Q55738904': ['Q55738905', 'Q55738909'],
#  'Q55738915': ['Q81028971'],
#  'Q55738928': ['Q55738929', 'Q55738931'],
#  'Q55738944': ['Q157420', 'Q787557', 'Q3976676'],
#  'Q8377': ['Q1542022', 'Q1818477', 'Q7999138', 'Q100540479'],
#  'Q504847': ['Q21099529'],
#  'Q778999': ['Q21009822'],
#  'Q1073120': ['Q1621499', 'Q66553333'],
#  'Q55721739': ['Q775570'],
#  'Q55721740': ['Q55721741', 'Q55721743', 'Q55721744'],
#  'Q55722035': ['Q1233386'],
#  'Q55722039': ['Q55722043', 'Q55722046', 'Q55722049'],
#  'Q55723221': ['Q208421', 'Q2781273'],
#  'Q55723227': ['Q1178361'],
#  'Q55723238': ['Q128309'],
#  'Q55723350': ['Q5842724'],
#  'Q55723439': ['Q28933634'],
#  'Q55724621': ['Q6169915', 'Q25697298'],
#  'Q55724639': ['Q55724643', 'Q55724653'],
#  'Q55738579': ['Q2383880', 'Q7127046', 'Q7565100'],
#  'Q55738581': ['Q55738582'],
#  'Q55738583': ['Q444037'],
#  'Q55738590': ['Q905244', 'Q2852614', 'Q4244288', 'Q6149665'],
#  'Q55738599': ['Q684058', 'Q1760249'],
#  'Q55738604': ['Q55738605', 'Q55738607'],
#  'Q55738641': ['Q524526', 'Q7127113'],
#  'Q55738644': ['Q55738645'],
#  'Q55738655': ['Q11787', 'Q2372035', 'Q2997443', 'Q3716790', 'Q95975568'],
#  'Q55738911': ['Q1335907', 'Q1679135', 'Q3929958'],
#  'Q55738912': ['Q778999'],
#  'Q187851': ['Q1494285',
#   'Q1548038',
#   'Q1823258',
#   'Q2037451',
#   'Q2625622',
#   'Q3353648',
#   'Q15791824',
#   'Q15824198',
#   'Q15849567',
#   'Q15849570',
#   'Q64040823'],
#  'Q204917': ['Q893187',
#   'Q1423051',
#   'Q1684392',
#   'Q1765082',
#   'Q2285118',
#   'Q69555476'],
#  'Q324299': ['Q46190664'],
#  'Q390570': ['Q369445', 'Q5405556'],
#  'Q685206': ['Q518585'],
#  'Q752638': ['Q1678703'],
#  'Q787557': ['Q157420', 'Q382616', 'Q745478', 'Q15872903'],
#  'Q1621499': ['Q21651966', 'Q43385258'],
#  'Q17082043': ['Q28944647'],
#  'Q55722043': ['Q133722', 'Q1493573', 'Q12273079'],
#  'Q55722046': ['Q1414882'],
#  'Q55724643': ['Q748187'],
#  'Q55724653': ['Q2908211'],
#  'Q55738663': ['Q204917'],
#  'Q55738665': ['Q187851',
#   'Q615403',
#   'Q1001877',
#   'Q1123270',
#   'Q1394795',
#   'Q1901997',
#   'Q4024964',
#   'Q6321200',
#   'Q6401851',
#   'Q8044776',
#   'Q19393547',
#   'Q19684608',
#   'Q28495286'],
#  'Q55738671': ['Q55738672', 'Q55738673'],
#  'Q55738677': ['Q187780', 'Q4410905', 'Q55738679', 'Q55738680'],
#  'Q55738679': ['Q1423051'],
#  'Q55738684': ['Q281460', 'Q752638', 'Q7661431'],
#  'Q55738685': ['Q4410796', 'Q5317831'],
#  'Q55738905': ['Q518585', 'Q1432696'],
#  'Q55738909': ['Q83266', 'Q685206', 'Q739515', 'Q94698206'],
#  'Q55738931': ['Q902984'],
#  'Q76923197': ['Q5323804',
#   'Q5440437',
#   'Q7992392',
#   'Q76810781',
#   'Q76927954',
#   'Q76934176',
#   'Q76934343',
#   'Q76938135',
#   'Q76938619',
#   'Q76938856',
#   'Q77382683',
#   'Q77382911',
#   'Q77383807',
#   'Q77383978',
#   'Q77384291',
#   'Q77388310',
#   'Q77388710'],
#  'Q76923428': ['Q4650513',
#   'Q5439989',
#   'Q5440437',
#   'Q76810781',
#   'Q76928247',
#   'Q76930110',
#   'Q76934176',
#   'Q76935385',
#   'Q76937168',
#   'Q76937752',
#   'Q76938135',
#   'Q76938365',
#   'Q76939765',
#   'Q77057127',
#   'Q77058618',
#   'Q77382683',
#   'Q77382911',
#   'Q77383807',
#   'Q77383978',
#   'Q77384291',
#   'Q77388310',
#   'Q77388710'],
#  'Q93992': ['Q8563672'],
#  'Q203449': ['Q2389842'],
#  'Q204638': ['Q5171699'],
#  'Q229717': ['Q3574707'],
#  'Q742168': ['Q56259485'],
#  'Q2563510': ['Q1212123'],
#  'Q2566774': ['Q2030820'],
#  'Q7651136': ['Q954904', 'Q956406', 'Q1073120', 'Q105840751'],
#  'Q11648241': ['Q2312868', 'Q8192099'],
#  'Q55721738': ['Q55721739', 'Q55721740'],
#  'Q55721745': ['Q505174', 'Q5099323', 'Q55722035', 'Q55722039'],
#  'Q55738874': ['Q9798', 'Q736874', 'Q810551'],
#  'Q55738903': ['Q1432696', 'Q1678302', 'Q1757829', 'Q55738904'],
#  'Q55738913': ['Q55738914', 'Q55738915', 'Q98381333'],
#  'Q55738921': ['Q5171699'],
#  'Q55738922': ['Q1744357'],
#  'Q55738926': ['Q902984', 'Q7563205', 'Q55738928', 'Q55738937'],
#  'Q55738940': ['Q131168',
#   'Q163759',
#   'Q499387',
#   'Q1134216',
#   'Q1474853',
#   'Q7630969',
#   'Q55738941',
#   'Q55738944'],
#  'Q55738986': ['Q55738988', 'Q55738990'],
#  'Q55774273': ['Q1114297', 'Q1569742', 'Q55738953', 'Q55738954'],
#  'Q356887': ['Q1786052',
#   'Q3689360',
#   'Q4007279',
#   'Q4007280',
#   'Q15141711',
#   'Q47090311',
#   'Q66057874'],
#  'Q384324': ['Q5113837', 'Q16543898', 'Q27492080', 'Q47001818'],
#  'Q681251': ['Q47001818'],
#  'Q1136653': ['Q669370', 'Q19059942'],
#  'Q1588017': ['Q8374', 'Q504847', 'Q2450129', 'Q13417190', 'Q17099625'],
#  'Q1704079': ['Q1744337', 'Q8079928'],
#  'Q2991844': ['Q20578007', 'Q74581228'],
#  'Q5521203': ['Q66829666', 'Q66829670', 'Q68305090', 'Q68305250'],
#  'Q55721731': ['Q55721732', 'Q55721733', 'Q69388262'],
#  'Q55721734': ['Q1014229', 'Q5581711', 'Q55721735', 'Q55721736'],
#  'Q55723185': ['Q748760'],
#  'Q55723216': ['Q55723221', 'Q55723227'],
#  'Q55723232': ['Q1532595', 'Q55723238', 'Q55723242'],
#  'Q55723253': ['Q614158'],
#  'Q55738588': ['Q55738590', 'Q55738591'],
#  'Q55738592': ['Q10862199'],
#  'Q105840309': ['Q17127090'],
#  'Q1678703': ['Q6604441'],
#  'Q1765082': ['Q18669788', 'Q86987181'],
#  'Q69555476': ['Q1483670', 'Q69555977', 'Q69564891']}

# %%
superclase
#Hijo: padres
# Out:
# {'Q191464': ['Q11404'],
#  'Q208421': ['Q11404', 'Q55723221'],
#  'Q211028': ['Q11404'],
#  'Q221769': ['Q11404'],
#  'Q440856': ['Q11404'],
#  'Q520754': ['Q11404'],
#  'Q537750': ['Q11404', 'Q212892'],
#  'Q811075': ['Q11404'],
#  'Q849349': ['Q11404'],
#  'Q1062015': ['Q11404', 'Q5913432'],
#  'Q1156506': ['Q11404'],
#  'Q1158124': ['Q11404'],
#  'Q1196937': ['Q11404', 'Q5199281'],
#  'Q1235547': ['Q11404'],
#  'Q1321939': ['Q11404'],
#  'Q1436500': ['Q11404', 'Q55723287'],
#  'Q1558889': ['Q11404'],
#  'Q1575231': ['Q11404'],
#  'Q2118356': ['Q11404'],
#  'Q2217018': ['Q11404'],
#  'Q2391458': ['Q11404'],
#  'Q2565221': ['Q11404'],
#  'Q2754430': ['Q11404'],
#  'Q3038392': ['Q11404', 'Q212892'],
#  'Q3199707': ['Q11404'],
#  'Q3623050': ['Q11404', 'Q133163'],
#  'Q4450903': ['Q11404'],
#  'Q4863624': ['Q11404'],
#  'Q4905606': ['Q11404'],
#  'Q5064156': ['Q11404'],
#  'Q5211919': ['Q11404'],
#  'Q6458439': ['Q11404'],
#  'Q7278496': ['Q11404'],
#  'Q7384685': ['Q11404'],
#  'Q7682928': ['Q11404', 'Q212892'],
#  'Q7852753': ['Q11404'],
#  'Q10396699': ['Q11404'],
#  'Q10829913': ['Q11404'],
#  'Q11420300': ['Q11404'],
#  'Q11950748': ['Q11404', 'Q133163'],
#  'Q12698682': ['Q11404'],
#  'Q12821705': ['Q11404'],
#  'Q13025534': ['Q11404'],
#  'Q14640031': ['Q11404', 'Q133163'],
#  'Q15614634': ['Q11404', 'Q34379'],
#  'Q28657984': ['Q11404'],
#  'Q28944914': ['Q11404'],
#  'Q60617211': ['Q11404'],
#  'Q60742599': ['Q11404'],
#  'Q80862258': ['Q11404'],
#  'Q101968884': ['Q11404'],
#  'Q129321': ['Q12639'],
#  'Q133722': ['Q12639', 'Q133163', 'Q55722043'],
#  'Q339801': ['Q12639'],
#  'Q390110': ['Q12639'],
#  'Q398619': ['Q12639'],
#  'Q835684': ['Q12639'],
#  'Q859236': ['Q12639'],
#  'Q871633': ['Q12639'],
#  'Q936762': ['Q12639'],
#  'Q943438': ['Q12639', 'Q133163'],
#  'Q963334': ['Q12639'],
#  'Q976406': ['Q12639'],
#  'Q978694': ['Q12639'],
#  'Q1014229': ['Q12639', 'Q55721734'],
#  'Q1043002': ['Q12639'],
#  'Q1050106': ['Q12639'],
#  'Q1075560': ['Q12639', 'Q55722090'],
#  'Q1195473': ['Q12639', 'Q16678513'],
#  'Q1196263': ['Q12639'],
#  'Q1252956': ['Q12639'],
#  'Q1371129': ['Q12639'],
#  'Q1394579': ['Q12639', 'Q55722122'],
#  'Q1401426': ['Q12639'],
#  'Q1414882': ['Q12639', 'Q55722046'],
#  'Q1514705': ['Q12639', 'Q55721723'],
#  'Q1537130': ['Q12639'],
#  'Q1540998': ['Q12639'],
#  'Q1743465': ['Q12639'],
#  'Q1790046': ['Q12639', 'Q55720619'],
#  'Q1842022': ['Q12639', 'Q1071649'],
#  'Q1968760': ['Q12639'],
#  'Q2118808': ['Q12639'],
#  'Q2280552': ['Q12639', 'Q1071649'],
#  'Q2553890': ['Q12639'],
#  'Q2574301': ['Q12639'],
#  'Q2628163': ['Q12639'],
#  'Q2640100': ['Q12639', 'Q1165766'],
#  'Q2698284': ['Q12639'],
#  'Q2815701': ['Q12639'],
#  'Q2904003': ['Q12639', 'Q1071649', 'Q2132068'],
#  'Q2964066': ['Q12639'],
#  'Q3051404': ['Q12639'],
#  'Q3069712': ['Q12639'],
#  'Q3075428': ['Q12639'],
#  'Q3089272': ['Q12639'],
#  'Q3177916': ['Q12639', 'Q52954'],
#  'Q3216262': ['Q12639'],
#  'Q3286003': ['Q12639'],
#  'Q4073152': ['Q12639'],
#  'Q4201135': ['Q12639', 'Q165666'],
#  'Q4203025': ['Q12639'],
#  'Q4260715': ['Q12639', 'Q34379'],
#  'Q4422479': ['Q12639', 'Q133163'],
#  'Q4508644': ['Q12639'],
#  'Q4748495': ['Q12639', 'Q5421167'],
#  'Q4804279': ['Q12639'],
#  'Q4835508': ['Q12639'],
#  'Q4837771': ['Q12639'],
#  'Q4869261': ['Q12639'],
#  'Q4883310': ['Q12639'],
#  'Q4885547': ['Q12639'],
#  'Q4924951': ['Q12639'],
#  'Q4925415': ['Q12639'],
#  'Q4926117': ['Q12639'],
#  'Q4928618': ['Q12639'],
#  'Q4936269': ['Q12639'],
#  'Q4965824': ['Q12639'],
#  'Q4997651': ['Q12639'],
#  'Q5018028': ['Q12639'],
#  'Q5018032': ['Q12639'],
#  'Q5091360': ['Q12639'],
#  'Q5118643': ['Q12639'],
#  'Q5269026': ['Q12639'],
#  'Q5280486': ['Q12639', 'Q133163'],
#  'Q5503427': ['Q12639'],
#  'Q5520758': ['Q12639'],
#  'Q5567120': ['Q12639'],
#  'Q5567145': ['Q12639'],
#  'Q5571121': ['Q12639'],
#  'Q5616867': ['Q12639'],
#  'Q5960459': ['Q12639'],
#  'Q6368868': ['Q12639'],
#  'Q6415165': ['Q12639'],
#  'Q6443033': ['Q12639'],
#  'Q6443034': ['Q12639'],
#  'Q6585154': ['Q12639'],
#  'Q6585156': ['Q12639'],
#  'Q6585157': ['Q12639'],
#  'Q6667913': ['Q12639'],
#  'Q6701540': ['Q12639'],
#  'Q6704467': ['Q12639'],
#  'Q6845269': ['Q12639'],
#  'Q7079990': ['Q12639'],
#  'Q7095084': ['Q12639'],
#  'Q7189851': ['Q12639'],
#  'Q7191300': ['Q12639'],
#  'Q7199741': ['Q12639'],
#  'Q7207611': ['Q12639'],
#  'Q7296331': ['Q12639'],
#  'Q7561075': ['Q12639'],
#  'Q7561115': ['Q12639'],
#  'Q7619070': ['Q12639'],
#  'Q7666172': ['Q12639'],
#  'Q7667735': ['Q12639'],
#  'Q7826219': ['Q12639'],
#  'Q7837932': ['Q12639'],
#  'Q7852942': ['Q12639'],
#  'Q7877832': ['Q12639'],
#  'Q8015157': ['Q12639', 'Q1165766'],
#  'Q9007999': ['Q12639'],
#  'Q9067389': ['Q12639'],
#  'Q11859952': ['Q12639'],
#  'Q12010762': ['Q12639'],
#  'Q12273079': ['Q12639', 'Q55722043'],
#  'Q12620014': ['Q12639', 'Q915689'],
#  'Q13062980': ['Q12639', 'Q1514705'],
#  'Q16257797': ['Q12639'],
#  'Q16632086': ['Q12639'],
#  'Q16875619': ['Q12639'],
#  'Q16878852': ['Q12639'],
#  'Q16885385': ['Q12639'],
#  'Q16891573': ['Q12639'],
#  'Q16908447': ['Q12639'],
#  'Q20106138': ['Q12639'],
#  'Q21789767': ['Q12639'],
#  'Q55722920': ['Q12639'],
#  'Q55722940': ['Q12639'],
#  'Q55738956': ['Q12639', 'Q50821977'],
#  'Q57592280': ['Q12639'],
#  'Q66124118': ['Q12639'],
#  'Q6010': ['Q27939'],
#  'Q41923': ['Q27939'],
#  'Q127624': ['Q27939'],
#  'Q579955': ['Q27939'],
#  'Q600094': ['Q27939'],
#  'Q820922': ['Q27939'],
#  'Q1436228': ['Q27939'],
#  'Q1477153': ['Q27939'],
#  'Q1497328': ['Q27939'],
#  'Q1500983': ['Q27939'],
#  'Q1553339': ['Q27939'],
#  'Q1567963': ['Q27939'],
#  'Q2222716': ['Q27939'],
#  'Q2706051': ['Q27939'],
#  'Q2956219': ['Q27939'],
#  'Q2956237': ['Q27939'],
#  'Q2956242': ['Q27939'],
#  'Q2956246': ['Q27939'],
#  'Q3655696': ['Q27939'],
#  'Q3655812': ['Q27939'],
#  'Q3924081': ['Q27939'],
#  'Q3976062': ['Q27939'],
#  'Q3981262': ['Q27939'],
#  'Q5249313': ['Q27939'],
#  'Q6781835': ['Q27939'],
#  'Q10394634': ['Q27939'],
#  'Q12057308': ['Q27939'],
#  'Q12336368': ['Q27939'],
#  'Q15990884': ['Q27939'],
#  'Q18822510': ['Q27939'],
#  'Q19973796': ['Q27939'],
#  'Q25616123': ['Q27939'],
#  'Q66098673': ['Q27939'],
#  'Q79054127': ['Q27939'],
#  'Q11404': ['Q34379'],
#  'Q12639': ['Q34379'],
#  'Q27939': ['Q34379'],
#  'Q52954': ['Q34379'],
#  'Q105738': ['Q34379'],
#  'Q133163': ['Q34379'],
#  'Q212892': ['Q34379'],
#  'Q217306': ['Q34379'],
#  'Q230062': ['Q34379'],
#  'Q245519': ['Q34379'],
#  'Q258681': ['Q34379'],
#  'Q334606': ['Q34379'],
#  'Q356923': ['Q34379'],
#  'Q365289': ['Q34379'],
#  'Q386382': ['Q34379'],
#  'Q391640': ['Q34379'],
#  'Q424111': ['Q34379'],
#  'Q431585': ['Q34379'],
#  'Q432358': ['Q34379'],
#  'Q471918': ['Q34379'],
#  'Q487818': ['Q34379'],
#  'Q492055': ['Q34379'],
#  'Q513996': ['Q34379'],
#  'Q530209': ['Q34379'],
#  'Q541464': ['Q34379'],
#  'Q545271': ['Q34379'],
#  'Q550596': ['Q34379'],
#  'Q619351': ['Q34379'],
#  'Q623168': ['Q34379'],
#  'Q654117': ['Q34379'],
#  'Q659216': ['Q34379'],
#  'Q679771': ['Q34379'],
#  'Q695269': ['Q34379'],
#  'Q698590': ['Q34379', 'Q25348503'],
#  'Q698593': ['Q34379', 'Q2353374'],
#  'Q704687': ['Q34379'],
#  'Q713574': ['Q34379'],
#  'Q715223': ['Q34379'],
#  'Q735008': ['Q34379'],
#  'Q758885': ['Q34379'],
#  'Q810447': ['Q34379'],
#  'Q810545': ['Q34379'],
#  'Q816031': ['Q34379'],
#  'Q816656': ['Q34379'],
#  'Q825246': ['Q34379'],
#  'Q859091': ['Q34379'],
#  'Q889113': ['Q34379'],
#  'Q890731': ['Q34379', 'Q8347'],
#  'Q893045': ['Q34379'],
#  'Q895007': ['Q34379'],
#  'Q911724': ['Q34379'],
#  'Q924514': ['Q34379'],
#  'Q952980': ['Q34379', 'Q659216'],
#  'Q956339': ['Q34379'],
#  'Q977922': ['Q34379'],
#  'Q1051772': ['Q34379'],
#  'Q1052089': ['Q34379'],
#  'Q1071649': ['Q34379'],
#  'Q1099050': ['Q34379'],
#  'Q1134224': ['Q34379'],
#  'Q1158854': ['Q34379'],
#  'Q1243790': ['Q34379'],
#  'Q1282828': ['Q34379'],
#  'Q1295894': ['Q34379'],
#  'Q1328586': ['Q34379'],
#  'Q1381282': ['Q34379'],
#  'Q1434775': ['Q34379'],
#  'Q1493069': ['Q34379', 'Q194492'],
#  'Q1493856': ['Q34379'],
#  'Q1554749': ['Q34379'],
#  'Q1559267': ['Q34379'],
#  'Q1585780': ['Q34379'],
#  'Q1632523': ['Q34379'],
#  'Q1756773': ['Q34379', 'Q1071649', 'Q11405'],
#  'Q1759467': ['Q34379'],
#  'Q1791240': ['Q34379'],
#  'Q1829398': ['Q34379', 'Q8350'],
#  'Q2002523': ['Q34379'],
#  'Q2030249': ['Q34379'],
#  'Q2048167': ['Q34379'],
#  'Q2125979': ['Q34379'],
#  'Q2171311': ['Q34379'],
#  'Q2195783': ['Q34379'],
#  'Q2215175': ['Q34379'],
#  'Q2229742': ['Q34379'],
#  'Q2305258': ['Q34379'],
#  'Q2310383': ['Q34379'],
#  'Q2313828': ['Q34379'],
#  'Q2361629': ['Q34379'],
#  'Q2374764': ['Q34379'],
#  'Q2382928': ['Q34379'],
#  'Q2386534': ['Q34379'],
#  'Q2390872': ['Q34379'],
#  'Q2399657': ['Q34379'],
#  'Q2419480': ['Q34379'],
#  'Q2452218': ['Q34379'],
#  'Q2453802': ['Q34379'],
#  'Q2473977': ['Q34379', 'Q1327500'],
#  'Q2510552': ['Q34379', 'Q212892'],
#  'Q2511482': ['Q34379'],
#  'Q2529757': ['Q34379'],
#  'Q2532441': ['Q34379'],
#  'Q2540826': ['Q34379'],
#  'Q2551648': ['Q34379'],
#  'Q2564890': ['Q34379'],
#  'Q2646434': ['Q34379'],
#  'Q2724498': ['Q34379'],
#  'Q2746062': ['Q34379'],
#  'Q2755228': ['Q34379', 'Q258896'],
#  'Q2827710': ['Q34379'],
#  'Q2858170': ['Q34379'],
#  'Q2879595': ['Q34379'],
#  'Q2887846': ['Q34379'],
#  'Q2895785': ['Q34379', 'Q230262', 'Q6607'],
#  'Q2900642': ['Q34379'],
#  'Q2902353': ['Q34379'],
#  'Q2902424': ['Q34379'],
#  'Q2912399': ['Q34379', 'Q1051772'],
#  'Q2917420': ['Q34379'],
#  'Q2958769': ['Q34379'],
#  'Q3009831': ['Q34379', 'Q19650003'],
#  'Q3040117': ['Q34379'],
#  'Q3058452': ['Q34379'],
#  'Q3061445': ['Q34379', 'Q181247'],
#  'Q3122611': ['Q34379'],
#  'Q3127531': ['Q34379'],
#  'Q3142190': ['Q34379', 'Q1555833'],
#  'Q3143699': ['Q34379'],
#  'Q3152884': ['Q34379'],
#  'Q3153674': ['Q34379'],
#  'Q3181140': ['Q34379', 'Q212892', 'Q1283177'],
#  'Q3190079': ['Q34379'],
#  'Q3194590': ['Q34379'],
#  'Q3200735': ['Q34379'],
#  'Q3209207': ['Q34379'],
#  'Q3299336': ['Q34379'],
#  'Q3300302': ['Q34379'],
#  'Q3339215': ['Q34379', 'Q173453', 'Q8347'],
#  'Q3346567': ['Q34379'],
#  'Q3395204': ['Q34379'],
#  'Q3408860': ['Q34379'],
#  'Q3415911': ['Q34379'],
#  'Q3416144': ['Q34379'],
#  'Q3418321': ['Q34379'],
#  'Q3480678': ['Q34379'],
#  'Q3481213': ['Q34379', 'Q105303913'],
#  'Q3482784': ['Q34379', 'Q1071649'],
#  'Q3495190': ['Q34379'],
#  'Q3509664': ['Q34379'],
#  'Q3514627': ['Q34379'],
#  'Q3515769': ['Q34379'],
#  'Q3538954': ['Q34379'],
#  'Q3541635': ['Q34379', 'Q241337'],
#  'Q3559944': ['Q34379'],
#  'Q3623161': ['Q34379'],
#  'Q3624466': ['Q34379'],
#  'Q3631657': ['Q34379'],
#  'Q3636149': ['Q34379'],
#  'Q3636159': ['Q34379'],
#  'Q3659427': ['Q34379'],
#  'Q3662051': ['Q34379'],
#  'Q3675133': ['Q34379'],
#  'Q3675208': ['Q34379'],
#  'Q3675209': ['Q34379'],
#  'Q3728958': ['Q34379'],
#  'Q3753343': ['Q34379'],
#  'Q3785746': ['Q34379'],
#  'Q3809543': ['Q34379'],
#  'Q3868722': ['Q34379'],
#  'Q3901246': ['Q34379'],
#  'Q3913027': ['Q34379', 'Q936762'],
#  'Q3955010': ['Q34379'],
#  'Q3961834': ['Q34379'],
#  'Q3964959': ['Q34379'],
#  'Q3973375': ['Q34379'],
#  'Q3977133': ['Q34379'],
#  'Q3979125': ['Q34379'],
#  'Q3980595': ['Q34379'],
#  'Q3980611': ['Q34379'],
#  'Q3992030': ['Q34379'],
#  'Q3999196': ['Q34379'],
#  'Q4009015': ['Q34379'],
#  'Q4019221': ['Q34379'],
#  'Q4058045': ['Q34379'],
#  'Q4097743': ['Q34379'],
#  'Q4160615': ['Q34379'],
#  'Q4179783': ['Q34379'],
#  'Q4180005': ['Q34379'],
#  'Q4207259': ['Q34379'],
#  'Q4217223': ['Q34379'],
#  'Q4244156': ['Q34379'],
#  'Q4306652': ['Q34379'],
#  'Q4358503': ['Q34379'],
#  'Q4371818': ['Q34379'],
#  'Q4384972': ['Q34379'],
#  'Q4399245': ['Q34379'],
#  'Q4447851': ['Q34379'],
#  'Q4470335': ['Q34379'],
#  'Q4524679': ['Q34379'],
#  'Q4644330': ['Q34379'],
#  'Q4667250': ['Q34379'],
#  'Q4683217': ['Q34379'],
#  'Q4687908': ['Q34379'],
#  'Q4697540': ['Q34379'],
#  'Q4699678': ['Q34379'],
#  'Q4734668': ['Q34379'],
#  'Q4739172': ['Q34379'],
#  'Q4745429': ['Q34379'],
#  'Q4751792': ['Q34379'],
#  'Q4778966': ['Q34379'],
#  'Q4783433': ['Q34379'],
#  'Q4784605': ['Q34379'],
#  'Q4807598': ['Q34379'],
#  'Q4812665': ['Q34379'],
#  'Q4818209': ['Q34379'],
#  'Q4833134': ['Q34379'],
#  'Q4839758': ['Q34379'],
#  'Q4842576': ['Q34379'],
#  'Q4855834': ['Q34379', 'Q258896'],
#  'Q4858007': ['Q34379'],
#  'Q4876234': ['Q34379'],
#  'Q4904776': ['Q34379'],
#  'Q4906756': ['Q34379', 'Q163829'],
#  'Q4936748': ['Q34379'],
#  'Q4937543': ['Q34379'],
#  'Q4939982': ['Q34379'],
#  'Q4943384': ['Q34379'],
#  'Q4971783': ['Q34379'],
#  'Q4986985': ['Q34379'],
#  'Q4989127': ['Q34379'],
#  'Q5000938': ['Q34379'],
#  'Q5021684': ['Q34379'],
#  'Q5037685': ['Q34379'],
#  'Q5039581': ['Q34379'],
#  'Q5057403': ['Q34379'],
#  'Q5065645': ['Q34379', 'Q55724840'],
#  'Q5066401': ['Q34379'],
#  'Q5073927': ['Q34379'],
#  'Q5094876': ['Q34379'],
#  'Q5097384': ['Q34379'],
#  'Q5104748': ['Q34379'],
#  'Q5116565': ['Q34379'],
#  'Q5129638': ['Q34379'],
#  'Q5150931': ['Q34379'],
#  'Q5171897': ['Q34379'],
#  'Q5188204': ['Q34379'],
#  'Q5189202': ['Q34379'],
#  'Q5193091': ['Q34379'],
#  'Q5195473': ['Q34379'],
#  'Q5199417': ['Q34379'],
#  'Q5202987': ['Q34379'],
#  'Q5227697': ['Q34379'],
#  'Q5252609': ['Q34379'],
#  'Q5268580': ['Q34379'],
#  'Q5268673': ['Q34379'],
#  'Q5268703': ['Q34379'],
#  'Q5269692': ['Q34379'],
#  'Q5284584': ['Q34379'],
#  'Q5299971': ['Q34379'],
#  'Q5309083': ['Q34379'],
#  'Q5311266': ['Q34379'],
#  'Q5311633': ['Q34379'],
#  'Q5312527': ['Q34379'],
#  'Q5312626': ['Q34379'],
#  'Q5321271': ['Q34379', 'Q181247'],
#  'Q5325306': ['Q34379'],
#  'Q5350462': ['Q34379'],
#  'Q5357606': ['Q34379'],
#  'Q5357961': ['Q34379', 'Q7272401'],
#  'Q5359741': ['Q34379'],
#  'Q5365913': ['Q34379'],
#  'Q5389067': ['Q34379'],
#  'Q5401002': ['Q34379'],
#  'Q5421167': ['Q34379'],
#  'Q5446820': ['Q34379'],
#  'Q5454461': ['Q34379'],
#  'Q5465744': ['Q34379'],
#  'Q5466463': ['Q34379'],
#  'Q5511031': ['Q34379'],
#  'Q5516807': ['Q34379'],
#  'Q5518524': ['Q34379'],
#  'Q5520015': ['Q34379'],
#  'Q5520022': ['Q34379'],
#  'Q5520755': ['Q34379'],
#  'Q5528996': ['Q34379'],
#  'Q5529320': ['Q34379'],
#  'Q5555723': ['Q34379'],
#  'Q5577129': ['Q34379'],
#  'Q5577965': ['Q34379', 'Q192096'],
#  'Q5577967': ['Q34379'],
#  'Q5581804': ['Q34379'],
#  'Q5599360': ['Q34379'],
#  'Q5614420': ['Q34379'],
#  'Q5614726': ['Q34379'],
#  'Q5616828': ['Q34379'],
#  'Q5616864': ['Q34379'],
#  'Q5616871': ['Q34379'],
#  'Q5616873': ['Q34379'],
#  'Q5616880': ['Q34379'],
#  'Q5618064': ['Q34379'],
#  'Q5636660': ['Q34379'],
#  'Q5640442': ['Q34379'],
#  'Q5647100': ['Q34379'],
#  'Q5647435': ['Q34379', 'Q1273167'],
#  'Q5669631': ['Q34379'],
#  'Q5669795': ['Q34379'],
#  'Q5672149': ['Q34379'],
#  'Q5676660': ['Q34379', 'Q4951628'],
#  'Q5682233': ['Q34379'],
#  'Q5686093': ['Q34379'],
#  'Q5691425': ['Q34379'],
#  'Q5692465': ['Q34379'],
#  'Q5708319': ['Q34379'],
#  'Q5714725': ['Q34379'],
#  'Q5739373': ['Q34379'],
#  'Q5739510': ['Q34379'],
#  'Q5748186': ['Q34379'],
#  'Q5755977': ['Q34379'],
#  'Q5765399': ['Q34379'],
#  'Q5766417': ['Q34379'],
#  'Q5769609': ['Q34379'],
#  'Q5784662': ['Q34379'],
#  'Q5807311': ['Q34379'],
#  'Q5851173': ['Q34379'],
#  'Q5875501': ['Q34379'],
#  'Q5887436': ['Q34379'],
#  'Q5891381': ['Q34379', 'Q6607'],
#  'Q5910397': ['Q34379'],
#  'Q5989356': ['Q34379', 'Q936762'],
#  'Q5989502': ['Q34379'],
#  'Q5998237': ['Q34379'],
#  'Q6004656': ['Q34379'],
#  'Q6053421': ['Q34379'],
#  'Q6074814': ['Q34379'],
#  'Q6105823': ['Q34379'],
#  'Q6116662': ['Q34379'],
#  'Q6138473': ['Q34379'],
#  'Q6138475': ['Q34379'],
#  'Q6138488': ['Q34379'],
#  'Q6140170': ['Q34379'],
#  'Q6159663': ['Q34379'],
#  'Q6169915': ['Q34379', 'Q55724621'],
#  'Q6172796': ['Q34379'],
#  'Q6174597': ['Q34379'],
#  'Q6191226': ['Q34379'],
#  'Q6191895': ['Q34379'],
#  'Q6202344': ['Q34379'],
#  'Q6312746': ['Q34379'],
#  'Q6322455': ['Q34379'],
#  'Q6322465': ['Q34379'],
#  'Q6343712': ['Q34379'],
#  'Q6354593': ['Q34379'],
#  'Q6371338': ['Q34379'],
#  'Q6373847': ['Q34379'],
#  'Q6374198': ['Q34379', 'Q133163'],
#  'Q6377724': ['Q34379'],
#  'Q6379590': ['Q34379', 'Q55774135'],
#  'Q6382446': ['Q34379'],
#  'Q6398221': ['Q34379'],
#  'Q6402245': ['Q34379'],
#  'Q6402253': ['Q34379'],
#  'Q6403208': ['Q34379'],
#  'Q6404050': ['Q34379', 'Q1798603'],
#  'Q6411198': ['Q34379'],
#  'Q6429164': ['Q34379', 'Q5581711'],
#  'Q6429165': ['Q34379', 'Q5581711'],
#  'Q6430350': ['Q34379'],
#  'Q6432225': ['Q34379'],
#  'Q6435771': ['Q34379'],
#  'Q6436666': ['Q34379'],
#  'Q6436675': ['Q34379'],
#  'Q6441262': ['Q34379'],
#  'Q6442289': ['Q34379'],
#  'Q6442505': ['Q34379', 'Q510487'],
#  'Q6442967': ['Q34379'],
#  'Q6453652': ['Q34379'],
#  'Q6453655': ['Q34379'],
#  'Q6461940': ['Q34379'],
#  'Q6462789': ['Q34379'],
#  'Q6472082': ['Q34379'],
#  'Q6491889': ['Q34379'],
#  'Q6508789': ['Q34379'],
#  'Q6532301': ['Q34379', 'Q55724880'],
#  'Q6586195': ['Q34379'],
#  'Q7672803': ['Q34379'],
#  'Q7673920': ['Q34379'],
#  'Q7674568': ['Q34379'],
#  'Q7678546': ['Q34379'],
#  'Q7679165': ['Q34379'],
#  'Q7681055': ['Q34379'],
#  'Q7681062': ['Q34379'],
#  'Q7683067': ['Q34379'],
#  'Q7685353': ['Q34379'],
#  'Q7687617': ['Q34379'],
#  'Q7690562': ['Q34379'],
#  'Q7698121': ['Q34379'],
#  'Q7700564': ['Q34379'],
#  'Q7707025': ['Q34379'],
#  'Q7710699': ['Q34379'],
#  'Q7725623': ['Q34379'],
#  'Q7801775': ['Q34379'],
#  'Q7804752': ['Q34379'],
#  'Q7808741': ['Q34379'],
#  'Q7808838': ['Q34379'],
#  'Q7810254': ['Q34379'],
#  'Q7811975': ['Q34379'],
#  'Q7813451': ['Q34379'],
#  'Q7814483': ['Q34379'],
#  'Q7830966': ['Q34379'],
#  'Q7841293': ['Q34379'],
#  'Q7843503': ['Q34379'],
#  'Q7844785': ['Q34379'],
#  'Q7844787': ['Q34379'],
#  'Q7844788': ['Q34379', 'Q55724811'],
#  'Q7844789': ['Q34379'],
#  'Q7844791': ['Q34379'],
#  'Q7849269': ['Q34379'],
#  'Q7849271': ['Q34379'],
#  'Q7849273': ['Q34379'],
#  'Q7849749': ['Q34379'],
#  'Q7851703': ['Q34379'],
#  'Q7852608': ['Q34379'],
#  'Q7852690': ['Q34379', 'Q11405'],
#  'Q7857859': ['Q34379'],
#  'Q7876892': ['Q34379'],
#  'Q7878283': ['Q34379'],
#  'Q7901528': ['Q34379'],
#  'Q7928364': ['Q34379'],
#  'Q7933010': ['Q34379'],
#  'Q7961299': ['Q34379'],
#  'Q7976961': ['Q34379'],
#  'Q8045285': ['Q34379'],
#  'Q8046046': ['Q34379'],
#  'Q8047056': ['Q34379'],
#  'Q8047761': ['Q34379'],
#  'Q8048103': ['Q34379'],
#  'Q8070483': ['Q34379'],
#  'Q8075090': ['Q34379'],
#  'Q8075256': ['Q34379'],
#  'Q8079916': ['Q34379'],
#  'Q8079917': ['Q34379'],
#  'Q8079921': ['Q34379'],
#  'Q8204672': ['Q34379'],
#  'Q8353519': ['Q34379'],
#  'Q9001426': ['Q34379'],
#  'Q9022704': ['Q34379'],
#  'Q9065175': ['Q34379'],
#  'Q9081684': ['Q34379'],
#  'Q9182138': ['Q34379'],
#  'Q9212830': ['Q34379', 'Q659216'],
#  'Q9419091': ['Q34379'],
#  'Q9659186': ['Q34379'],
#  'Q10269821': ['Q34379'],
#  'Q10306950': ['Q34379'],
#  'Q10314435': ['Q34379'],
#  'Q10353206': ['Q34379'],
#  'Q10369682': ['Q34379'],
#  'Q10403797': ['Q34379', 'Q8338'],
#  'Q10431752': ['Q34379'],
#  'Q10431758': ['Q34379'],
#  'Q10753171': ['Q34379'],
#  'Q10783013': ['Q34379'],
#  'Q10783687': ['Q34379'],
#  'Q10822595': ['Q34379'],
#  'Q10840083': ['Q34379'],
#  'Q10840437': ['Q34379'],
#  'Q10861374': ['Q34379'],
#  'Q10892404': ['Q34379'],
#  'Q11075759': ['Q34379'],
#  'Q11092881': ['Q34379'],
#  'Q11098361': ['Q34379'],
#  'Q11215782': ['Q34379'],
#  'Q11341612': ['Q34379'],
#  'Q11498653': ['Q34379'],
#  'Q11650198': ['Q34379', 'Q208320'],
#  'Q11682277': ['Q34379'],
#  'Q11829254': ['Q34379'],
#  'Q11910152': ['Q34379'],
#  'Q11911068': ['Q34379'],
#  'Q11920628': ['Q34379'],
#  'Q11939060': ['Q34379'],
#  'Q11946334': ['Q34379'],
#  'Q11953199': ['Q34379'],
#  'Q11954880': ['Q34379', 'Q2407046'],
#  'Q6653370': ['Q34379'],
#  'Q6654102': ['Q34379'],
#  'Q6668722': ['Q34379'],
#  'Q6710917': ['Q34379'],
#  'Q6718658': ['Q34379'],
#  'Q6723506': ['Q34379'],
#  'Q6732512': ['Q34379'],
#  'Q6740488': ['Q34379'],
#  'Q6748128': ['Q34379'],
#  'Q6749152': ['Q34379'],
#  'Q6749173': ['Q34379'],
#  'Q6750463': ['Q34379'],
#  'Q6754723': ['Q34379'],
#  'Q6759026': ['Q34379'],
#  'Q6772421': ['Q34379'],
#  'Q6782415': ['Q34379'],
#  'Q6783062': ['Q34379'],
#  'Q6797579': ['Q34379'],
#  'Q6815777': ['Q34379'],
#  'Q6862658': ['Q34379'],
#  'Q6864712': ['Q34379'],
#  'Q6875024': ['Q34379'],
#  'Q6932203': ['Q34379'],
#  'Q6936014': ['Q34379'],
#  'Q6943773': ['Q34379'],
#  'Q6951309': ['Q34379'],
#  'Q6960304': ['Q34379'],
#  'Q7047745': ['Q34379', 'Q1295894'],
#  'Q7064485': ['Q34379'],
#  'Q7071063': ['Q34379'],
#  'Q7071407': ['Q34379'],
#  'Q7075256': ['Q34379'],
#  'Q7075353': ['Q34379'],
#  'Q7076774': ['Q34379'],
#  'Q7083206': ['Q34379'],
#  'Q7090062': ['Q34379', 'Q811075'],
#  'Q7090795': ['Q34379'],
#  'Q7095385': ['Q34379'],
#  'Q7101770': ['Q34379'],
#  'Q7101775': ['Q34379'],
#  'Q7103992': ['Q34379'],
#  'Q7108528': ['Q34379'],
#  'Q7120230': ['Q34379'],
#  'Q7123295': ['Q34379'],
#  'Q7129321': ['Q34379'],
#  'Q7130187': ['Q34379'],
#  'Q7143055': ['Q34379'],
#  'Q7186113': ['Q34379'],
#  'Q7198298': ['Q34379'],
#  'Q7201800': ['Q34379'],
#  'Q7205095': ['Q34379'],
#  'Q7265233': ['Q34379'],
#  'Q7269255': ['Q34379'],
#  'Q7269501': ['Q34379'],
#  'Q7271943': ['Q34379'],
#  'Q7272401': ['Q34379'],
#  'Q7272469': ['Q34379'],
#  'Q7281253': ['Q34379'],
#  'Q7303480': ['Q34379'],
#  'Q7314870': ['Q34379', 'Q98457398'],
#  'Q7320165': ['Q34379'],
#  'Q7334676': ['Q34379'],
#  'Q7360333': ['Q34379'],
#  'Q7361386': ['Q34379'],
#  'Q7365591': ['Q34379'],
#  'Q7365593': ['Q34379'],
#  'Q7379154': ['Q34379', 'Q270200'],
#  'Q7403597': ['Q34379'],
#  'Q7404961': ['Q34379'],
#  'Q7406098': ['Q34379'],
#  'Q7408984': ['Q34379'],
#  'Q7410180': ['Q34379', 'Q8347'],
#  'Q7418239': ['Q34379'],
#  'Q7418340': ['Q34379'],
#  'Q7421024': ['Q34379'],
#  'Q7426334': ['Q34379'],
#  'Q7428594': ['Q34379'],
#  'Q7428890': ['Q34379'],
#  'Q7462274': ['Q34379'],
#  'Q7502339': ['Q34379'],
#  'Q7505701': ['Q34379'],
#  'Q7506038': ['Q34379'],
#  'Q7513987': ['Q34379'],
#  'Q7515478': ['Q34379'],
#  'Q7531816': ['Q34379'],
#  'Q7533633': ['Q34379'],
#  'Q7555423': ['Q34379'],
#  'Q7564023': ['Q34379'],
#  'Q7564871': ['Q34379'],
#  'Q7572372': ['Q34379'],
#  'Q7586583': ['Q34379'],
#  'Q7623972': ['Q34379'],
#  'Q7623984': ['Q34379'],
#  'Q7630969': ['Q34379', 'Q131168', 'Q55738940'],
#  'Q7636250': ['Q34379'],
#  'Q7638092': ['Q34379'],
#  'Q7639273': ['Q34379'],
#  'Q7652693': ['Q34379'],
#  'Q7661404': ['Q34379'],
#  'Q7664811': ['Q34379'],
#  'Q18449487': ['Q34379'],
#  'Q18627458': ['Q34379'],
#  'Q19671148': ['Q34379'],
#  'Q19856213': ['Q34379'],
#  'Q19895199': ['Q34379'],
#  'Q19899453': ['Q34379'],
#  'Q20009773': ['Q34379'],
#  'Q20103041': ['Q34379'],
#  'Q20103238': ['Q34379'],
#  'Q20104603': ['Q34379'],
#  'Q20104853': ['Q34379'],
#  'Q20106313': ['Q34379'],
#  'Q20106353': ['Q34379'],
#  'Q20106964': ['Q34379'],
#  'Q20523954': ['Q34379'],
#  'Q20585538': ['Q34379'],
#  'Q20826903': ['Q34379'],
#  'Q20854933': ['Q34379'],
#  'Q20967773': ['Q34379'],
#  'Q21080967': ['Q34379'],
#  'Q21081475': ['Q34379'],
#  'Q21087040': ['Q34379'],
#  'Q21087453': ['Q34379'],
#  'Q25093046': ['Q34379'],
#  'Q25101248': ['Q34379'],
#  'Q25226698': ['Q34379'],
#  'Q25348503': ['Q34379', 'Q47369'],
#  'Q25395631': ['Q34379'],
#  'Q25399492': ['Q34379'],
#  'Q25412985': ['Q34379'],
#  'Q25472791': ['Q34379'],
#  'Q25644178': ['Q34379'],
#  'Q25680583': ['Q34379'],
#  'Q27027147': ['Q34379'],
#  'Q27181298': ['Q34379'],
#  'Q27510104': ['Q34379'],
#  'Q27513249': ['Q34379'],
#  'Q28137123': ['Q34379'],
#  'Q28148538': ['Q34379'],
#  'Q28170750': ['Q34379'],
#  'Q28171515': ['Q34379'],
#  'Q28192975': ['Q34379'],
#  'Q28219771': ['Q34379'],
#  'Q28403542': ['Q34379'],
#  'Q28452681': ['Q34379'],
#  'Q28692811': ['Q34379'],
#  'Q28710739': ['Q34379'],
#  'Q28737179': ['Q34379'],
#  'Q29017799': ['Q34379'],
#  'Q29277213': ['Q34379'],
#  'Q29301219': ['Q34379'],
#  'Q30034571': ['Q34379'],
#  'Q30324270': ['Q34379'],
#  'Q30347637': ['Q34379'],
#  'Q30347664': ['Q34379'],
#  'Q31842594': ['Q34379', 'Q101401'],
#  'Q34379956': ['Q34379'],
#  'Q37681691': ['Q34379'],
#  'Q39056298': ['Q34379'],
#  'Q40447270': ['Q34379'],
#  'Q40447413': ['Q34379', 'Q55723259'],
#  'Q40448318': ['Q34379'],
#  'Q43079402': ['Q34379'],
#  'Q44254442': ['Q34379'],
#  'Q44254482': ['Q34379'],
#  'Q44254502': ['Q34379'],
#  'Q44254550': ['Q34379'],
#  'Q44254585': ['Q34379'],
#  'Q44254611': ['Q34379'],
#  'Q44254669': ['Q34379'],
#  'Q44254678': ['Q34379'],
#  'Q44254733': ['Q34379'],
#  'Q45753024': ['Q34379'],
#  'Q46996061': ['Q34379', 'Q8350'],
#  'Q46996068': ['Q34379'],
#  'Q48817576': ['Q34379'],
#  'Q49184007': ['Q34379'],
#  'Q50329237': ['Q34379'],
#  'Q50331514': ['Q34379'],
#  'Q51846072': ['Q34379'],
#  'Q52987174': ['Q34379', 'Q230262'],
#  'Q55568438': ['Q34379'],
#  'Q55738523': ['Q34379'],
#  'Q56062174': ['Q34379'],
#  'Q56062175': ['Q34379'],
#  'Q56196958': ['Q34379', 'Q105379653', 'Q12521411'],
#  'Q56196959': ['Q34379'],
#  'Q56196961': ['Q34379'],
#  'Q56196962': ['Q34379'],
#  'Q56251798': ['Q34379'],
#  'Q56251800': ['Q34379'],
#  'Q56251803': ['Q34379'],
#  'Q56251805': ['Q34379'],
#  'Q56251806': ['Q34379'],
#  'Q56276235': ['Q34379'],
#  'Q56277888': ['Q34379'],
#  'Q56401746': ['Q34379'],
#  'Q56476228': ['Q34379'],
#  'Q56862947': ['Q34379'],
#  'Q59419216': ['Q34379', 'Q212892'],
#  'Q11955392': ['Q34379'],
#  'Q11990687': ['Q34379'],
#  'Q12017895': ['Q34379'],
#  'Q12059669': ['Q34379'],
#  'Q12233838': ['Q34379'],
#  'Q12483344': ['Q34379'],
#  'Q12483346': ['Q34379'],
#  'Q12484415': ['Q34379'],
#  'Q12485397': ['Q34379'],
#  'Q12519046': ['Q34379'],
#  'Q12521411': ['Q34379', 'Q212892'],
#  'Q12791479': ['Q34379'],
#  'Q12863848': ['Q34379'],
#  'Q12885443': ['Q34379'],
#  'Q12904608': ['Q34379'],
#  'Q12983208': ['Q34379'],
#  'Q12987976': ['Q34379'],
#  'Q13038039': ['Q34379', 'Q11405'],
#  'Q13038049': ['Q34379'],
#  'Q13096799': ['Q34379'],
#  'Q13135638': ['Q34379'],
#  'Q13408004': ['Q34379'],
#  'Q13636556': ['Q34379'],
#  'Q13656026': ['Q34379'],
#  'Q14754685': ['Q34379'],
#  'Q15057905': ['Q34379'],
#  'Q15069864': ['Q34379'],
#  'Q15210789': ['Q34379'],
#  'Q15212740': ['Q34379'],
#  'Q15220707': ['Q34379'],
#  'Q15717974': ['Q34379', 'Q180733'],
#  'Q15785425': ['Q34379', 'Q192096'],
#  'Q15824524': ['Q34379'],
#  'Q15869380': ['Q34379'],
#  'Q16133280': ['Q34379'],
#  'Q16205517': ['Q34379'],
#  'Q16256860': ['Q34379'],
#  'Q16304285': ['Q34379'],
#  'Q16522042': ['Q34379'],
#  'Q16556212': ['Q34379'],
#  'Q16572861': ['Q34379'],
#  'Q16573450': ['Q34379'],
#  'Q16590872': ['Q34379'],
#  'Q16629274': ['Q34379'],
#  'Q16637700': ['Q34379'],
#  'Q16678513': ['Q34379'],
#  'Q16708063': ['Q34379'],
#  'Q16796308': ['Q34379'],
#  'Q16837506': ['Q34379'],
#  'Q16843539': ['Q34379'],
#  'Q16892532': ['Q34379'],
#  'Q16910195': ['Q34379'],
#  'Q16910872': ['Q34379'],
#  'Q16911115': ['Q34379'],
#  'Q16916457': ['Q34379'],
#  'Q16917012': ['Q34379'],
#  'Q16918224': ['Q34379'],
#  'Q16918625': ['Q34379'],
#  'Q16919362': ['Q34379'],
#  'Q16928253': ['Q34379'],
#  'Q16928510': ['Q34379'],
#  'Q16938266': ['Q34379'],
#  'Q16938324': ['Q34379'],
#  'Q16940786': ['Q34379'],
#  'Q16965914': ['Q34379'],
#  'Q16975813': ['Q34379'],
#  'Q16976029': ['Q34379'],
#  'Q16977624': ['Q34379'],
#  'Q16999252': ['Q34379'],
#  'Q17000154': ['Q34379'],
#  'Q17012197': ['Q34379'],
#  'Q17025635': ['Q34379'],
#  'Q17049229': ['Q34379', 'Q1426973'],
#  'Q17055647': ['Q34379'],
#  'Q17061825': ['Q34379'],
#  'Q17062754': ['Q34379'],
#  'Q17064573': ['Q34379'],
#  'Q17067314': ['Q34379'],
#  'Q17068242': ['Q34379'],
#  'Q17070015': ['Q34379'],
#  'Q17070147': ['Q34379'],
#  'Q17070215': ['Q34379'],
#  'Q17082422': ['Q34379'],
#  'Q17084554': ['Q34379'],
#  'Q17085087': ['Q34379', 'Q510487'],
#  'Q17086716': ['Q34379'],
#  'Q17099062': ['Q34379'],
#  'Q17105516': ['Q34379'],
#  'Q17117240': ['Q34379'],
#  'Q17143535': ['Q34379'],
#  'Q17172850': ['Q34379', 'Q98329515'],
#  'Q17189221': ['Q34379'],
#  'Q17591720': ['Q34379'],
#  'Q18178803': ['Q34379'],
#  'Q18224135': ['Q34379'],
#  'Q18350431': ['Q34379'],
#  'Q18377839': ['Q34379'],
#  'Q18379775': ['Q34379'],
#  'Q18391628': ['Q34379', 'Q4951628'],
#  'Q59480249': ['Q34379'],
#  'Q60024229': ['Q34379'],
#  ...}

# %% [markdown]
# ### 3) Imprimir un subárbol de la taxonomía
#
# Crea una operación _print_tree_ que imprimir la jerarquía de clases a partir de un concepto y hasta un nivel de profundidad determinado.
#
# Por ejemplo, a continuación podemos ver el principio de la jerarquía de [voces](https://www.wikidata.org/wiki/Q17172850) con 3 niveles de profundidad:
#
# ```
# 0 voz (Q17172850)
#   1 operatic vocal (Q101436564)
#   1 alto (Q6983813)
#    2 mezzosoprano ligera (Q6012300)
#    2 boy alto (Q53395277)
#    2 alto castrato (Q53395016)
#    2 contralto (Q37137)
#   1 contralto (Q37137)
#    2 contralto cómica (Q5785182)
#    2 lyric contralto (Q54635214)
#    2 Tenorino (Q6141663)
#    2 contralto de coloratura (Q54635184)
#    2 deep contralto (Q54635335)
#    2 contralto dramática (Q5785183)
#   1 bajo (Q27911)
#    2 heavy acting bass (Q54636271)
#    2 bajo profundo (Q2532487)
#    2 bajo buffo (Q1002146)
#    ...
# ```
#
# Como ocurre en todas las grandes bases de conocimiento, dentro de Wikidata hay información que no ha sido bien introducida o está mal clasificada. ¿Puedes encontrar algún ejemplo concreto dentro de la jerarquía de instrumentos?

# %%
def print_tree(concepto, profundidad):

    if profundidad == 0:
        return None

    #imprimir el árbol partiendo de la profundidad 0 y el concepto 'concepto'
    print_tree_aux(concepto, profundidad , 0)


def print_tree_aux(concepto, profundidad_ini, profundidad):

    if (profundidad == profundidad_ini):
        return None

    #imprime el número de espacios necesarios según la altura del árbol
    for i in range (profundidad):
            print('   ', end='')

    print(profundidad, identificador_etiqueta[concepto], '(' + concepto + ')')

    #si el concepto no tiene hijos simplemente finaliza la función
    if not(concepto in subclase.keys()):
        return None

    #llamar a print_tree_aux para cada hijo de 'concepto'
    for c in subclase[concepto]:
        print_tree_aux(c, profundidad_ini, profundidad + 1)

# %% [markdown]
# * #### Comentarios:
#
# Print_tree() es una función que hace uso de la función auxiliar print_tree_aux().
#
# Print_tree_aux() es una función que se dedica a imprimir todo el árbol de forma recursiva y hace uso de un argumento extra en el que se guarda la profuncidad en la que se encuentra la función de forma que así podemos imprimirla correctamente y podemos saber cuando hemos llegado a la altura especificada.
#
# -------------

# %%
print_tree('Q17172850', 3)
# Out:
# 0 voz (Q17172850)
#    1 bajo (Q27911)
#       2 bajo-barítono (Q810480)
#       2 bajo buffo (Q1002146)
#       2 bajo profundo (Q2532487)
#       2 bajo cantante (Q3636053)
#       2 grave (Q5885030)
#       2 octavist (Q7082656)
#       2 bajo caractère (Q20638448)
#       2 high bass (Q54636007)
#       2 dramatic high bass (Q54636036)
#       2 serious bass (Q54636068)
#       2 heavy acting bass (Q54636271)
#       2 Bass bourdon (Q64363543)
#    1 barítono (Q31687)
#       2 bajo-barítono (Q810480)
#       2 character baritone (Q1062931)
#       2 heldenbaritone (Q1601737)
#       2 Barítono buffo (Q5721499)
#       2 Barítono ligero (Q5721503)
#       2 grave (Q5885030)
#       2 Barítono lírico (Q8243255)
#       2 Barítono dramático (Q8243257)
#       2 baryton-noble (Q19740895)
#       2 barítono Martin (Q21478751)
#       2 Barítono martín (Q25404193)
#       2 barítono verdiano (Q54635681)
#       2 acting baritone (Q54635751)
#       2 Kavalierbariton (Q54635784)
#    1 contralto (Q37137)
#       2 contralto cómica (Q5785182)
#       2 contralto dramática (Q5785183)
#       2 Tenorino (Q6141663)
#       2 contralto de coloratura (Q54635184)
#       2 lyric contralto (Q54635214)
#       2 deep contralto (Q54635335)
#    1 mezzosoprano (Q186506)
#       2 altmezzo (Q682525)
#       2 Q1300059 (Q1300059)
#       2 mezzosoprano lírica (Q1878954)
#       2 sopranista (Q1999862)
#       2 mezzosoprano dramática (Q6012297)
#       2 coloratura mezzo-soprano (Q54634572)
#       2 mezzosoprano ligera (Q54634726)
#       2 character mezzo-soprano (Q54634862)
#       2 mezzo-soprano castrato (Q54634945)
#    1 castrato (Q210970)
#       2 alto castrato (Q53395016)
#       2 soprano castrato (Q53830255)
#       2 mezzo-soprano castrato (Q54634945)
#    1 contratenor (Q223166)
#       2 haute-contre (Q1873389)
#    1 Xöömej (Q1067089)
#    1 Voz blanca (Q6164901)
#       2 child soprano (Q53829839)
#    1 alto (Q6983813)
#       2 contralto (Q37137)
#       2 mezzosoprano ligera (Q6012300)
#       2 alto castrato (Q53395016)
#       2 boy alto (Q53395277)
#    1 Treble voice (Q25303818)
#    1 male singing voice (Q54285279)
#    1 female singing voice (Q54285818)
#    1 backing vocal (Q60396389)
#    1 high voice (Q98116969)
#       2 tenor (Q27914)
#       2 soprano (Q30903)
#       2 child soprano (Q53829839)
#    1 operatic vocal (Q101436564)

# %% [markdown]
# * #### Comentarios:
#
# Un error que podemos encontrar en Wikidata es que hay ciertos objetos que no tienen definida su etiqueta.
#
# Por ejemplo: '1 Q2722253 (Q2722253)'
#
#
# Por otra parte, encontramos que hay algún objeto que está introducido varias veces, pero con su identificador diferente.
#
# barítono Martin (Q21478751)
# Barítono martín (Q25404193)
#
# -------

# %% [markdown]
# ### 4) Obtener los LCS
#
# Crea una operación _lcs_ que devuelva todos los LCS de dos conceptos determinados. Recuerda que un concepto C es LCS(A, B) si es más general que ambos y no se puede especializar más sin dejar de serlo.
#
# Para implementarlo seguramente te resulte útil tener otro método que devuelva todos los conceptos más generales que uno dado. _Pista: es fácil de implementar usando operaciones entre conjuntos_.
#
# Ejemplos:
#
# ```
# mezzosoprano dramática (Q6012297), mezzosoprano ligera (Q54634726), mezzosoprano (Q186506)
# LCS('Q6012297', 'Q54634726') = {'Q186506'}
#
# grave (Q5885030), mezzosoprano ligera (Q6012300), voz (Q17172850)
# LCS('Q5885030', 'Q6012300') = {'Q17172850'}
#
# tenor (Q27914)
# LCS('Q27914', 'Q27914') = {'Q27914'}
#
# viola eléctrica (Q15336282), bajo eléctrico (Q64166304), instrumento de cuerda (Q1798603), electrófono (Q105738), necked box lutes (Q55724840)
# LCS('Q15336282', 'Q64166304') = {'Q55724840', 'Q105738', 'Q1798603}
# ```

# %%
def lcs(concepto1, concepto2):
    
    antecesores1 = antecesores(concepto1)
    antecesores2 = antecesores(concepto2)
    antecesores1.add(concepto1)
    antecesores2.add(concepto2)
    
    antecesores_comunes = antecesores1 & antecesores2
    
    aux = set()
    
    for elem in antecesores_comunes:
        aux |= antecesores(elem)
        
    antecesores_comunes -= aux
    
    return antecesores_comunes

def antecesores(concepto):

    ret = set()

    if not(concepto in superclase.keys()):
        return set()

    #añadimos todos los padres del concepto al conjunto
    for padre in superclase[concepto]:
        ret.add(padre)
        ret = ret | antecesores(padre)

    return ret

# %% [markdown]
# * #### Comentarios:
#
# La función antecesores devuelve todo el conjunto de padres del concepto dado y de sus respectivos padres, de forma recursiva.
#
# En la función lcs calculamos todos los antecesores comunes a ambos conceptos y los guardamos en antecesores_comunes.
# Tras esto, nos deshacemos de todos antecesores que sean menos específicos para quedarnos al final con los antecesores comunes más bajos.
#
# -------------

# %%
lcs('Q6012297', 'Q54634726')
# Out:
# {'Q186506'}

# %%
lcs('Q5885030', 'Q6012300')
# Out:
# {'Q17172850'}

# %%
lcs('Q27914', 'Q27914')
# Out:
# {'Q27914'}

# %%
lcs('Q15336282', 'Q64166304')
# Out:
# {'Q105738', 'Q1798603', 'Q55724840'}

# %% [markdown]
# ### 5) Obtener caminos mínimos
#
# Crea una operación _path_ que calcule el camino mínimo entre dos conceptos A y B siendo A más o igual de general que B. Como la taxonomía no tiene ciclos puedes implementarlo como una búsqueda en profunidad. Ten en cuenta que los caminos sólo pueden contener conceptos más específicos o iguales a A y más generales o iguales a B.
#
# Ejemplos:
#
# ```
# path('Q186506', 'Q54634726') = [mezzosoprano (Q186506), mezzosoprano ligera (Q54634726)]
#
# path('Q17172850', 'Q6012300') = [voz (Q17172850), alto (Q6983813), mezzosoprano ligera (Q6012300)]
#
# path('Q27914', 'Q27914') = [tenor (Q27914)]
#
# path('Q34379', 'Q105738') = [instrumento musical (Q34379), cordófono (Q1051772), composite chordophones (Q19588495), lutes (Q1808578), handle lutes (Q30038759), necked lutes (Q55724833), necked box lutes (Q55724840)]
#  ```

# %%
#imprimeEtiqueta le pasamos una lista para que imprima su etiqueta con su identificador con el formato adecuado
def imprimeEtiqueta(elmens):
    
    print('[', end='')
    for x in range (len(elmens)):
    
        print(identificador_etiqueta[elmens[x]]+ ' (' + elmens[x] +')', end ='')
        
        #Controlar el ultimo elemento
        if(x < len(elmens)-1):
            print(', ', end='')
        
    print(']')

# %%
#Path nos devuelve el camino minimo entre el concepto1 y el concepto2
def path(concepto1,concepto2):

    ret = list()
    
    #Caso base
    if concepto1 == concepto2:
        ret.append(concepto1)
        return ret
    
    #Si concepto1 no tiene hijos, se termina devolviendo la lista.
    if not(concepto1 in subclase.keys()):
        return list()

    #Este for son las llamadas recursivas de una busqueda en profundidad
    for c in subclase[concepto1]:
        #si ret es vacio, entonces sigfica que encontramos el camino y no hace falta seguir expandiendo el arbol de busqueda
        if ret == list():
            ret = path(c, concepto2)

    if ret == list():
        return ret
    else:
        ret.append(concepto1)
        return ret

# %% [markdown]
# * ### Comentarios:
#
# Para buscar el camino mas corto entre dos conceptos, usamos la función Path que recorre la taxonomía recursivamente hasta encontrarlo, para ello, miramos cada uno de los hijos del primer concepto.
#
# ---------

# %%
imprimeEtiqueta(path('Q186506', 'Q54634726'))
# Out:
# [mezzosoprano ligera (Q54634726), mezzosoprano (Q186506)]

# %%
imprimeEtiqueta(path('Q17172850', 'Q6012300'))
# Out:
# [mezzosoprano ligera (Q6012300), alto (Q6983813), voz (Q17172850)]

# %%
imprimeEtiqueta(path('Q27914', 'Q27914'))
# Out:
# [tenor (Q27914)]

# %%
imprimeEtiqueta(path('Q34379', 'Q105738'))
# Out:
# [electrófono (Q105738), instrumento musical (Q34379)]

# %% [markdown]
# ### 6) Calcular la similitud
#
# Implementa una operación _similarity_ que calcule la similtud entre dos conceptos. Debe devolver tanto el valor númerico de similitud como los caminos desde la raiz al LCS y desde el LCS a cada uno de los dos conceptos.
#
# Ten en cuenta que debes usar un LCS que maximice el valor de similitud. Si la información de Wikidata no ha cambiado, los valores de similitud deberían coincidir con los que aparecen en los ejemplos pero los caminos no tienen por qué. Y recuerda que no es lo mismo el números de aristas de un camino que el número de nodos del camino.
#
# Ejemplos:
#
# ```
# similarity('Q6012297', 'Q54634726')
# 0.5
# [instrumento musical (Q34379), voz (Q17172850), mezzosoprano (Q186506)]
# [mezzosoprano (Q186506), mezzosoprano dramática (Q6012297)]
# [mezzosoprano (Q186506), mezzosoprano ligera (Q54634726)]
#
# similarity('Q186506', 'Q54634726')
# 0.6666666666666666
# [instrumento musical (Q34379), voz (Q17172850), mezzosoprano (Q186506)]
# [mezzosoprano (Q186506)]
# [mezzosoprano (Q186506), mezzosoprano ligera (Q54634726)]
#
# similarity('Q27914', 'Q27914')
# 1.0
# [instrumento musical (Q34379), voz (Q17172850), high voice (Q98116969), tenor (Q27914)]
# [tenor (Q27914)]
# [tenor (Q27914)]
#
# similarity('Q76239', 'Q78987')
# 0.42857142857142855
# [instrumento musical (Q34379), cordófono (Q1051772), instrumento de cuerda (Q1798603), instrumento de cuerda pulsada (Q230262)]
# [instrumento de cuerda pulsada (Q230262), cítara (Q76239)]
# [instrumento de cuerda pulsada (Q230262), plucked necked box lutes (Q57306162), guitarra (Q6607), guitarra eléctrica (Q78987)]
# ```

# %%
def similarity(obj1, obj2):

    raiz = 'Q34379'

    min_comun = lcs(obj1, obj2)

    max_similarity = 0

    while min_comun != set():

        lcs_aux = min_comun.pop()

        num_aux, camino_raiz_aux, ruta1_aux, ruta2_aux = similarity_aux(obj1,obj2,lcs_aux)

        if num_aux >= max_similarity:
            max_similarity = num_aux
            max_lcs = lcs_aux
            camino_raiz = camino_raiz_aux
            ruta1 = ruta1_aux
            ruta2 = ruta2_aux

    print("Similarity: ", max_similarity)
    print('LCS: ', identificador_etiqueta[max_lcs], max_lcs)
    print('Camino a raiz: ',end = '')
    imprimeEtiqueta(camino_raiz)
    print('Ruta 1: ',end = '')
    imprimeEtiqueta(ruta1)
    print('Ruta 2: ',end = '')
    imprimeEtiqueta(ruta2)



def similarity_aux(obj1,obj2,lcs):

    raiz = 'Q34379'

    min_comun = lcs

    camino_raiz = path(raiz, min_comun)

    ruta1 = path(min_comun, obj1)

    ruta2 = path(min_comun, obj2)

    #hay que restarle -1 a las longitudes de los caminos porque hay que contar las aristas 
    return (len(camino_raiz) - 1)/(((len(camino_raiz) - 1)+(len(ruta1) - 1)+(len(ruta2) - 1))), camino_raiz, ruta1, ruta2

# %% [markdown]
# * ### Comentarios:
#
# Para calcular el LCS común a los dos conceptos, reutilizamos la función LCS. Y para calcular los caminos desde la raíz al LCS y desde el LCS a cada uno de los dos conceptos, reutilizamos la función path.
#
# Como podemos tener varios conceptos a una misma distancia mínima, mediante el while del código y la función auxiliar, calculamos para cada uno de esos conceptos la similitud correspondiente, y guardamos aquella que es máxima.
#
# -------

# %%
similarity('Q6012297', 'Q54634726')
# Out:
# Similarity:  0.5
# LCS:  mezzosoprano Q186506
# Camino a raiz: [mezzosoprano (Q186506), voz (Q17172850), instrumento musical (Q34379)]
# Ruta 1: [mezzosoprano dramática (Q6012297), mezzosoprano (Q186506)]
# Ruta 2: [mezzosoprano ligera (Q54634726), mezzosoprano (Q186506)]

# %%
similarity('Q186506', 'Q54634726')
# Out:
# Similarity:  0.6666666666666666
# LCS:  mezzosoprano Q186506
# Camino a raiz: [mezzosoprano (Q186506), voz (Q17172850), instrumento musical (Q34379)]
# Ruta 1: [mezzosoprano (Q186506)]
# Ruta 2: [mezzosoprano ligera (Q54634726), mezzosoprano (Q186506)]

# %%
similarity('Q27914', 'Q27914')
# Out:
# Similarity:  1.0
# LCS:  tenor Q27914
# Camino a raiz: [tenor (Q27914), high voice (Q98116969), voz (Q17172850), instrumento musical (Q34379)]
# Ruta 1: [tenor (Q27914)]
# Ruta 2: [tenor (Q27914)]

# %%
similarity('Q76239', 'Q78987')
# Out:
# Similarity:  0.42857142857142855
# LCS:  instrumento de cuerda pulsada Q230262
# Camino a raiz: [instrumento de cuerda pulsada (Q230262), instrumento de cuerda (Q1798603), cordófono (Q1051772), instrumento musical (Q34379)]
# Ruta 1: [cítara (Q76239), instrumento de cuerda pulsada (Q230262)]
# Ruta 2: [guitarra eléctrica (Q78987), guitarra (Q6607), plucked necked box lutes (Q57306162), instrumento de cuerda pulsada (Q230262)]

# %% [markdown]
# ### 7) Análisis de las similitudes
#
# Calcula la similitud 2 a 2 de los siguientes instrumentos y explica razonadamente si los valores obtenidos tienen sentido de acuerdo a tu intuición sobre si se parecen o no.
#
# ```
# piano (Q5994), guitarra (Q6607), guitarra eléctrica (Q78987), flauta (Q11405), trompeta (Q8338)
# ```

# %%
def similitud_2_a_2(conjunto):

    for x in range (len(conjunto)):
        for y in range(x + 1, len(conjunto)):
            #Para mostrar los elementos que estamos comparando
            print('Comparacion: ' + identificador_etiqueta[conjunto[x]] + ', ' + identificador_etiqueta[conjunto[y]])
            #Motrar la similitud
            similarity(conjunto[x], conjunto[y])
            print(end='\n\n')

# %%
conjunto = ['Q5994','Q6607','Q78987','Q11405','Q8338']

# %%
similitud_2_a_2(conjunto)
# Out:
# Comparacion: piano, guitarra
# Similarity:  0.2727272727272727
# LCS:  instrumento de cuerda pulsada Q230262
# Camino a raiz: [instrumento de cuerda pulsada (Q230262), instrumento de cuerda (Q1798603), cordófono (Q1051772), instrumento musical (Q34379)]
# Ruta 1: [piano (Q5994), true board zithers with resonator box (Q4951628), true board zithers with resonator (Q55724742), true board zithers (Q55724736), board zithers (Q50829016), cítara (Q76239), instrumento de cuerda pulsada (Q230262)]
# Ruta 2: [guitarra (Q6607), plucked necked box lutes (Q57306162), instrumento de cuerda pulsada (Q230262)]
#
#
# Comparacion: piano, guitarra eléctrica
# Similarity:  0.25
# LCS:  instrumento de cuerda pulsada Q230262
# Camino a raiz: [instrumento de cuerda pulsada (Q230262), instrumento de cuerda (Q1798603), cordófono (Q1051772), instrumento musical (Q34379)]
# Ruta 1: [piano (Q5994), true board zithers with resonator box (Q4951628), true board zithers with resonator (Q55724742), true board zithers (Q55724736), board zithers (Q50829016), cítara (Q76239), instrumento de cuerda pulsada (Q230262)]
# Ruta 2: [guitarra eléctrica (Q78987), guitarra (Q6607), plucked necked box lutes (Q57306162), instrumento de cuerda pulsada (Q230262)]
#
#
# Comparacion: piano, flauta
# Similarity:  0.0
# LCS:  instrumento musical Q34379
# Camino a raiz: [instrumento musical (Q34379)]
# Ruta 1: [piano (Q5994), teclado (Q52954), instrumento musical (Q34379)]
# Ruta 2: [flauta (Q11405), instrumento de viento (Q173453), aerófono (Q659216), instrumento musical (Q34379)]
#
#
# Comparacion: piano, trompeta
# Similarity:  0.0
# LCS:  instrumento musical Q34379
# Camino a raiz: [instrumento musical (Q34379)]
# Ruta 1: [piano (Q5994), teclado (Q52954), instrumento musical (Q34379)]
# Ruta 2: [trompeta (Q8338), instrumento de viento-metal (Q180744), instrumento de viento (Q173453), aerófono (Q659216), instrumento musical (Q34379)]
#
#
# Comparacion: guitarra, guitarra eléctrica
# Similarity:  0.8333333333333334
# LCS:  guitarra Q6607
# Camino a raiz: [guitarra (Q6607), plucked necked box lutes (Q57306162), instrumento de cuerda pulsada (Q230262), instrumento de cuerda (Q1798603), cordófono (Q1051772), instrumento musical (Q34379)]
# Ruta 1: [guitarra (Q6607)]
# Ruta 2: [guitarra eléctrica (Q78987), guitarra (Q6607)]
#
#
# Comparacion: guitarra, flauta
# Similarity:  0.0
# LCS:  instrumento musical Q34379
# Camino a raiz: [instrumento musical (Q34379)]
# Ruta 1: [guitarra (Q6607), plucked necked box lutes (Q57306162), instrumento de cuerda pulsada (Q230262), instrumento de cuerda (Q1798603), cordófono (Q1051772), instrumento musical (Q34379)]
# Ruta 2: [flauta (Q11405), instrumento de viento (Q173453), aerófono (Q659216), instrumento musical (Q34379)]
#
#
# Comparacion: guitarra, trompeta
# Similarity:  0.0
# LCS:  instrumento musical Q34379
# Camino a raiz: [instrumento musical (Q34379)]
# Ruta 1: [guitarra (Q6607), plucked necked box lutes (Q57306162), instrumento de cuerda pulsada (Q230262), instrumento de cuerda (Q1798603), cordófono (Q1051772), instrumento musical (Q34379)]
# Ruta 2: [trompeta (Q8338), instrumento de viento-metal (Q180744), instrumento de viento (Q173453), aerófono (Q659216), instrumento musical (Q34379)]
#
#
# Comparacion: guitarra eléctrica, flauta
# Similarity:  0.0
# LCS:  instrumento musical Q34379
# Camino a raiz: [instrumento musical (Q34379)]
# Ruta 1: [guitarra eléctrica (Q78987), electro-acoustic chordophones (Q55738960), electro-acoustic instruments (Q50821977), electrófono (Q105738), instrumento musical (Q34379)]
# Ruta 2: [flauta (Q11405), instrumento de viento (Q173453), aerófono (Q659216), instrumento musical (Q34379)]
#
#
# Comparacion: guitarra eléctrica, trompeta
# Similarity:  0.0
# LCS:  instrumento musical Q34379
# Camino a raiz: [instrumento musical (Q34379)]
# Ruta 1: [guitarra eléctrica (Q78987), electro-acoustic chordophones (Q55738960), electro-acoustic instruments (Q50821977), electrófono (Q105738), instrumento musical (Q34379)]
# Ruta 2: [trompeta (Q8338), instrumento de viento-metal (Q180744), instrumento de viento (Q173453), aerófono (Q659216), instrumento musical (Q34379)]
#
#
# Comparacion: flauta, trompeta
# Similarity:  0.4
# LCS:  instrumento de viento Q173453
# Camino a raiz: [instrumento de viento (Q173453), aerófono (Q659216), instrumento musical (Q34379)]
# Ruta 1: [flauta (Q11405), instrumento de viento (Q173453)]
# Ruta 2: [trompeta (Q8338), instrumento de viento-metal (Q180744), instrumento de viento (Q173453)]

# %% [markdown]
# * #### Comentarios:
# Tras evaluar la salida, estamos de acuerdo con el resultado obtenido. Entre los instrumentos de las mismas familias, ya sea cuerda o viento, hay un mayor porcentaje de similitud.
#
# Comparando entre el piano y las guitarras (0.27%), y la flauta y la trompeta (0.4),  aunque ambas comparaciones solo tienen en común que son instrumentos de la misma familia, hay menor similitud entre el piano y las guitarras porque al tener la misma longitud del LCS hasta la raíz que la otra comparación, y mayor longitud de ruta desde los instrumentos hasta el LCS, aplicando la fórmula de similitud, obtenemos un menor porcentaje.
#
# Entre flauta y trompeta obtenemos 0.4 porque ambos son de viento, pero no hay más similitudes ya que uno pertenece a la familia de viento metal y el otro no. Y entre el piano y las guitarras solo hay en común que son de cuerda. En cambio, entre guitarra y guitarra eléctrica se aprecia que tienen bastante en común: [guitarra (Q6607), plucked necked box lutes (Q57306162), instrumento de cuerda pulsada (Q230262), instrumento de cuerda (Q1798603), cordófono (Q1051772), instrumento musical (Q34379)].
#
# ----------------
